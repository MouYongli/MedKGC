# %%
import csv

# Specify the file path
# csv_file_path = 'output_gpt.csv'
csv_file_path = 'output.csv'

# Read the data from the CSV file
data = []
with open(csv_file_path, 'r', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        data.append(row)

# total number of rows
print(f"total number of rows: {len(data)}")

# count the number of rows with "ui" = ''
print(f"number of not normalized rows: {len([row for row in data if row['ui'] == ''])}")
# Out:
# total number of rows: 1250
# number of not normalized rows: 752

# %%
import json
import time
from pprint import pprint
import pandas as pd


all_entities = pd.read_csv('output.csv')

# Print total number of entities
print(f"Total number of entities: {len(all_entities)}")

# count the number of rows with column "ui" = null
print(f"Number of not normalized entities: {len(all_entities[all_entities['ui'].isnull()])}")


import sys
import os
from pprint import pprint

# # Add the parent directory to the Python path
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(parent_dir)

from utils.umls_api import umls_id2semantic


# 遍历all_entities
for index, row in all_entities.iterrows():
    # if 'ui' = null, then print
    if pd.notnull(row['ui']):
        # print(row['ui'])
        print(row['semanticTypes'])
#         if row['semanticTypes'] == "No results":
#             row['semanticTypes'] = umls_id2semantic(row['ui'])
#             time.sleep(0.05)


# # Save the updated DataFrame to a new CSV file
# output_file = 'output_with_report.csv'

# all_entities.to_csv(output_file, index=False)

# print(f"数据已保存到 '{output_file}' 文件中。")
# Out:
# Total number of entities: 1250
# Number of not normalized entities: 752
# Body Part, Organ, or Organ Component
# Qualitative Concept
# Qualitative Concept
# Spatial Concept
# Spatial Concept
# Spatial Concept
# Spatial Concept
# Spatial Concept
# Spatial Concept
# Body Part, Organ, or Organ Component
# Body Part, Organ, or Organ Component
# Spatial Concept
# Qualitative Concept
# Spatial Concept
# Anatomical Structure
# Functional Concept
# Qualitative Concept
# Pathologic Function
# Body Part, Organ, or Organ Component
# Chemical Viewed Functionally
# Body Part, Organ, or Organ Component
# Quantitative Concept
# Pathologic Function
# Disease or Syndrome
# Qualitative Concept
# Spatial Concept
# Activity
# Injury or Poisoning
# Temporal Concept
# Finding
# Chemical Viewed Structurally
# Finding
# Body Part, Organ, or Organ Component
# Spatial Concept
# Finding
# Spatial Concept
# Qualitative Concept
# Body Location or Region
# Body Location or Region
# Immunologic Factor
# ...
