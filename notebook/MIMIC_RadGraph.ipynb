# %% [markdown]
# # MIMIC
# location:
# - /DATA1/llm-research/MIMIC-CXR
#
# number of studies:
# - 227,835 radiology studies

# %% [markdown]
# # RadGraph
# location:
# - /DATA1/llm-research/RadGraph/physionet.org/files/radgraph/1.0.0/
#
# file:
# - train,json
# - 425 reports
# - source: {'MIMIC-CXR'}
#   - question (not 500?)
#
# file:
# - test.json
# - 100 reports
# - source: {'MIMIC-CXR', 'CheXpert'}
#
# Paper RadGraph
# > We release a development dataset, which contains board-certified radiologist annotations for 500 radiology reports from the MIMIC-CXR dataset (14,579 entities and 10,889 relations), and a test dataset, which contains two independent sets of board-certified radiologist annotations for 100 radiology reports split equally across the MIMIC-CXR and CheXpert datasets.
#
# ## Summary of train.json

# %%
import json
from pprint import pprint

path = '/DATA1/llm-research/RadGraph/physionet.org/files/radgraph/1.0.0/train.json'
# path = '/DATA1/llm-research/RadGraph/physionet.org/files/radgraph/1.0.0/dev.json'


with open(path, 'r') as f:
    train_data = json.load(f)

# Length of data
print('Length of data:', len(train_data))

# Print first 10 keys of data
print('First 10 keys of data:', list(train_data.keys())[:10])

# Show an example
# example_key = 'p18/p18004941/s58821758.txt'
# print('Example:', example_key)
# pprint.pprint(train_data[example_key])

# print text
# print('Text:', train_data[example_key]['text'])
# pprint(train_data[example_key])

# path = '/DATA1/llm-research/RadGraph/physionet.org/files/radgraph/1.0.0/dev.json'
# Out:
# Length of data: 425
# First 10 keys of data: ['p18/p18004941/s58821758.txt', 'p18/p18004941/s58034164.txt', 'p18/p18004941/s57101461.txt', 'p18/p18004941/s52289350.txt', 'p18/p18004941/s55426484.txt', 'p18/p18004941/s55576421.txt', 'p18/p18003081/s57007000.txt', 'p18/p18003081/s51239857.txt', 'p18/p18003081/s56557601.txt', 'p18/p18003081/s59630984.txt']

# %% [markdown]
# ## Uniqeu entities in training data
# Length of all_unique_entities_dict: 1250

# %%
import json
import pprint

# Step 1: Initialize an empty dictionary to store all unique entities
# structure: label: {entity: {normalization: null, reports: list}}
all_unique_entities_dict = {}

# list of all entities
i = 0

# Step 2: Iterate through each report in the train_data
for report_key, report_data in train_data.items():
    for entity_id, entity_info in report_data['entities'].items():
        i += 1
        entity = entity_info['tokens']
        label = entity_info['label']
        start_ix = entity_info['start_ix']
        end_ix = entity_info['end_ix']



        if entity not in all_unique_entities_dict:
            all_unique_entities_dict[entity] = {
                'label': label,
                'reports': [
                    {report_key: 
                        {   'start_ix': start_ix, 
                            'end_ix': end_ix
                        }
                    }
                ],
                'normalization': None
            }
        else:
            all_unique_entities_dict[entity]['reports'].append(
                {report_key: 
                    {   'start_ix': start_ix, 
                        'end_ix': end_ix
                    }
                }
            )

# len of all_unique_entities_dict
print('Length of all_unique_entities_dict:', len(all_unique_entities_dict))
print('Number of entities:', i)
# Out:
# Length of all_unique_entities_dict: 1250
# Number of entities: 12388

# %% [markdown]
# ## write to file

# %%
# Save Output all_entities to a JSON file
# with open('all_unique_entities.json', 'w', encoding='utf-8') as f:
#     json.dump(all_unique_entities_dict, f, ensure_ascii=False, indent=4)

# print("All entities have been saved to 'all_unique_entities.json'")
# Out:
# All entities have been saved to 'all_unique_entities.json'

# %% [markdown]
# ## Read the saved file

# %%
import json
import pprint

## Read the saved file
with open('../resource/all_unique_entities.json', 'r', encoding='utf-8') as f:
    all_unique_entities = json.load(f)

# Print the first 10 entities
print('First 10 entities:')
pprint.pprint(list(all_unique_entities.keys())[:10])

print(all_unique_entities['Lung']['normalization'])
# Out:
# First 10 entities:
# ['Lungs',
#  'clear',
#  'Normal',
#  'cardiomediastinal',
#  'hilar',
#  'silhouettes',
#  'pleural',
#  'surfaces',
#  'Endotracheal',
#  'tube']
# None

# %% [markdown]
# ## sorted by label (e.g. ANATOMY, OBSERVATION, etc.)

# %%
import json
import pprint

# Step 1: Initialize an empty dictionary to store all unique entities
# structure: label: {entity: {normalization: null, reports: list}}
all_entities = {}

# Step 2: Iterate through each report in the train_data
for report_key, report_data in train_data.items():
    if 'entities' in report_data:
        # Step 3: Iterate through each entity in 'entities'
        for entity_id, entity_info in report_data['entities'].items():
            # get 'tokens' as entity
            entity = entity_info['tokens']
            # get 'label' as label
            label = entity_info['label']
            
            # if label not in all_entities
            if label not in all_entities:
                # add new label with entity, normalization, and report_key
                all_entities[label] = {entity: {'normalization': None, 'reports': [report_key]}}
            else:
                # if entity not in all_entities[label]
                if entity not in all_entities[label]:
                    # add new entity with normalization and report_key
                    all_entities[label][entity] = {'normalization': None, 'reports': [report_key]}
                else:
                    # update existing entity with new report_key
                    all_entities[label][entity]['reports'].append(report_key)

# Print the results for 'ANAT-DP' label
pprint.pprint(all_entities['ANAT-DP'])

# Print the number of unique entities for 'ANAT-DP' label
print(f"Number of unique 'ANAT-DP' entities: {len(all_entities['ANAT-DP'])}")

# Output all_entities to a JSON file
with open('all_entities.json', 'w', encoding='utf-8') as f:
    json.dump(all_entities, f, ensure_ascii=False, indent=4)

print("All entities have been saved to 'all_entities.json'")
# Out:
# {'1.8 cm above': {'normalization': None,
#                   'reports': ['p10/p10002428/s59659695.txt',
#                               'p10/p10002428/s59659695.txt']},
#  '2.8 cm above': {'normalization': None,
#                   'reports': ['p15/p15007517/s52317711.txt']},
#  '2.9 cm above': {'normalization': None,
#                   'reports': ['p15/p15009504/s51227163.txt']},
#  '3 cm above': {'normalization': None,
#                 'reports': ['p15/p15006483/s59006665.txt',
#                             'p15/p15006483/s57012181.txt']},
#  '3.4 cm': {'normalization': None, 'reports': ['p15/p15009504/s58857907.txt']},
#  '3.5 cm above': {'normalization': None,
#                   'reports': ['p15/p15007517/s59416262.txt']},
#  '3.6 cm above': {'normalization': None,
#                   'reports': ['p15/p15009504/s52538987.txt']},
#  '4 cm above': {'normalization': None,
#                 'reports': ['p18/p18010079/s55080309.txt']},
#  '4.3 cm': {'normalization': None, 'reports': ['p18/p18004941/s52289350.txt']},
#  '4.6 cm above': {'normalization': None,
#                   'reports': ['p10/p10002428/s56836542.txt']},
#  '4.7 cm above': {'normalization': None,
#                   'reports': ['p15/p15007517/s50648100.txt']},
#  '5 cm above': {'normalization': None,
#                 'reports': ['p18/p18026902/s57297476.txt']},
#  '5.6 cm': {'normalization': None, 'reports': ['p10/p10002428/s56597576.txt']},
#  '6 cm above': {'normalization': None,
#                 'reports': ['p10/p10004235/s52379321.txt',
#                             'p10/p10004235/s52379321.txt']},
#  '7 cm': {'normalization': None,
#           'reports': ['p10/p10004235/s57318275.txt',
#                       'p10/p10004235/s57318275.txt']},
#  '8 cm above': {'normalization': None,
#                 'reports': ['p18/p18003402/s52034419.txt']},
#  'AC': {'normalization': None,
#         'reports': ['p15/p15001834/s54486241.txt',
#                     'p15/p15001834/s58938701.txt',
#                     'p15/p15001834/s58938701.txt']},
#  'AP': {'normalization': None, 'reports': ['p15/p15165563/s54509771.txt']},
#  'AZYGOS': {'normalization': None, 'reports': ['p18/p18012427/s52470431.txt']},
#  'Aorta': {'normalization': None,
#            'reports': ['p15/p15003296/s54535760.txt',
#                        'p15/p15007487/s57478149.txt']},
#  'Aortic': {'normalization': None,
#             'reports': ['p10/p10005749/s53170451.txt',
#                         'p18/p18001922/s51753105.txt']},
#  'Apical': {'normalization': None, 'reports': ['p18/p18010079/s55080309.txt']},
#  'BASILAR': {'normalization': None, 'reports': ['p15/p15009233/s50208186.txt']},
#  'BILATERAL': {'normalization': None,
#                'reports': ['p15/p15009233/s50208186.txt']},
#  'Base': {'normalization': None, 'reports': ['p15/p15002496/s51438936.txt']},
#  'Biapical': {'normalization': None,
#               'reports': ['p15/p15003294/s51224077.txt',
#                           'p15/p15003294/s51225513.txt',
#                           'p15/p15003294/s58755630.txt',
#                           'p15/p15003294/s57007434.txt',
#                           'p18/p18003894/s58464660.txt',
#                           'p15/p15001393/s54726934.txt',
#                           'p18/p18028180/s53423151.txt']},
#  'Bibasilar': {'normalization': None,
#                'reports': ['p15/p15024484/s55357745.txt',
#                            'p15/p15024484/s55357745.txt',
#                            'p10/p10005749/s53170451.txt',
#                            'p15/p15001136/s50077246.txt',
#                            'p18/p18001922/s51753105.txt',
#                            'p15/p15003296/s54535760.txt',
#                            'p15/p15003296/s54535760.txt',
#                            'p18/p18022445/s52389030.txt',
#                            'p18/p18003894/s58464660.txt',
#                            'p10/p10003502/s53282957.txt',
#                            'p18/p18022983/s57985067.txt',
#                            'p18/p18022983/s57381264.txt',
#                            'p10/p10004235/s52379321.txt',
#                            'p10/p10004235/s52379321.txt',
#                            'p10/p10004235/s57318275.txt',
#                            'p18/p18001157/s57119564.txt',
#                            'p15/p15009233/s59402206.txt',
#                            'p15/p15009233/s59402206.txt',
#                            'p10/p10002428/s56100138.txt',
#                            'p10/p10002428/s57506266.txt']},
#  'Bilateral': {'normalization': None,
#                'reports': ['p15/p15024484/s55162960.txt',
#                            'p15/p15024484/s59036766.txt',
#                            'p10/p10004457/s55439624.txt',
#                            'p10/p10005749/s57249718.txt',
#                            'p10/p10005749/s58865310.txt',
#                            'p10/p10003502/s52139270.txt',
#                            'p18/p18000745/s59579972.txt',
#                            'p18/p18000745/s52172170.txt',
#                            'p10/p10007795/s54581957.txt',
#                            'p10/p10007795/s57677975.txt',
#                            'p15/p15007517/s50648100.txt',
#                            'p15/p15007517/s52317711.txt',
#                            'p15/p15009504/s55274948.txt',
#                            'p10/p10005368/s57426090.txt',
#                            'p18/p18001157/s59771012.txt',
#                            'p18/p18017189/s55185780.txt',
#                            'p10/p10002428/s50292543.txt',
#                            'p10/p10002428/s59015983.txt',
#                            'p10/p10002428/s57506266.txt',
#                            'p10/p10002428/s59659695.txt',
#                            'p15/p15007710/s51338738.txt',
#                            'p10/p10005024/s59581256.txt',
#                            'p15/p15001203/s50723040.txt']},
#  'Bony': {'normalization': None,
#           'reports': ['p15/p15024484/s59036766.txt',
#                       'p10/p10003956/s53245562.txt',
#                       'p10/p10002930/s55885481.txt',
#                       'p10/p10002661/s53368584.txt',
#                       'p15/p15009233/s54027174.txt',
#                       'p15/p15000393/s52116555.txt',
#                       'p15/p15001834/s58938701.txt']},
#  'Both': {'normalization': None, 'reports': ['p15/p15002643/s51061808.txt']},
#  'Bronchial': {'normalization': None,
#                'reports': ['p10/p10003019/s58365492.txt',
#                            'p18/p18011616/s59704184.txt']},
#  'Bronchovascular': {'normalization': None,
#                      'reports': ['p15/p15001834/s58938701.txt']},
#  'CARDIAC': {'normalization': None,
#              'reports': ['p18/p18012427/s52470431.txt',
#                          'p15/p15009233/s50208186.txt']},
#  'CP': {'normalization': None,
#         'reports': ['p10/p10005368/s54510564.txt',
#                     'p10/p10005368/s54510564.txt']},
#  'Cardiac': {'normalization': None,
#              'reports': ['p10/p10005749/s59735352.txt',
#                          'p10/p10005749/s53170451.txt',
#                          'p18/p18023211/s56555187.txt',
#                          'p15/p15001136/s52592881.txt',
#                          'p18/p18001922/s52288833.txt',
#                          'p15/p15165563/s57194811.txt',
#                          'p15/p15078112/s56824160.txt',
#                          'p15/p15003294/s57007434.txt',
#                          'p18/p18012427/s54748444.txt',
#                          'p15/p15003296/s54535760.txt',
#                          'p15/p15003296/s51554855.txt',
#                          'p18/p18022445/s51773947.txt',
#                          'p18/p18001942/s56433237.txt',
#                          'p15/p15002678/s54040323.txt',
#                          'p10/p10003502/s57641661.txt',
#                          'p10/p10003502/s52309364.txt',
#                          'p10/p10003502/s50084553.txt',
#                          'p18/p18028999/s58738737.txt',
#                          'p18/p18020943/s55270846.txt',
#                          'p18/p18020943/s56433279.txt',
#                          'p18/p18022983/s57985067.txt',
#                          'p15/p15009504/s55274948.txt',
#                          'p15/p15009504/s51227163.txt',
#                          'p18/p18015004/s59622916.txt',
#                          'p10/p10003637/s57024735.txt',
#                          'p10/p10003019/s53098685.txt',
#                          'p18/p18003402/s55894071.txt',
#                          'p10/p10002428/s52460896.txt',
#                          'p10/p10002428/s59891001.txt',
#                          'p10/p10002428/s55758034.txt',
#                          'p10/p10002428/s59414737.txt',
#                          'p10/p10002428/s58838312.txt',
#                          'p10/p10002428/s58851198.txt',
#                          'p10/p10002428/s54020701.txt',
#                          'p10/p10002428/s59098825.txt',
#                          'p15/p15002496/s52886085.txt',
#                          'p15/p15001474/s58221226.txt',
#                          'p15/p15002397/s57752049.txt',
#                          'p18/p18000379/s55748408.txt']},
#  'Cardiomediastinal': {'normalization': None,
#                        'reports': ['p15/p15024484/s55162960.txt',
#                                    'p15/p15024484/s59429123.txt',
#                                    'p15/p15024484/s54162490.txt',
#                                    'p18/p18023211/s59956583.txt',
#                                    'p15/p15004061/s56845046.txt',
#                                    'p15/p15078112/s59479753.txt',
#                                    'p18/p18026902/s51741672.txt',
#                                    'p15/p15007487/s53221126.txt',
#                                    'p15/p15002678/s56528605.txt',
#                                    'p15/p15002678/s50618143.txt',
#                                    'p18/p18022983/s51605945.txt',
#                                    'p15/p15006483/s57974872.txt',
#                                    'p10/p10002930/s55885481.txt',
#                                    'p10/p10007795/s54492585.txt',
#                                    'p10/p10007795/s56375093.txt',
#                                    'p15/p15007517/s58745793.txt',
#                                    'p10/p10002661/s53368584.txt',
#                                    'p15/p15003988/s51924979.txt',
#                                    'p10/p10004235/s59895508.txt',
#                                    'p10/p10003019/s58365492.txt',
#                                    'p10/p10003019/s55931751.txt',
#                                    'p18/p18001529/s58906888.txt',
#                                    'p15/p15000393/s51634677.txt',
#                                    'p15/p15000393/s52116555.txt',
#                                    'p10/p10002428/s50862960.txt',
#                                    'p10/p10002428/s51574899.txt',
#                                    'p15/p15007710/s57053735.txt',
#                                    'p18/p18000379/s57516501.txt',
#                                    'p15/p15001834/s52944718.txt',
#                                    'p15/p15001834/s50931830.txt']},
#  'Central': {'normalization': None, 'reports': ['p18/p18006842/s56350245.txt']},
#  'Coronary': {'normalization': None,
#               'reports': ['p18/p18017189/s55185780.txt']},
#  'GE': {'normalization': None,
#         'reports': ['p18/p18022445/s56006486.txt',
#                     'p10/p10002428/s56597576.txt']},
#  'GE junction': {'normalization': None,
#                  'reports': ['p18/p18015004/s57985812.txt']},
#  'HILAR': {'normalization': None, 'reports': ['p18/p18012427/s52470431.txt']},
#  'Heart': {'normalization': None,
#            'reports': ['p18/p18004941/s58034164.txt',
#                        'p18/p18003081/s52532534.txt',
#                        'p18/p18003081/s52648242.txt',
#                        'p18/p18003081/s53302126.txt',
#                        'p10/p10005749/s58865310.txt',
#                        'p18/p18001922/s51753105.txt',
#                        'p15/p15078112/s53214365.txt',
#                        'p15/p15078112/s51228277.txt',
#                        'p15/p15078112/s58703686.txt',
#                        'p18/p18026902/s59872068.txt',
#                        'p15/p15003294/s58755630.txt',
#                        'p15/p15003296/s58235657.txt',
#                        'p18/p18010079/s53957050.txt',
#                        'p18/p18010079/s55080309.txt',
#                        'p15/p15007487/s52305139.txt',
#                        'p15/p15007487/s57478149.txt',
#                        'p15/p15002538/s51219765.txt',
#                        'p15/p15002538/s51219765.txt',
#                        'p18/p18019295/s57254021.txt',
#                        'p18/p18019295/s52492192.txt',
#                        'p18/p18003894/s50954658.txt',
#                        'p15/p15002678/s59989751.txt',
#                        'p15/p15002678/s54481740.txt',
#                        'p15/p15002678/s54481740.txt',
#                        'p10/p10003502/s53282957.txt',
#                        'p18/p18022983/s57381264.txt',
#                        'p10/p10007795/s57677975.txt',
#                        'p10/p10005866/s56175428.txt',
#                        'p15/p15007517/s59740051.txt',
#                        'p15/p15003988/s51924979.txt',
#                        'p15/p15002074/s52562523.txt',
#                        'p10/p10005368/s56689183.txt',
#                        'p18/p18015004/s58110495.txt',
#                        'p18/p18015004/s56533254.txt',
#                        'p18/p18015004/s54721527.txt',
#                        'p18/p18015004/s51210113.txt',
#                        'p10/p10003637/s51461467.txt',
#                        'p10/p10003019/s55487822.txt',
#                        'p10/p10003019/s55487822.txt',
#                        'p10/p10003019/s59635047.txt',
#                        'p10/p10003019/s59607556.txt',
#                        'p15/p15001393/s54726934.txt',
#                        'p18/p18001157/s59771012.txt',
#                        'p10/p10004322/s57662923.txt',
#                        'p18/p18003402/s58269004.txt',
#                        'p18/p18017189/s55185780.txt',
#                        'p15/p15000393/s58990129.txt',
#                        'p15/p15000393/s53701643.txt',
#                        'p15/p15000393/s59128455.txt',
#                        'p15/p15000393/s59788459.txt',
#                        'p15/p15000393/s57099953.txt',
#                        'p10/p10002428/s56100138.txt',
#                        'p10/p10002428/s59258773.txt',
#                        'p10/p10002428/s58581921.txt',
#                        'p10/p10002428/s57064083.txt',
#                        'p15/p15002496/s51438936.txt',
#                        'p15/p15001474/s51737379.txt',
#                        'p15/p15007710/s57675460.txt',
#                        'p18/p18011616/s57021204.txt',
#                        'p18/p18028180/s53423151.txt',
#                        'p18/p18028180/s57601456.txt',
#                        'p18/p18028180/s55973443.txt',
#                        'p18/p18000379/s59391463.txt',
#                        'p18/p18000379/s53632378.txt']},
#  'Hemidiaphragm': {'normalization': None,
#                    'reports': ['p18/p18022445/s55421520.txt']},
#  'Hila': {'normalization': None, 'reports': ['p10/p10002428/s50027225.txt']},
#  'Hilar': {'normalization': None,
#            'reports': ['p15/p15009504/s58857907.txt',
#                        'p10/p10005368/s56689183.txt',
#                        'p18/p18017189/s54781713.txt',
#                        'p15/p15009233/s51745487.txt',
#                        'p18/p18001786/s51462360.txt',
#                        'p15/p15002397/s57752049.txt']},
#  'IJ': {'normalization': None,
#         'reports': ['p15/p15004061/s51985597.txt',
#                     'p18/p18003894/s53451407.txt',
#                     'p18/p18003894/s58464660.txt',
#                     'p18/p18028999/s57987829.txt',
#                     'p18/p18028999/s57987829.txt',
#                     'p18/p18028999/s57987829.txt',
#                     'p18/p18028999/s53725346.txt',
#                     'p15/p15007517/s58608641.txt',
#                     'p15/p15009504/s55274948.txt',
#                     'p15/p15009504/s59292871.txt',
#                     'p15/p15009504/s59292871.txt',
#                     'p15/p15009504/s51227163.txt',
#                     'p15/p15009504/s56362726.txt',
#                     'p10/p10002428/s59098825.txt']},
#  'Interstitial': {'normalization': None,
#                   'reports': ['p15/p15002496/s52886085.txt']},
#  'L 2 through L 4': {'normalization': None,
#                      'reports': ['p18/p18010079/s53957050.txt']},
#  'LOBE': {'normalization': None, 'reports': ['p18/p18012427/s52470431.txt']},
#  'LUNG': {'normalization': None, 'reports': ['p18/p18012427/s52470431.txt']},
#  'Lateral': {'normalization': None, 'reports': ['p18/p18001157/s59771012.txt']},
#  'Left': {'normalization': None,
#           'reports': ['p18/p18003081/s51438902.txt',
#                       'p10/p10005749/s54060141.txt',
#                       'p18/p18001922/s57925491.txt',
#                       'p15/p15004061/s50854153.txt',
#                       'p15/p15004061/s50854153.txt',
#                       'p15/p15078112/s59839693.txt',
#                       'p15/p15078112/s58166907.txt',
#                       'p15/p15078112/s59479753.txt',
#                       'p15/p15078112/s56824160.txt',
#                       'p18/p18026902/s58219787.txt',
#                       'p18/p18026902/s57297476.txt',
#                       'p18/p18012427/s54748444.txt',
#                       'p15/p15003296/s56457261.txt',
#                       'p18/p18010079/s59097048.txt',
#                       'p18/p18010079/s53957050.txt',
#                       'p15/p15007487/s59926921.txt',
#                       'p15/p15007487/s52305139.txt',
#                       'p15/p15007487/s57478149.txt',
#                       'p15/p15007487/s53221126.txt',
#                       'p15/p15007487/s59752695.txt',
#                       'p15/p15007487/s55512501.txt',
#                       'p15/p15007487/s58025316.txt',
#                       'p18/p18003894/s54842645.txt',
#                       'p10/p10007795/s54581957.txt',
#                       'p10/p10005866/s56175428.txt',
#                       'p15/p15007517/s51550673.txt',
#                       'p18/p18017363/s54401973.txt',
#                       'p10/p10003019/s55931751.txt',
#                       'p10/p10003019/s58505074.txt',
#                       'p15/p15000393/s58990129.txt',
#                       'p15/p15000393/s53701643.txt',
#                       'p15/p15000393/s52929930.txt',
#                       'p15/p15000393/s57099953.txt',
#                       'p15/p15000393/s55479181.txt',
#                       'p15/p15000393/s55723653.txt',
#                       'p10/p10002428/s51574899.txt',
#                       'p10/p10002428/s58838312.txt',
#                       'p10/p10002428/s50027225.txt',
#                       'p18/p18006842/s50471520.txt',
#                       'p15/p15002496/s51438936.txt',
#                       'p15/p15002496/s52886085.txt',
#                       'p15/p15001203/s50723040.txt']},
#  'Left - sided': {'normalization': None,
#                   'reports': ['p15/p15004061/s51985597.txt',
#                               'p15/p15078112/s59479753.txt',
#                               'p10/p10007795/s54054513.txt',
#                               'p10/p10003637/s51461467.txt']},
#  'Left sided': {'normalization': None,
#                 'reports': ['p18/p18003894/s53451407.txt']},
#  'Low': {'normalization': None, 'reports': ['p10/p10003637/s51371378.txt']},
#  'Lower': {'normalization': None, 'reports': ['p15/p15165563/s53383993.txt']},
#  'Lung': {'normalization': None,
#           'reports': ['p18/p18003081/s57007000.txt',
#                       'p10/p10005749/s54060141.txt',
#                       'p18/p18023211/s56555187.txt',
#                       'p15/p15004061/s51985597.txt',
#                       'p15/p15078112/s53834915.txt',
#                       'p15/p15003296/s51554855.txt',
#                       'p15/p15003296/s55162880.txt',
#                       'p15/p15007487/s53221126.txt',
#                       'p15/p15002678/s50618143.txt',
#                       'p18/p18022983/s51605945.txt',
#                       'p18/p18022983/s57985067.txt',
#                       'p18/p18017363/s54401973.txt',
#                       'p18/p18017363/s55076850.txt',
#                       'p18/p18015004/s56533254.txt',
#                       'p18/p18015004/s51210113.txt',
#                       'p18/p18015004/s51210113.txt',
#                       'p10/p10003019/s59829602.txt',
#                       'p18/p18001157/s57119564.txt',
#                       'p15/p15009233/s57930478.txt',
#                       'p15/p15001834/s58938701.txt']},
#  'Lungs': {'normalization': None,
#            'reports': ['p18/p18004941/s58821758.txt',
#                        'p18/p18003081/s53302126.txt',
#                        'p18/p18001922/s52638004.txt',
#                        'p18/p18001922/s52288833.txt',
#                        'p15/p15165563/s51659523.txt',
#                        'p15/p15004061/s56845046.txt',
#                        'p15/p15078112/s51228277.txt',
#                        'p15/p15078112/s58703686.txt',
#                        'p18/p18026902/s53920289.txt',
#                        'p18/p18026902/s51741672.txt',
#                        'p15/p15002538/s51219765.txt',
#                        'p18/p18019295/s57254021.txt',
#                        'p18/p18019295/s52492192.txt',
#                        'p10/p10002930/s55885481.txt',
#                        'p15/p15003988/s51924979.txt',
#                        'p15/p15002074/s52562523.txt',
#                        'p10/p10003637/s51461467.txt',
#                        'p15/p15000393/s59128455.txt',
#                        'p10/p10002428/s58581921.txt',
#                        'p15/p15003026/s53882677.txt',
#                        'p18/p18011616/s50630819.txt',
#                        'p18/p18028180/s53423151.txt',
#                        'p18/p18028180/s57601456.txt',
#                        'p18/p18000379/s59391463.txt',
#                        'p18/p18000379/s58920421.txt']},
#  'MEDIASTINAL': {'normalization': None,
#                  'reports': ['p18/p18012427/s52470431.txt']},
#  'Median': {'normalization': None, 'reports': ['p18/p18026902/s57297476.txt']},
#  'Mediastinal': {'normalization': None,
#                  'reports': ['p18/p18003081/s55159460.txt',
#                              'p15/p15001136/s50077246.txt',
#                              'p15/p15165563/s57008959.txt',
#                              'p15/p15003294/s58755630.txt',
#                              'p15/p15003294/s57007434.txt',
#                              'p18/p18012427/s55382203.txt',
#                              'p15/p15003296/s54535760.txt',
#                              'p10/p10003502/s57812613.txt',
#                              'p18/p18020943/s56320518.txt',
#                              'p18/p18020943/s56433279.txt',
#                              'p10/p10005866/s56175428.txt',
#                              'p18/p18015004/s59622916.txt',
#                              'p10/p10003637/s51461467.txt',
#                              'p10/p10004322/s57662923.txt',
#                              'p15/p15002496/s52886085.txt',
#                              'p15/p15007710/s57675460.txt',
#                              'p18/p18011616/s57021204.txt',
#                              'p18/p18000379/s59391463.txt',
#                              'p15/p15002643/s51061808.txt']},
#  'Mediastinum': {'normalization': None,
#                  'reports': ['p15/p15165563/s51659523.txt',
#                              'p15/p15002678/s59989751.txt']},
#  'Midline': {'normalization': None, 'reports': ['p18/p18026902/s51741672.txt']},
#  'Multiple': {'normalization': None,
#               'reports': ['p10/p10002428/s56100138.txt',
#                           'p10/p10002428/s56100138.txt']},
#  'Osseous': {'normalization': None,
#              'reports': ['p18/p18003081/s52532534.txt',
#                          'p15/p15078112/s53214365.txt',
#                          'p15/p15002957/s50480029.txt',
#                          'p10/p10002428/s58838312.txt',
#                          'p15/p15001474/s58221226.txt']},
#  'PARENCHYMAL': {'normalization': None,
#                  'reports': ['p18/p18012427/s52470431.txt',
#                              'p18/p18012427/s52470431.txt']},
#  'PLEURAL': {'normalization': None, 'reports': ['p15/p15009233/s50208186.txt']},
#  'PULMONARY': {'normalization': None,
#                'reports': ['p15/p15009233/s50208186.txt']},
#  'Pectus': {'normalization': None, 'reports': ['p10/p10003255/s52843603.txt']},
#  'Perihilar': {'normalization': None,
#                'reports': ['p10/p10003502/s53282957.txt']},
#  'Peripheral': {'normalization': None,
#                 'reports': ['p15/p15007710/s57053735.txt']},
#  'Pleural': {'normalization': None,
#              'reports': ['p10/p10007795/s56375093.txt',
#                          'p15/p15009504/s59050955.txt',
#                          'p18/p18015004/s54721527.txt',
#                          'p18/p18015004/s51210113.txt',
#                          'p10/p10002428/s59891001.txt',
#                          'p15/p15007710/s57675460.txt']},
#  'Pulmonary': {'normalization': None,
#                'reports': ['p18/p18004941/s58034164.txt',
#                            'p15/p15024484/s55357745.txt',
#                            'p15/p15165563/s57194811.txt',
#                            'p18/p18012427/s54748444.txt',
#                            'p15/p15003296/s52507068.txt',
#                            'p18/p18022445/s56006486.txt',
#                            'p18/p18022445/s51773947.txt',
#                            'p10/p10003502/s50084553.txt',
#                            'p18/p18022983/s57985067.txt',
#                            'p15/p15007517/s55042886.txt',
#                            'p10/p10004235/s52379321.txt',
#                            'p10/p10004235/s52379321.txt',
#                            'p10/p10004235/s52379321.txt',
#                            'p18/p18015004/s54721527.txt',
#                            'p18/p18001157/s59771012.txt',
#                            'p18/p18006842/s50230234.txt',
#                            'p15/p15001474/s51737379.txt',
#                            'p18/p18011616/s57021204.txt',
#                            'p18/p18028180/s57844688.txt',
#                            'p18/p18000379/s59391463.txt',
#                            'p18/p18000379/s55748408.txt']},
#  'Remainder': {'normalization': None,
#                'reports': ['p10/p10003019/s58365492.txt']},
#  'Retrocardiac': {'normalization': None,
#                   'reports': ['p18/p18026902/s55810062.txt',
#                               'p18/p18026902/s59872068.txt',
#                               'p18/p18028999/s56651721.txt',
#                               'p10/p10007795/s54317369.txt',
#                               'p15/p15007517/s55042886.txt',
#                               'p15/p15007517/s55042886.txt',
#                               'p15/p15009504/s58857907.txt',
#                               'p18/p18017363/s55076850.txt',
#                               'p18/p18017363/s55076850.txt',
#                               'p18/p18015004/s51210113.txt',
#                               'p18/p18003402/s52034419.txt',
#                               'p18/p18006842/s59376580.txt']},
#  'Rib': {'normalization': None,
#          'reports': ['p18/p18010079/s59097048.txt',
#                      'p18/p18010079/s53957050.txt']},
#  'Right': {'normalization': None,
#            'reports': ['p18/p18023211/s56555187.txt',
#                        'p15/p15165563/s53383993.txt',
#                        'p15/p15078112/s52859232.txt',
#                        'p15/p15078112/s56824160.txt',
#                        'p18/p18026902/s58219787.txt',
#                        'p18/p18026902/s57297476.txt',
#                        'p18/p18026902/s57297476.txt',
#                        'p15/p15003294/s55968942.txt',
#                        'p18/p18012427/s54748444.txt',
#                        'p15/p15003296/s58235657.txt',
#                        'p18/p18003894/s58777551.txt',
#                        'p18/p18003894/s58464660.txt',
#                        'p15/p15002678/s59989751.txt',
#                        'p15/p15002678/s50508258.txt',
#                        'p18/p18028999/s57987829.txt',
#                        'p18/p18028999/s57987829.txt',
#                        'p18/p18028999/s58738737.txt',
#                        'p18/p18020943/s55270846.txt',
#                        'p18/p18020943/s55270846.txt',
#                        'p18/p18020943/s56433279.txt',
#                        'p18/p18020943/s56433279.txt',
#                        'p18/p18022983/s52601618.txt',
#                        'p18/p18000745/s59984925.txt',
#                        'p18/p18000745/s52172170.txt',
#                        'p10/p10007795/s57677975.txt',
#                        'p15/p15007517/s58608641.txt',
#                        'p15/p15009504/s55274948.txt',
#                        'p15/p15009504/s51227163.txt',
#                        'p18/p18017363/s54401973.txt',
#                        'p10/p10005368/s57426090.txt',
#                        'p10/p10004235/s52604377.txt',
#                        'p10/p10003019/s56635465.txt',
#                        'p10/p10003019/s56635465.txt',
#                        'p10/p10003019/s55487822.txt',
#                        'p10/p10003019/s55487822.txt',
#                        'p10/p10003019/s55931751.txt',
#                        'p18/p18003402/s58269004.txt',
#                        'p15/p15009233/s51745487.txt',
#                        'p15/p15000393/s53701643.txt',
#                        'p10/p10002428/s52460896.txt',
#                        'p10/p10002428/s59891001.txt',
#                        'p10/p10002428/s59659695.txt',
#                        'p10/p10002428/s58581921.txt',
#                        'p10/p10002428/s57064083.txt',
#                        'p18/p18006842/s55078395.txt',
#                        'p15/p15002496/s50531159.txt',
#                        'p15/p15002496/s52886085.txt',
#                        'p15/p15007710/s53832381.txt',
#                        'p18/p18011616/s57021204.txt',
#                        'p18/p18000379/s53632378.txt',
#                        'p18/p18017572/s56064830.txt']},
#  'Right - sided': {'normalization': None,
#                    'reports': ['p15/p15078112/s56882127.txt',
#                                'p18/p18003894/s53451407.txt',
#                                'p18/p18000379/s57516501.txt']},
#  'SILHOUETTE': {'normalization': None,
#                 'reports': ['p18/p18012427/s52470431.txt',
#                             'p15/p15009233/s50208186.txt']},
#  'SIZE': {'normalization': None, 'reports': ['p18/p18012427/s52470431.txt']},
#  'STRUCTURES': {'normalization': None,
#                 'reports': ['p18/p18012427/s52470431.txt']},
#  'SVC': {'normalization': None,
#          'reports': ['p10/p10005749/s54040624.txt',
#                      'p15/p15004061/s51985597.txt',
#                      'p15/p15078112/s56357121.txt',
#                      'p15/p15078112/s56357121.txt',
#                      'p15/p15078112/s58166907.txt',
#                      'p15/p15078112/s59479753.txt',
#                      'p15/p15078112/s59479753.txt',
#                      'p15/p15078112/s56824160.txt',
#                      'p18/p18026902/s58219787.txt',
#                      'p18/p18026902/s59872068.txt',
#                      'p15/p15002678/s50508258.txt',
#                      'p18/p18028999/s57987829.txt',
#                      'p18/p18028999/s57987829.txt',
#                      'p18/p18028999/s57987829.txt',
#                      'p18/p18028999/s53725346.txt',
#                      'p18/p18020943/s55270846.txt',
#                      'p18/p18020943/s55270846.txt',
#                      'p15/p15006483/s59006665.txt',
#                      'p10/p10007795/s54492585.txt',
#                      'p10/p10007795/s54317369.txt',
#                      'p10/p10007795/s57677975.txt',
#                      'p10/p10007795/s57677975.txt',
#                      'p10/p10007795/s58754452.txt',
#                      'p10/p10007795/s54054513.txt',
#                      'p10/p10007795/s56375093.txt',
#                      'p10/p10004235/s52604377.txt',
#                      'p10/p10004235/s52604377.txt',
#                      'p10/p10004235/s58604118.txt',
#                      'p10/p10003019/s59339276.txt',
#                      'p18/p18003402/s52418327.txt',
#                      'p10/p10002428/s56836542.txt',
#                      'p10/p10002428/s56597576.txt',
#                      'p10/p10002428/s50027225.txt',
#                      'p18/p18028180/s50287111.txt',
#                      'p15/p15002852/s58489231.txt']},
#  'Soft tissue': {'normalization': None,
#                  'reports': ['p18/p18001942/s56433237.txt']},
#  'Spinal': {'normalization': None,
#             'reports': ['p18/p18003402/s59341192.txt',
#                         'p18/p18003402/s55894071.txt']},
#  'Sternal': {'normalization': None,
#              'reports': ['p18/p18022983/s57381264.txt',
#                          'p18/p18000745/s59579972.txt']},
#  'Subcutaneous': {'normalization': None,
#                   'reports': ['p18/p18010079/s55080309.txt',
#                               'p15/p15000393/s59788459.txt',
#                               'p18/p18017572/s51869019.txt']},
#  'Superiorly': {'normalization': None,
#                 'reports': ['p10/p10002428/s58838312.txt',
#                             'p15/p15002496/s53190310.txt']},
#  'T 12 vertebral': {'normalization': None,
#                     'reports': ['p18/p18011616/s55142338.txt']},
#  'T 5 through T 9': {'normalization': None,
#                      'reports': ['p18/p18002106/s56517301.txt',
#                                  'p18/p18002106/s56517301.txt']},
#  'Thoracic': {'normalization': None,
#               'reports': ['p15/p15002035/s52843277.txt']},
#  'Thoracolumbar': {'normalization': None,
#                    'reports': ['p18/p18011616/s50630819.txt']},
#  'Trachea': {'normalization': None, 'reports': ['p15/p15002643/s51061808.txt']},
#  'Upper': {'normalization': None,
#            'reports': ['p15/p15003294/s54302152.txt',
#                        'p10/p10004235/s58604118.txt',
#                        'p18/p18015004/s58110495.txt',
#                        'p18/p18015004/s56533254.txt',
#                        'p10/p10002428/s59258773.txt',
#                        'p18/p18000379/s56020891.txt',
#                        'p18/p18017572/s56064830.txt']},
#  'Vascular': {'normalization': None,
#               'reports': ['p18/p18001922/s50114627.txt',
#                           'p18/p18000379/s51568340.txt']},
#  'Vasculature': {'normalization': None,
#                  'reports': ['p10/p10003502/s52309364.txt']},
#  'Vertebral': {'normalization': None,
#                'reports': ['p18/p18003402/s58269004.txt',
#                            'p18/p18003402/s55894071.txt',
#                            'p18/p18003402/s52034419.txt']},
#  'Visceral': {'normalization': None,
#               'reports': ['p18/p18000379/s57516501.txt']},
#  'abdomen': {'normalization': None,
#              'reports': ['p15/p15002183/s52341485.txt',
#                          'p10/p10007795/s57491780.txt',
#                          'p10/p10007795/s54317369.txt',
#                          'p15/p15007517/s59740051.txt',
#                          'p18/p18017363/s55076850.txt',
#                          'p15/p15009233/s58131029.txt',
#                          'p15/p15002496/s52862073.txt',
#                          'p15/p15001474/s51737379.txt',
#                          'p18/p18011616/s59704184.txt',
#                          'p15/p15001834/s54265476.txt']},
#  'acromioclavicular': {'normalization': None,
#                        'reports': ['p15/p15002496/s55461318.txt']},
#  'adjacent': {'normalization': None,
#               'reports': ['p10/p10005749/s57249718.txt',
#                           'p18/p18001942/s56433237.txt',
#                           'p10/p10005866/s56175428.txt',
#                           'p10/p10003019/s59005604.txt',
#                           'p10/p10003019/s59607556.txt',
#                           'p15/p15000393/s52929930.txt']},
#  'airspace': {'normalization': None,
#               'reports': ['p15/p15024484/s55357745.txt',
#                           'p15/p15024484/s55357745.txt',
#                           'p15/p15003296/s55100464.txt',
#                           'p15/p15003296/s55100464.txt',
#                           'p15/p15006483/s54362708.txt',
#                           'p15/p15006483/s54362708.txt',
#                           'p18/p18000745/s53121171.txt',
#                           'p18/p18000745/s59984925.txt',
#                           'p18/p18000745/s52172170.txt',
#                           'p15/p15007517/s59740051.txt',
#                           'p15/p15009504/s58857907.txt',
#                           'p15/p15009504/s52538987.txt',
#                           'p15/p15009504/s52538987.txt',
#                           'p10/p10004235/s52379321.txt',
#                           'p10/p10003019/s53934356.txt',
#                           'p18/p18003402/s59341192.txt',
#                           'p15/p15007710/s51338738.txt']},
#  'airway': {'normalization': None,
#             'reports': ['p18/p18001922/s52326539.txt',
#                         'p10/p10002428/s58581921.txt']},
#  'alveolar': {'normalization': None,
#               'reports': ['p10/p10003502/s53282957.txt',
#                           'p18/p18000745/s51763935.txt',
#                           'p15/p15007517/s58745793.txt',
#                           'p15/p15007517/s58745793.txt',
#                           'p15/p15007517/s58608641.txt',
#                           'p15/p15007517/s58608641.txt',
#                           'p10/p10004235/s52962553.txt',
#                           'p10/p10004235/s52962553.txt']},
#  'angle': {'normalization': None,
#            'reports': ['p15/p15024484/s55357745.txt',
#                        'p15/p15024484/s55357745.txt',
#                        'p18/p18001922/s52288833.txt',
#                        'p18/p18001922/s52288833.txt',
#                        'p18/p18022445/s55421520.txt',
#                        'p15/p15002678/s56528605.txt',
#                        'p10/p10005866/s56175428.txt',
#                        'p10/p10005368/s54510564.txt',
#                        'p10/p10005368/s54510564.txt',
#                        'p15/p15002496/s52886085.txt',
#                        'p15/p15002496/s52886085.txt',
#                        'p15/p15002496/s53190310.txt',
#                        'p15/p15002496/s53190310.txt',
#                        'p18/p18011616/s59704184.txt']},
#  'angles': {'normalization': None, 'reports': ['p15/p15001474/s58221226.txt']},
#  'anterior': {'normalization': None,
#               'reports': ['p15/p15078112/s58703686.txt',
#                           'p15/p15002678/s54481740.txt',
#                           'p10/p10003019/s53934356.txt',
#                           'p15/p15000485/s56074305.txt',
#                           'p18/p18028180/s55973443.txt']},
#  'aorta': {'normalization': None,
#            'reports': ['p15/p15024484/s55357745.txt',
#                        'p18/p18023211/s58462799.txt',
#                        'p15/p15001136/s50077246.txt',
#                        'p15/p15165563/s54307084.txt',
#                        'p15/p15165563/s54509771.txt',
#                        'p15/p15165563/s53383993.txt',
#                        'p18/p18001942/s56433237.txt',
#                        'p10/p10003502/s51180958.txt',
#                        'p10/p10003502/s57812613.txt',
#                        'p18/p18020943/s53949676.txt',
#                        'p10/p10003052/s58630288.txt',
#                        'p10/p10003019/s52117631.txt',
#                        'p10/p10003019/s59730608.txt',
#                        'p18/p18001157/s57119564.txt',
#                        'p15/p15009233/s54785596.txt',
#                        'p15/p15002496/s54741884.txt',
#                        'p15/p15002496/s55461318.txt',
#                        'p15/p15001474/s51737379.txt',
#                        'p15/p15001474/s51737379.txt',
#                        'p15/p15007710/s53803512.txt',
#                        'p15/p15007710/s57053735.txt',
#                        'p15/p15007710/s57053735.txt',
#                        'p15/p15007710/s57053735.txt',
#                        'p15/p15007710/s57377858.txt',
#                        'p18/p18011616/s57021204.txt',
#                        'p18/p18011616/s50686187.txt',
#                        'p18/p18028180/s57826518.txt']},
#  'aortic': {'normalization': None,
#             'reports': ['p15/p15078112/s59479753.txt',
#                         'p18/p18026902/s59872068.txt',
#                         'p15/p15007487/s57478149.txt',
#                         'p18/p18017189/s55185780.txt',
#                         'p15/p15002496/s53190310.txt',
#                         'p15/p15002496/s54796318.txt',
#                         'p18/p18028180/s53423151.txt',
#                         'p15/p15002852/s58489231.txt']},
#  'apex': {'normalization': None,
#           'reports': ['p18/p18004941/s58034164.txt',
#                       'p18/p18010079/s55080309.txt',
#                       'p15/p15007487/s59034151.txt',
#                       'p15/p15007487/s53221126.txt',
#                       'p18/p18003894/s58464660.txt',
#                       'p15/p15002678/s54481740.txt',
#                       'p15/p15002678/s50618143.txt',
#                       'p15/p15002678/s50618143.txt',
#                       'p18/p18028999/s58738737.txt',
#                       'p10/p10005368/s57426090.txt',
#                       'p10/p10003637/s57024735.txt',
#                       'p15/p15000393/s57099953.txt',
#                       'p15/p15000393/s57099953.txt',
#                       'p18/p18006842/s54156702.txt',
#                       'p18/p18017572/s56064830.txt']},
#  'apical': {'normalization': None,
#             'reports': ['p15/p15003294/s50875241.txt',
#                         'p18/p18010079/s59097048.txt',
#                         'p18/p18010079/s56436361.txt',
#                         'p18/p18010079/s53957050.txt',
#                         'p15/p15007487/s54185768.txt',
#                         'p15/p15007487/s59752695.txt',
#                         'p15/p15007487/s59752695.txt',
#                         'p15/p15007487/s53197725.txt',
#                         'p15/p15007487/s58357685.txt',
#                         'p15/p15001501/s55616331.txt',
#                         'p18/p18003894/s58777551.txt',
#                         'p18/p18003894/s53451407.txt',
#                         'p18/p18003894/s53451407.txt',
#                         'p18/p18003894/s56902065.txt',
#                         'p15/p15002678/s53430015.txt',
#                         'p15/p15003988/s50511251.txt',
#                         'p10/p10005368/s56689183.txt',
#                         'p10/p10005368/s56689183.txt',
#                         'p10/p10005368/s57426090.txt',
#                         'p18/p18001157/s59771012.txt',
#                         'p15/p15000393/s53701643.txt',
#                         'p15/p15000393/s59128455.txt',
#                         'p15/p15000393/s57099953.txt',
#                         'p15/p15000393/s55723653.txt',
#                         'p10/p10002428/s58838312.txt',
#                         'p10/p10002428/s58838312.txt',
#                         'p18/p18000379/s59261316.txt',
#                         'p18/p18000379/s59261316.txt',
#                         'p18/p18000379/s58920421.txt',
#                         'p18/p18000379/s58920421.txt',
#                         'p18/p18000379/s57516501.txt',
#                         'p18/p18000379/s57516501.txt',
#                         'p18/p18000379/s51817182.txt',
#                         'p18/p18000379/s56020891.txt',
#                         'p18/p18000379/s53632378.txt',
#                         'p18/p18017572/s52030715.txt',
#                         'p18/p18017572/s51869019.txt',
#                         'p18/p18017572/s54836720.txt']},
#  'apices': {'normalization': None, 'reports': ['p18/p18003081/s50577366.txt']},
#  'appearance': {'normalization': None,
#                 'reports': ['p10/p10002559/s52212843.txt']},
#  'approximately 1.8 cm': {'normalization': None,
#                           'reports': ['p18/p18004941/s55576421.txt']},
#  'approximately 12 cm': {'normalization': None,
#                          'reports': ['p18/p18004941/s55576421.txt']},
#  'approximately 2 cm': {'normalization': None,
#                         'reports': ['p18/p18004941/s55576421.txt']},
#  'approximately 2.3 cm': {'normalization': None,
#                           'reports': ['p10/p10005866/s56175428.txt',
#                                       'p10/p10005866/s56175428.txt']},
#  'approximately 5 cm': {'normalization': None,
#                         'reports': ['p10/p10002428/s57506266.txt',
#                                     'p10/p10002428/s57506266.txt']},
#  'approximately a 4.6 cm': {'normalization': None,
#                             'reports': ['p18/p18004941/s58034164.txt']},
#  'arch': {'normalization': None,
#           'reports': ['p15/p15003296/s54535760.txt',
#                       'p15/p15007487/s57478149.txt',
#                       'p15/p15002496/s53190310.txt',
#                       'p15/p15002496/s54796318.txt',
#                       'p18/p18028180/s53423151.txt',
#                       'p18/p18028180/s57826518.txt']},
#  'area': {'normalization': None,
#           'reports': ['p10/p10003637/s51371378.txt',
#                       'p18/p18001157/s59771012.txt']},
#  'areas': {'normalization': None,
#            'reports': ['p10/p10003019/s52117631.txt',
#                        'p10/p10003019/s59607556.txt']},
#  'arteries': {'normalization': None,
#               'reports': ['p15/p15009504/s55274948.txt',
#                           'p15/p15009504/s51227163.txt',
#                           'p18/p18017189/s55185780.txt',
#                           'p18/p18017189/s55185780.txt',
#                           'p18/p18017189/s59226684.txt',
#                           'p15/p15001474/s58221226.txt',
#                           'p15/p15007710/s57053735.txt']},
#  'artery': {'normalization': None,
#             'reports': ['p10/p10005749/s54060141.txt',
#                         'p10/p10005749/s54060141.txt',
#                         'p10/p10005749/s54060141.txt',
#                         'p10/p10005749/s57249718.txt',
#                         'p10/p10005749/s57249718.txt',
#                         'p10/p10005749/s58865310.txt',
#                         'p18/p18017189/s59226684.txt',
#                         'p18/p18000379/s51568340.txt',
#                         'p18/p18000379/s51568340.txt']},
#  'aspect': {'normalization': None,
#             'reports': ['p15/p15165563/s54307084.txt',
#                         'p10/p10002428/s57887188.txt']},
#  'atrium': {'normalization': None,
#             'reports': ['p15/p15002183/s52341485.txt',
#                         'p18/p18022445/s56006486.txt',
#                         'p18/p18003894/s58777551.txt',
#                         'p18/p18003894/s58464660.txt',
#                         'p18/p18003894/s56064707.txt',
#                         'p18/p18028999/s57987829.txt',
#                         'p18/p18028999/s57987829.txt',
#                         'p18/p18028999/s57987829.txt',
#                         'p15/p15007517/s59740051.txt',
#                         'p15/p15009504/s55274948.txt',
#                         'p15/p15009504/s59292871.txt',
#                         'p15/p15009504/s51227163.txt',
#                         'p15/p15009504/s56362726.txt',
#                         'p15/p15009504/s54918382.txt',
#                         'p15/p15009504/s59050955.txt',
#                         'p18/p18017363/s53531162.txt',
#                         'p18/p18017363/s54401973.txt',
#                         'p18/p18017363/s55076850.txt',
#                         'p10/p10002428/s58851198.txt',
#                         'p18/p18006842/s54156702.txt',
#                         'p18/p18006842/s56350245.txt',
#                         'p18/p18006842/s59597753.txt']},
#  'axilla': {'normalization': None,
#             'reports': ['p10/p10002428/s59659695.txt',
#                         'p10/p10002428/s59659695.txt',
# ...
#                           'p15/p15078112/s55285875.txt',
#                           'p15/p15078112/s53834915.txt',
#                           'p15/p15078112/s56357121.txt',
#                           'p15/p15078112/s56357121.txt',
#                           'p15/p15078112/s59839693.txt',
#                           'p15/p15078112/s52859232.txt',
#                           'p15/p15003296/s58126961.txt',
#                           'p15/p15003296/s58126961.txt',
#                           'p15/p15003296/s52507068.txt',
#                           'p15/p15003296/s52507068.txt',
#                           'p15/p15003296/s55100464.txt',
#                           'p15/p15003296/s55162880.txt',
#                           'p15/p15003296/s58235657.txt',
#                           'p15/p15003296/s58235657.txt',
#                           'p18/p18022445/s51773947.txt',
#                           'p10/p10002804/s53422998.txt',
#                           'p15/p15002678/s50618143.txt',
#                           'p15/p15002678/s50618143.txt',
#                           'p10/p10003502/s57641661.txt',
#                           'p10/p10003502/s57641661.txt',
#                           'p10/p10003502/s53836463.txt',
#                           'p10/p10003502/s53282957.txt',
#                           'p18/p18020943/s55270846.txt',
#                           'p18/p18020943/s53949676.txt',
#                           'p18/p18020943/s57074556.txt',
#                           'p18/p18020943/s57074556.txt',
#                           'p18/p18022983/s52601618.txt',
#                           'p15/p15006483/s54362708.txt',
#                           'p18/p18000745/s59652189.txt',
#                           'p10/p10005866/s56175428.txt',
#                           'p10/p10005866/s56175428.txt',
#                           'p10/p10005866/s56175428.txt',
#                           'p15/p15007517/s50648100.txt',
#                           'p15/p15007517/s58608641.txt',
#                           'p15/p15003988/s50511251.txt',
#                           'p10/p10004235/s52379321.txt',
#                           'p10/p10004235/s52379321.txt',
#                           'p10/p10004235/s52379321.txt',
#                           'p10/p10004235/s52379321.txt',
#                           'p10/p10004235/s57318275.txt',
#                           'p10/p10004235/s57318275.txt',
#                           'p10/p10004235/s58604118.txt',
#                           'p10/p10004235/s59895508.txt',
#                           'p18/p18015004/s54721527.txt',
#                           'p10/p10003637/s57024735.txt',
#                           'p10/p10003019/s59829602.txt',
#                           'p10/p10003019/s59829602.txt',
#                           'p10/p10003019/s59829602.txt',
#                           'p10/p10003019/s59730608.txt',
#                           'p10/p10004322/s57662923.txt',
#                           'p18/p18017189/s54781713.txt',
#                           'p15/p15009233/s57256545.txt',
#                           'p15/p15009233/s57930478.txt',
#                           'p15/p15009233/s57930478.txt',
#                           'p15/p15009233/s58131029.txt',
#                           'p15/p15009233/s54889621.txt',
#                           'p10/p10002428/s59891001.txt',
#                           'p10/p10002428/s56100138.txt',
#                           'p10/p10002428/s57506266.txt',
#                           'p18/p18006842/s50471520.txt',
#                           'p18/p18006842/s56350245.txt',
#                           'p18/p18006842/s56350245.txt',
#                           'p18/p18006842/s56350245.txt',
#                           'p18/p18006842/s56350245.txt',
#                           'p15/p15002496/s50531159.txt',
#                           'p15/p15002496/s52886085.txt',
#                           'p15/p15002496/s55374744.txt',
#                           'p15/p15000485/s56074305.txt',
#                           'p18/p18000379/s51062789.txt',
#                           'p18/p18000379/s55748408.txt',
#                           'p10/p10002559/s59849480.txt',
#                           'p15/p15001834/s56269673.txt']},
#  'vascularity': {'normalization': None,
#                  'reports': ['p15/p15024484/s55357745.txt',
#                              'p18/p18026902/s57297476.txt',
#                              'p18/p18012427/s54748444.txt',
#                              'p15/p15009233/s54618867.txt']},
#  'vasculature': {'normalization': None,
#                  'reports': ['p18/p18004941/s58034164.txt',
#                              'p10/p10005749/s53170451.txt',
#                              'p10/p10005749/s53170451.txt',
#                              'p15/p15165563/s56337929.txt',
#                              'p15/p15165563/s59506127.txt',
#                              'p15/p15078112/s58166907.txt',
#                              'p15/p15078112/s58703686.txt',
#                              'p18/p18000735/s50785186.txt',
#                              'p18/p18019295/s57254021.txt',
#                              'p18/p18001942/s56433237.txt',
#                              'p15/p15002678/s56528605.txt',
#                              'p18/p18022983/s57985067.txt',
#                              'p18/p18022983/s57381264.txt',
#                              'p15/p15006483/s59006665.txt',
#                              'p10/p10003019/s59339276.txt',
#                              'p18/p18001157/s59771012.txt',
#                              'p10/p10002428/s58581921.txt',
#                              'p18/p18006842/s55078395.txt',
#                              'p18/p18006842/s56350245.txt',
#                              'p18/p18006842/s59597753.txt',
#                              'p15/p15001474/s51737379.txt',
#                              'p18/p18011616/s57021204.txt',
#                              'p18/p18011616/s56212412.txt',
#                              'p18/p18028180/s57844688.txt',
#                              'p18/p18028180/s57826518.txt',
#                              'p18/p18000379/s59391463.txt']},
#  'vein': {'normalization': None,
#           'reports': ['p18/p18020943/s57074556.txt',
#                       'p10/p10003019/s59607556.txt',
#                       'p10/p10002428/s52460896.txt',
#                       'p10/p10002428/s59258773.txt',
#                       'p10/p10002428/s58851198.txt',
#                       'p10/p10002428/s57506266.txt']},
#  'veins': {'normalization': None, 'reports': ['p15/p15078112/s58166907.txt']},
#  'venous': {'normalization': None,
#             'reports': ['p10/p10005749/s54040624.txt',
#                         'p15/p15004061/s56845046.txt',
#                         'p15/p15078112/s56357121.txt',
#                         'p15/p15078112/s56357121.txt',
#                         'p15/p15078112/s56357121.txt',
#                         'p15/p15078112/s56357121.txt',
#                         'p15/p15078112/s56824160.txt',
#                         'p15/p15002678/s53430015.txt',
#                         'p15/p15007517/s50648100.txt',
#                         'p15/p15007517/s51550673.txt',
#                         'p10/p10003637/s51371378.txt',
#                         'p18/p18017189/s59226684.txt',
#                         'p10/p10002428/s57887188.txt',
#                         'p10/p10002428/s50444997.txt']},
#  'ventricle': {'normalization': None,
#                'reports': ['p18/p18022445/s56006486.txt',
#                            'p18/p18017363/s53531162.txt',
#                            'p18/p18017363/s54401973.txt',
#                            'p18/p18017363/s55076850.txt',
#                            'p10/p10003637/s51461467.txt',
#                            'p10/p10003637/s57024735.txt',
#                            'p18/p18006842/s54156702.txt',
#                            'p18/p18006842/s54156702.txt',
#                            'p18/p18006842/s56350245.txt',
#                            'p18/p18006842/s59597753.txt',
#                            'p18/p18006842/s59597753.txt']},
#  'ventricular': {'normalization': None,
#                  'reports': ['p15/p15001136/s50077246.txt',
#                              'p18/p18001942/s56433237.txt',
#                              'p15/p15007517/s50648100.txt']},
#  'vertebral': {'normalization': None,
#                'reports': ['p18/p18001942/s56433237.txt',
#                            'p10/p10003019/s52117631.txt',
#                            'p10/p10003019/s52117631.txt',
#                            'p10/p10003019/s52117631.txt',
#                            'p10/p10003019/s58505074.txt',
#                            'p18/p18028180/s55973443.txt']},
#  'vessel': {'normalization': None,
#             'reports': ['p10/p10004235/s52379321.txt',
#                         'p10/p10004235/s52379321.txt']},
#  'vessels': {'normalization': None,
#              'reports': ['p15/p15002678/s53430015.txt',
#                          'p18/p18020943/s57074556.txt',
#                          'p10/p10003637/s51371378.txt',
#                          'p10/p10002428/s57887188.txt']},
#  'visualized': {'normalization': None,
#                 'reports': ['p18/p18017363/s55076850.txt']},
#  'volume': {'normalization': None,
#             'reports': ['p18/p18003081/s53302126.txt',
#                         'p15/p15004061/s50854153.txt',
#                         'p15/p15004061/s51985597.txt',
#                         'p15/p15004061/s50269894.txt',
#                         'p15/p15078112/s58166907.txt',
#                         'p15/p15078112/s52859232.txt',
#                         'p18/p18026902/s51741672.txt',
#                         'p18/p18022445/s55421520.txt',
#                         'p18/p18022445/s51773947.txt',
#                         'p15/p15007487/s57478149.txt',
#                         'p15/p15007487/s53221126.txt',
#                         'p10/p10003502/s53836463.txt',
#                         'p10/p10003502/s53836463.txt',
#                         'p18/p18028999/s57987829.txt',
#                         'p18/p18028999/s53725346.txt',
#                         'p10/p10003019/s58365492.txt',
#                         'p10/p10003019/s59829602.txt',
#                         'p10/p10003019/s59829602.txt',
#                         'p10/p10003019/s59635047.txt',
#                         'p15/p15009233/s54889621.txt',
#                         'p15/p15000393/s55843146.txt',
#                         'p15/p15000393/s52929930.txt',
#                         'p15/p15000393/s57099953.txt',
#                         'p10/p10002428/s57887188.txt',
#                         'p15/p15002496/s51438936.txt',
#                         'p18/p18017572/s54836720.txt']},
#  'volumes': {'normalization': None,
#              'reports': ['p18/p18004941/s52289350.txt',
#                          'p18/p18004941/s55576421.txt',
#                          'p18/p18003081/s57007000.txt',
#                          'p18/p18003081/s51239857.txt',
#                          'p18/p18003081/s51239857.txt',
#                          'p18/p18003081/s52648242.txt',
#                          'p18/p18003081/s55159460.txt',
#                          'p10/p10005749/s54060141.txt',
#                          'p18/p18023211/s58130107.txt',
#                          'p18/p18023211/s56555187.txt',
#                          'p15/p15165563/s53383993.txt',
#                          'p15/p15004061/s51985597.txt',
#                          'p15/p15078112/s53834915.txt',
#                          'p15/p15078112/s56882127.txt',
#                          'p18/p18026902/s55739083.txt',
#                          'p15/p15003296/s58126961.txt',
#                          'p15/p15003296/s58126961.txt',
#                          'p15/p15003296/s52507068.txt',
#                          'p15/p15003296/s52507068.txt',
#                          'p15/p15003296/s51554855.txt',
#                          'p15/p15003296/s55162880.txt',
#                          'p15/p15003296/s55162880.txt',
#                          'p15/p15003296/s51481960.txt',
#                          'p15/p15003296/s58235657.txt',
#                          'p15/p15003296/s58235657.txt',
#                          'p18/p18010079/s56436361.txt',
#                          'p15/p15002538/s51219765.txt',
#                          'p18/p18019295/s52492192.txt',
#                          'p15/p15002678/s54137434.txt',
#                          'p15/p15002678/s50618143.txt',
#                          'p18/p18022983/s51605945.txt',
#                          'p18/p18022983/s57985067.txt',
#                          'p18/p18022983/s57985067.txt',
#                          'p18/p18022983/s52601618.txt',
#                          'p18/p18022983/s57381264.txt',
#                          'p15/p15007517/s59740051.txt',
#                          'p10/p10003052/s58630288.txt',
#                          'p15/p15009504/s53368774.txt',
#                          'p18/p18017363/s54401973.txt',
#                          'p18/p18017363/s55076850.txt',
#                          'p10/p10005368/s56689183.txt',
#                          'p10/p10004235/s52379321.txt',
#                          'p10/p10004235/s52379321.txt',
#                          'p10/p10004235/s52379321.txt',
#                          'p10/p10004235/s52379321.txt',
#                          'p10/p10004235/s57318275.txt',
#                          'p18/p18015004/s57985812.txt',
#                          'p18/p18015004/s57985812.txt',
#                          'p18/p18015004/s52149254.txt',
#                          'p18/p18015004/s56533254.txt',
#                          'p18/p18015004/s56533254.txt',
#                          'p18/p18015004/s51210113.txt',
#                          'p18/p18015004/s51210113.txt',
#                          'p10/p10003637/s51371378.txt',
#                          'p10/p10003019/s59829602.txt',
#                          'p10/p10003019/s59829602.txt',
#                          'p10/p10003019/s59829602.txt',
#                          'p10/p10003019/s52117631.txt',
#                          'p10/p10003019/s59730608.txt',
#                          'p18/p18001157/s57119564.txt',
#                          'p15/p15009233/s57930478.txt',
#                          'p10/p10002428/s56100138.txt',
#                          'p18/p18006842/s55078395.txt',
#                          'p18/p18006842/s59597753.txt',
#                          'p18/p18011616/s59704184.txt',
#                          'p18/p18011616/s50686187.txt',
#                          'p10/p10002559/s52212843.txt',
#                          'p15/p15001203/s50723040.txt',
#                          'p15/p15001834/s58938701.txt']},
#  'wall': {'normalization': None,
#           'reports': ['p15/p15001136/s52592881.txt',
#                       'p15/p15165563/s54307084.txt',
#                       'p18/p18010079/s55080309.txt',
#                       'p15/p15007487/s54185768.txt',
#                       'p15/p15007487/s59034151.txt',
#                       'p15/p15007487/s52305139.txt',
#                       'p10/p10005368/s56689183.txt',
#                       'p10/p10003019/s58365492.txt',
#                       'p10/p10002428/s58581921.txt',
#                       'p18/p18006842/s50471520.txt',
#                       'p18/p18006842/s59597753.txt',
#                       'p18/p18011616/s59704184.txt',
#                       'p18/p18011616/s59704184.txt',
#                       'p18/p18028180/s57826518.txt',
#                       'p18/p18017572/s54836720.txt']},
#  'withdrawn 1 cm': {'normalization': None,
#                     'reports': ['p15/p15009504/s51227163.txt']},
#  'within': {'normalization': None,
#             'reports': ['p15/p15007487/s54185768.txt',
#                         'p10/p10007795/s54317369.txt',
#                         'p10/p10005866/s56175428.txt',
#                         'p10/p10005866/s56175428.txt']},
#  'zone': {'normalization': None,
#           'reports': ['p10/p10003502/s57812613.txt',
#                       'p10/p10005866/s56175428.txt',
#                       'p10/p10004235/s58604118.txt',
#                       'p18/p18003402/s52418327.txt',
#                       'p10/p10002428/s50444997.txt']}}
# Number of unique 'ANAT-DP' entities: 398
# All entities have been saved to 'all_entities.json'

# %% [markdown]
# ## 统计all_entities中每个entity出现的次数

# %%
from collections import Counter

def analyze_entity_frequency(all_entities):
    # Initialize a Counter to store entity frequencies
    entity_frequency = Counter()

    # Iterate through all labels and entities
    for label, entities in all_entities.items():
        for entity, document_keys in entities.items():
            # Count the number of documents for each entity
            entity_frequency[(entity, label)] += len(document_keys)

    # Print the results
    print("Entity Frequency Analysis:")
    for (entity, label), count in entity_frequency.most_common():
        print(f"Entity: '{entity}', Label: '{label}', Frequency: {count}")

    # Optional: Return the Counter object for further analysis if needed
    return entity_frequency

# Assuming all_entities is already defined and populated
analyze_entity_frequency(all_entities)
# Out:
# Entity Frequency Analysis:
# Entity: 'pleural', Label: 'ANAT-DP', Frequency: 316
# Entity: 'pneumothorax', Label: 'OBS-DA', Frequency: 239
# Entity: 'right', Label: 'ANAT-DP', Frequency: 211
# Entity: 'left', Label: 'ANAT-DP', Frequency: 191
# Entity: 'pulmonary', Label: 'ANAT-DP', Frequency: 176
# Entity: 'effusion', Label: 'OBS-DA', Frequency: 163
# Entity: 'normal', Label: 'OBS-DP', Frequency: 142
# Entity: 'unchanged', Label: 'OBS-DP', Frequency: 137
# Entity: 'lung', Label: 'ANAT-DP', Frequency: 124
# Entity: 'silhouette', Label: 'ANAT-DP', Frequency: 120
# Entity: 'size', Label: 'ANAT-DP', Frequency: 116
# Entity: 'atelectasis', Label: 'OBS-DP', Frequency: 110
# Entity: 'contours', Label: 'ANAT-DP', Frequency: 104
# Entity: 'lungs', Label: 'ANAT-DP', Frequency: 96
# Entity: 'clear', Label: 'OBS-DP', Frequency: 96
# Entity: 'consolidation', Label: 'OBS-DA', Frequency: 96
# Entity: 'acute', Label: 'OBS-DA', Frequency: 95
# Entity: 'mediastinal', Label: 'ANAT-DP', Frequency: 87
# Entity: 'focal', Label: 'OBS-DA', Frequency: 86
# Entity: 'lower', Label: 'ANAT-DP', Frequency: 82
# Entity: 'stable', Label: 'OBS-DP', Frequency: 81
# Entity: 'effusion', Label: 'OBS-DP', Frequency: 78
# Entity: 'tube', Label: 'OBS-DP', Frequency: 73
# Entity: 'cardiac', Label: 'ANAT-DP', Frequency: 71
# Entity: 'opacity', Label: 'OBS-DP', Frequency: 70
# Entity: 'small', Label: 'OBS-DP', Frequency: 70
# Entity: 'effusions', Label: 'OBS-DP', Frequency: 68
# Entity: 'lobe', Label: 'ANAT-DP', Frequency: 67
# Entity: 'hilar', Label: 'ANAT-DP', Frequency: 65
# Entity: 'heart', Label: 'ANAT-DP', Frequency: 63
# Entity: 'mild', Label: 'OBS-DP', Frequency: 63
# Entity: 'bilateral', Label: 'ANAT-DP', Frequency: 62
# Entity: 'edema', Label: 'OBS-DP', Frequency: 62
# Entity: 'Heart', Label: 'ANAT-DP', Frequency: 61
# Entity: 'vascular', Label: 'ANAT-DP', Frequency: 61
# Entity: 'moderate', Label: 'OBS-DP', Frequency: 58
# Entity: 'upper', Label: 'ANAT-DP', Frequency: 57
# Entity: 'pneumonia', Label: 'OBS-DA', Frequency: 57
# Entity: 'edema', Label: 'OBS-DA', Frequency: 56
# Entity: 'volumes', Label: 'ANAT-DP', Frequency: 55
# Entity: 'cardiomediastinal', Label: 'ANAT-DP', Frequency: 54
# Entity: 'tip', Label: 'OBS-DP', Frequency: 52
# Entity: 'cardiomegaly', Label: 'OBS-DP', Frequency: 52
# Entity: 'chest', Label: 'ANAT-DP', Frequency: 49
# Entity: 'Mild', Label: 'OBS-DP', Frequency: 49
# Entity: 'process', Label: 'OBS-DA', Frequency: 49
# Entity: 'cardiopulmonary', Label: 'ANAT-DP', Frequency: 48
# Entity: 'enlarged', Label: 'OBS-DP', Frequency: 46
# Entity: 'mid', Label: 'ANAT-DP', Frequency: 45
# Entity: 'Right', Label: 'ANAT-DP', Frequency: 45
# Entity: 'atelectasis', Label: 'OBS-U', Frequency: 43
# Entity: 'increased', Label: 'OBS-DP', Frequency: 42
# Entity: 'Left', Label: 'ANAT-DP', Frequency: 41
# Entity: 'opacities', Label: 'OBS-DP', Frequency: 41
# Entity: 'Cardiac', Label: 'ANAT-DP', Frequency: 39
# Entity: 'unremarkable', Label: 'OBS-DP', Frequency: 38
# Entity: 'low', Label: 'OBS-DP', Frequency: 38
# Entity: 'Moderate', Label: 'OBS-DP', Frequency: 38
# Entity: 'line', Label: 'OBS-DP', Frequency: 38
# Entity: 'osseous', Label: 'ANAT-DP', Frequency: 37
# Entity: 'base', Label: 'ANAT-DP', Frequency: 37
# Entity: 'pneumonia', Label: 'OBS-U', Frequency: 37
# Entity: 'interstitial', Label: 'ANAT-DP', Frequency: 36
# Entity: 'bibasilar', Label: 'ANAT-DP', Frequency: 34
# Entity: 'position', Label: 'OBS-DP', Frequency: 34
# Entity: 'congestion', Label: 'OBS-DP', Frequency: 34
# Entity: 'structures', Label: 'ANAT-DP', Frequency: 32
# Entity: 'hemidiaphragm', Label: 'ANAT-DP', Frequency: 32
# Entity: 'stomach', Label: 'ANAT-DP', Frequency: 31
# Entity: 'retrocardiac', Label: 'ANAT-DP', Frequency: 31
# Entity: 'apical', Label: 'ANAT-DP', Frequency: 31
# Entity: 'rib', Label: 'ANAT-DP', Frequency: 30
# Entity: 'Cardiomediastinal', Label: 'ANAT-DP', Frequency: 30
# Entity: 'basilar', Label: 'ANAT-DP', Frequency: 30
# Entity: 'slightly', Label: 'OBS-DP', Frequency: 30
# Entity: 'limits', Label: 'OBS-DP', Frequency: 30
# Entity: 'pneumothorax', Label: 'OBS-DP', Frequency: 30
# Entity: 'thoracic', Label: 'ANAT-DP', Frequency: 29
# Entity: 'Small', Label: 'OBS-DP', Frequency: 29
# Entity: 'new', Label: 'OBS-DP', Frequency: 29
# Entity: 'effusions', Label: 'OBS-DA', Frequency: 29
# Entity: 'SVC', Label: 'ANAT-DP', Frequency: 28
# Entity: 'catheter', Label: 'OBS-DP', Frequency: 28
# Entity: 'Lungs', Label: 'ANAT-DP', Frequency: 25
# Entity: 'vasculature', Label: 'ANAT-DP', Frequency: 25
# Entity: 'improved', Label: 'OBS-DP', Frequency: 25
# Entity: 'abnormalities', Label: 'OBS-DA', Frequency: 25
# Entity: 'effusion', Label: 'OBS-U', Frequency: 25
# Entity: 'volume', Label: 'ANAT-DP', Frequency: 24
# Entity: 'aorta', Label: 'ANAT-DP', Frequency: 24
# Entity: 'mildly', Label: 'OBS-DP', Frequency: 24
# Entity: 'small', Label: 'OBS-U', Frequency: 24
# Entity: 'mediastinum', Label: 'ANAT-DP', Frequency: 23
# Entity: 'Bilateral', Label: 'ANAT-DP', Frequency: 23
# Entity: 'within', Label: 'OBS-DP', Frequency: 23
# Entity: 'enlargement', Label: 'OBS-DP', Frequency: 22
# Entity: 'PICC', Label: 'OBS-DP', Frequency: 22
# Entity: 'carina', Label: 'ANAT-DP', Frequency: 21
# Entity: 'spine', Label: 'ANAT-DP', Frequency: 21
# Entity: 'infection', Label: 'OBS-U', Frequency: 21
# Entity: 'bases', Label: 'ANAT-DP', Frequency: 20
# Entity: 'atrium', Label: 'ANAT-DP', Frequency: 20
# Entity: 'intact', Label: 'OBS-DP', Frequency: 20
# Entity: 'abnormality', Label: 'OBS-DA', Frequency: 20
# Entity: 'silhouettes', Label: 'ANAT-DP', Frequency: 19
# Entity: 'Pulmonary', Label: 'ANAT-DP', Frequency: 19
# Entity: 'Lung', Label: 'ANAT-DP', Frequency: 19
# Entity: 'Mediastinal', Label: 'ANAT-DP', Frequency: 19
# Entity: 'ET', Label: 'OBS-DP', Frequency: 19
# Entity: 'clips', Label: 'OBS-DP', Frequency: 19
# Entity: 'edema', Label: 'OBS-U', Frequency: 19
# Entity: 'opacification', Label: 'OBS-DP', Frequency: 18
# Entity: 'scarring', Label: 'OBS-DP', Frequency: 18
# Entity: 'new', Label: 'OBS-DA', Frequency: 18
# Entity: 'basal', Label: 'ANAT-DP', Frequency: 17
# Entity: 'loss', Label: 'OBS-DP', Frequency: 17
# Entity: 'decreased', Label: 'OBS-DP', Frequency: 17
# Entity: 'in place', Label: 'OBS-DP', Frequency: 17
# Entity: 'congestion', Label: 'OBS-DA', Frequency: 17
# Entity: 'Bibasilar', Label: 'ANAT-DP', Frequency: 16
# Entity: 'subclavian', Label: 'ANAT-DP', Frequency: 16
# Entity: 'Unchanged', Label: 'OBS-DP', Frequency: 16
# Entity: 'linear', Label: 'OBS-DP', Frequency: 16
# Entity: 'changes', Label: 'OBS-DP', Frequency: 16
# Entity: 'fluid', Label: 'OBS-DP', Frequency: 16
# Entity: 'minimal', Label: 'OBS-DP', Frequency: 15
# Entity: 'Minimal', Label: 'OBS-DP', Frequency: 15
# Entity: 'New', Label: 'OBS-DP', Frequency: 15
# Entity: 'size', Label: 'OBS-DP', Frequency: 15
# Entity: 'increase', Label: 'OBS-DP', Frequency: 15
# Entity: 'Stable', Label: 'OBS-DP', Frequency: 15
# Entity: 'hyperinflated', Label: 'OBS-DP', Frequency: 15
# Entity: 'large', Label: 'OBS-DA', Frequency: 15
# Entity: 'parenchymal', Label: 'ANAT-DP', Frequency: 14
# Entity: 'wall', Label: 'ANAT-DP', Frequency: 14
# Entity: 'subcutaneous', Label: 'ANAT-DP', Frequency: 14
# Entity: 'layering', Label: 'OBS-DP', Frequency: 14
# Entity: 'well', Label: 'OBS-DP', Frequency: 14
# Entity: 'interval', Label: 'OBS-DP', Frequency: 14
# Entity: 'consolidation', Label: 'OBS-DP', Frequency: 14
# Entity: 'severe', Label: 'OBS-DP', Frequency: 14
# Entity: 'change', Label: 'OBS-DA', Frequency: 14
# Entity: 'apex', Label: 'ANAT-DP', Frequency: 13
# Entity: 'right - sided', Label: 'ANAT-DP', Frequency: 13
# Entity: 'quadrant', Label: 'ANAT-DP', Frequency: 13
# Entity: 'airspace', Label: 'ANAT-DP', Frequency: 13
# Entity: 'below', Label: 'ANAT-DP', Frequency: 13
# Entity: 'central', Label: 'ANAT-DP', Frequency: 13
# Entity: 'fractures', Label: 'OBS-DP', Frequency: 13
# Entity: 'pneumonia', Label: 'OBS-DP', Frequency: 13
# Entity: 'compressive', Label: 'OBS-DP', Frequency: 13
# Entity: 'prominent', Label: 'OBS-DP', Frequency: 13
# Entity: 'post', Label: 'OBS-DP', Frequency: 13
# Entity: 'markings', Label: 'OBS-DP', Frequency: 13
# Entity: 'devices', Label: 'OBS-DP', Frequency: 13
# Entity: 'expanded', Label: 'OBS-DP', Frequency: 13
# Entity: 'tube', Label: 'OBS-DA', Frequency: 13
# Entity: 'aspiration', Label: 'OBS-U', Frequency: 13
# Entity: 'NG', Label: 'OBS-DP', Frequency: 12
# Entity: 'Low', Label: 'OBS-DP', Frequency: 12
# Entity: 'substantial', Label: 'OBS-DP', Frequency: 12
# Entity: 'prominence', Label: 'OBS-DP', Frequency: 12
# Entity: 'standard', Label: 'OBS-DP', Frequency: 12
# Entity: 'chronic', Label: 'OBS-DP', Frequency: 12
# Entity: 'top', Label: 'OBS-DP', Frequency: 12
# Entity: 'greater', Label: 'OBS-DP', Frequency: 12
# Entity: 'diffuse', Label: 'OBS-DP', Frequency: 12
# Entity: 'Increased', Label: 'OBS-DP', Frequency: 12
# Entity: 'Surgical', Label: 'OBS-DP', Frequency: 12
# Entity: 'lead', Label: 'OBS-DP', Frequency: 12
# Entity: 'improvement', Label: 'OBS-DP', Frequency: 12
# Entity: 'emphysema', Label: 'OBS-DP', Frequency: 12
# Entity: 'worsening', Label: 'OBS-DP', Frequency: 12
# Entity: 'consolidation', Label: 'OBS-U', Frequency: 12
# Entity: 'distal', Label: 'ANAT-DP', Frequency: 11
# Entity: 'junction', Label: 'ANAT-DP', Frequency: 11
# Entity: 'venous', Label: 'ANAT-DP', Frequency: 11
# Entity: 'bilaterally', Label: 'ANAT-DP', Frequency: 11
# Entity: 'IJ', Label: 'ANAT-DP', Frequency: 11
# Entity: 'left - sided', Label: 'ANAT-DP', Frequency: 11
# Entity: 'Normal', Label: 'OBS-DP', Frequency: 11
# Entity: 'Endotracheal', Label: 'OBS-DP', Frequency: 11
# Entity: 'obscured', Label: 'OBS-DP', Frequency: 11
# Entity: 'endotracheal', Label: 'OBS-DP', Frequency: 11
# Entity: 'change', Label: 'OBS-DP', Frequency: 11
# Entity: 'enteric', Label: 'OBS-DP', Frequency: 11
# Entity: 'crowding', Label: 'OBS-DP', Frequency: 11
# Entity: 'scoliosis', Label: 'OBS-DP', Frequency: 11
# Entity: 'overlying', Label: 'OBS-DP', Frequency: 11
# Entity: 'wires', Label: 'OBS-DP', Frequency: 11
# Entity: 'thickening', Label: 'OBS-DP', Frequency: 11
# Entity: 'elevation', Label: 'OBS-DP', Frequency: 11
# Entity: 'support', Label: 'OBS-DP', Frequency: 11
# Entity: 'tortuous', Label: 'OBS-DP', Frequency: 11
# Entity: 'leads', Label: 'OBS-DP', Frequency: 11
# Entity: 'large', Label: 'OBS-DP', Frequency: 11
# Entity: 'tubes', Label: 'OBS-DP', Frequency: 11
# Entity: 'mild', Label: 'OBS-U', Frequency: 11
# Entity: 'infectious', Label: 'OBS-U', Frequency: 11
# Entity: 'bronchovascular', Label: 'ANAT-DP', Frequency: 10
# Entity: 'costophrenic', Label: 'ANAT-DP', Frequency: 10
# Entity: 'lateral', Label: 'ANAT-DP', Frequency: 10
# Entity: 'abdomen', Label: 'ANAT-DP', Frequency: 10
# Entity: 'intrathoracic', Label: 'ANAT-DP', Frequency: 10
# Entity: 'perihilar', Label: 'ANAT-DP', Frequency: 10
# Entity: 'Retrocardiac', Label: 'ANAT-DP', Frequency: 10
# Entity: 'region', Label: 'ANAT-DP', Frequency: 10
# Entity: 'grossly', Label: 'OBS-DP', Frequency: 10
# Entity: 'Severe', Label: 'OBS-DP', Frequency: 10
# Entity: 'sternotomy', Label: 'OBS-DP', Frequency: 10
# Entity: 'calcifications', Label: 'OBS-DP', Frequency: 10
# Entity: 'moderately', Label: 'OBS-DP', Frequency: 10
# Entity: 'air', Label: 'OBS-DP', Frequency: 10
# Entity: 'sutures', Label: 'OBS-DP', Frequency: 10
# Entity: 'overt', Label: 'OBS-DA', Frequency: 10
# Entity: 'air', Label: 'OBS-DA', Frequency: 10
# Entity: 'effusions', Label: 'OBS-U', Frequency: 10
# Entity: 'angle', Label: 'ANAT-DP', Frequency: 9
# Entity: 'both', Label: 'ANAT-DP', Frequency: 9
# Entity: 'ventricle', Label: 'ANAT-DP', Frequency: 9
# Entity: 'middle', Label: 'ANAT-DP', Frequency: 9
# Entity: 'little', Label: 'OBS-DP', Frequency: 9
# Entity: 'decrease', Label: 'OBS-DP', Frequency: 9
# Entity: 'overload', Label: 'OBS-DP', Frequency: 9
# Entity: 'slight', Label: 'OBS-DP', Frequency: 9
# Entity: 'upper', Label: 'OBS-DP', Frequency: 9
# Entity: 'postoperative', Label: 'OBS-DP', Frequency: 9
# Entity: 'free', Label: 'OBS-DA', Frequency: 9
# Entity: 'pneumothoraces', Label: 'OBS-DA', Frequency: 9
# Entity: 'surfaces', Label: 'ANAT-DP', Frequency: 8
# Entity: 'proximal', Label: 'ANAT-DP', Frequency: 8
# Entity: 'contour', Label: 'ANAT-DP', Frequency: 8
# Entity: 'jugular', Label: 'ANAT-DP', Frequency: 8
# Entity: 'aortic', Label: 'ANAT-DP', Frequency: 8
# Entity: 'neck', Label: 'ANAT-DP', Frequency: 8
# Entity: 'hemithorax', Label: 'ANAT-DP', Frequency: 8
# Entity: 'more', Label: 'OBS-DP', Frequency: 8
# Entity: 'worse', Label: 'OBS-DP', Frequency: 8
# Entity: 'device', Label: 'OBS-DP', Frequency: 8
# Entity: 'median', Label: 'OBS-DP', Frequency: 8
# Entity: 'disease', Label: 'OBS-DP', Frequency: 8
# Entity: 'degenerative', Label: 'OBS-DP', Frequency: 8
# Entity: 'surgical', Label: 'OBS-DP', Frequency: 8
# Entity: 'amount', Label: 'OBS-DP', Frequency: 8
# Entity: 'distal', Label: 'OBS-DP', Frequency: 8
# Entity: 'pacer', Label: 'OBS-DP', Frequency: 8
# Entity: 'fractures', Label: 'OBS-DA', Frequency: 8
# Entity: 'opacity', Label: 'OBS-DA', Frequency: 8
# Entity: 'hemorrhage', Label: 'OBS-U', Frequency: 8
# Entity: 'esophagus', Label: 'ANAT-DP', Frequency: 7
# Entity: 'Bony', Label: 'ANAT-DP', Frequency: 7
# Entity: 'posterior', Label: 'ANAT-DP', Frequency: 7
# Entity: 'diaphragm', Label: 'ANAT-DP', Frequency: 7
# Entity: 'Biapical', Label: 'ANAT-DP', Frequency: 7
# Entity: 'Upper', Label: 'ANAT-DP', Frequency: 7
# Entity: 'nasogastric', Label: 'OBS-DP', Frequency: 7
# Entity: 'similar', Label: 'OBS-DP', Frequency: 7
# Entity: 'larger', Label: 'OBS-DP', Frequency: 7
# Entity: 'Multiple', Label: 'OBS-DP', Frequency: 7
# Entity: 'fracture', Label: 'OBS-DP', Frequency: 7
# Entity: 'Interval', Label: 'OBS-DP', Frequency: 7
# Entity: 'extensive', Label: 'OBS-DP', Frequency: 7
# Entity: 'status', Label: 'OBS-DP', Frequency: 7
# Entity: 'monitoring', Label: 'OBS-DP', Frequency: 7
# Entity: 'Linear', Label: 'OBS-DP', Frequency: 7
# Entity: 'some', Label: 'OBS-DP', Frequency: 7
# Entity: 'Extensive', Label: 'OBS-DP', Frequency: 7
# Entity: 'Large', Label: 'OBS-DP', Frequency: 7
# Entity: 'central', Label: 'OBS-DP', Frequency: 7
# Entity: 'Dobbhoff', Label: 'OBS-DP', Frequency: 7
# Entity: 'displaced', Label: 'OBS-DA', Frequency: 7
# Entity: 'chronic', Label: 'OBS-U', Frequency: 7
# Entity: 'pneumothorax', Label: 'OBS-U', Frequency: 7
# Entity: 'border', Label: 'ANAT-DP', Frequency: 6
# Entity: 'adjacent', Label: 'ANAT-DP', Frequency: 6
# Entity: 'diaphragms', Label: 'ANAT-DP', Frequency: 6
# Entity: 'descending', Label: 'ANAT-DP', Frequency: 6
# Entity: 'hila', Label: 'ANAT-DP', Frequency: 6
# Entity: 'fissure', Label: 'ANAT-DP', Frequency: 6
# Entity: 'arch', Label: 'ANAT-DP', Frequency: 6
# Entity: 'vein', Label: 'ANAT-DP', Frequency: 6
# Entity: 'Pleural', Label: 'ANAT-DP', Frequency: 6
# Entity: 'arteries', Label: 'ANAT-DP', Frequency: 6
# Entity: 'Hilar', Label: 'ANAT-DP', Frequency: 6
# Entity: 'engorgement', Label: 'OBS-DP', Frequency: 6
# Entity: 'Nasogastric', Label: 'OBS-DP', Frequency: 6
# Entity: 'multiple', Label: 'OBS-DP', Frequency: 6
# Entity: 'deformities', Label: 'OBS-DP', Frequency: 6
# Entity: 'tortuosity', Label: 'OBS-DP', Frequency: 6
# Entity: 'blunting', Label: 'OBS-DP', Frequency: 6
# Entity: 'subtle', Label: 'OBS-DP', Frequency: 6
# Entity: 'otherwise', Label: 'OBS-DP', Frequency: 6
# Entity: 'Cardiomegaly', Label: 'OBS-DP', Frequency: 6
# Entity: 'Diffuse', Label: 'OBS-DP', Frequency: 6
# Entity: 'dense', Label: 'OBS-DP', Frequency: 6
# Entity: 'essentially', Label: 'OBS-DP', Frequency: 6
# Entity: 'hazy', Label: 'OBS-DP', Frequency: 6
# Entity: 'well - expanded', Label: 'OBS-DP', Frequency: 6
# Entity: 'chest', Label: 'OBS-DP', Frequency: 6
# Entity: 'pneumomediastinum', Label: 'OBS-DP', Frequency: 6
# Entity: 'drain', Label: 'OBS-DP', Frequency: 6
# Entity: 'A', Label: 'OBS-DP', Frequency: 6
# Entity: 'infiltrate', Label: 'OBS-DP', Frequency: 6
# Entity: 'feeding', Label: 'OBS-DP', Frequency: 6
# Entity: 'nodular', Label: 'OBS-DP', Frequency: 6
# Entity: 'chain', Label: 'OBS-DP', Frequency: 6
# Entity: 'opacities', Label: 'OBS-DA', Frequency: 6
# Entity: 'superimposed', Label: 'OBS-U', Frequency: 6
# Entity: 'focal', Label: 'OBS-U', Frequency: 6
# Entity: 'portion', Label: 'ANAT-DP', Frequency: 5
# Entity: 'Osseous', Label: 'ANAT-DP', Frequency: 5
# Entity: 'sternal', Label: 'ANAT-DP', Frequency: 5
# Entity: 'artery', Label: 'ANAT-DP', Frequency: 5
# Entity: 'valve', Label: 'ANAT-DP', Frequency: 5
# Entity: 'pericardial', Label: 'ANAT-DP', Frequency: 5
# Entity: 'hilus', Label: 'ANAT-DP', Frequency: 5
# Entity: 'lobar', Label: 'ANAT-DP', Frequency: 5
# Entity: 'hemidiaphragms', Label: 'ANAT-DP', Frequency: 5
# Entity: 'low', Label: 'ANAT-DP', Frequency: 5
# Entity: 'internal', Label: 'ANAT-DP', Frequency: 5
# Entity: 'trachea', Label: 'ANAT-DP', Frequency: 5
# Entity: 'anterior', Label: 'ANAT-DP', Frequency: 5
# Entity: 'medial', Label: 'ANAT-DP', Frequency: 5
# Entity: 'zone', Label: 'ANAT-DP', Frequency: 5
# Entity: 'alveolar', Label: 'ANAT-DP', Frequency: 5
# Entity: 'midline', Label: 'ANAT-DP', Frequency: 5
# Entity: 'fundus', Label: 'ANAT-DP', Frequency: 5
# Entity: 'appropriate', Label: 'OBS-DP', Frequency: 5
# Entity: 'This', Label: 'OBS-DP', Frequency: 5
# Entity: 'Mildly', Label: 'OBS-DP', Frequency: 5
# Entity: 'overall', Label: 'OBS-DP', Frequency: 5
# Entity: 'obscuring', Label: 'OBS-DP', Frequency: 5
# Entity: 'pressure', Label: 'OBS-DP', Frequency: 5
# Entity: 'relatively', Label: 'OBS-DP', Frequency: 5
# Entity: 'Slight', Label: 'OBS-DP', Frequency: 5
# Entity: 'focal', Label: 'OBS-DP', Frequency: 5
# Entity: 'calcified', Label: 'OBS-DP', Frequency: 5
# Entity: 'confluent', Label: 'OBS-DP', Frequency: 5
# Entity: 'CABG', Label: 'OBS-DP', Frequency: 5
# Entity: 'borderline', Label: 'OBS-DP', Frequency: 5
# Entity: 'nodules', Label: 'OBS-DP', Frequency: 5
# Entity: 'redistribution', Label: 'OBS-DP', Frequency: 5
# Entity: 'IJ', Label: 'OBS-DP', Frequency: 5
# Entity: 'worsened', Label: 'OBS-DP', Frequency: 5
# Entity: 'residual', Label: 'OBS-DP', Frequency: 5
# Entity: 'compression', Label: 'OBS-DP', Frequency: 5
# Entity: 'progression', Label: 'OBS-DP', Frequency: 5
# Entity: 'hardware', Label: 'OBS-DP', Frequency: 5
# Entity: 'density', Label: 'OBS-DP', Frequency: 5
# Entity: 'disease', Label: 'OBS-DA', Frequency: 5
# Entity: 'larger', Label: 'OBS-DA', Frequency: 5
# Entity: 'catheter', Label: 'OBS-DA', Frequency: 5
# Entity: 'infection', Label: 'OBS-DA', Frequency: 5
# Entity: 'scarring', Label: 'OBS-U', Frequency: 5
# Entity: 'process', Label: 'OBS-U', Frequency: 5
# Entity: 'fluid', Label: 'OBS-U', Frequency: 5
# Entity: 'underlying', Label: 'OBS-U', Frequency: 5
# Entity: 'near', Label: 'ANAT-DP', Frequency: 4
# Entity: 'vascularity', Label: 'ANAT-DP', Frequency: 4
# Entity: 'ribs', Label: 'ANAT-DP', Frequency: 4
# Entity: 'Left - sided', Label: 'ANAT-DP', Frequency: 4
# Entity: 'superior', Label: 'ANAT-DP', Frequency: 4
# Entity: 'cavoatrial', Label: 'ANAT-DP', Frequency: 4
# Entity: 'clavicle', Label: 'ANAT-DP', Frequency: 4
# Entity: 'vertebral', Label: 'ANAT-DP', Frequency: 4
# Entity: 'bodies', Label: 'ANAT-DP', Frequency: 4
# Entity: 'thoracolumbar', Label: 'ANAT-DP', Frequency: 4
# Entity: 'vessels', Label: 'ANAT-DP', Frequency: 4
# Entity: 'lumbar', Label: 'ANAT-DP', Frequency: 4
# Entity: 'periphery', Label: 'ANAT-DP', Frequency: 4
# Entity: 'suprahilar', Label: 'ANAT-DP', Frequency: 4
# Entity: 'Enteric', Label: 'OBS-DP', Frequency: 4
# Entity: 'positioning', Label: 'OBS-DP', Frequency: 4
# Entity: 'Borderline', Label: 'OBS-DP', Frequency: 4
# Entity: 'appearance', Label: 'OBS-DP', Frequency: 4
# Entity: 'findings', Label: 'OBS-DP', Frequency: 4
# Entity: 'consolidations', Label: 'OBS-DP', Frequency: 4
# Entity: 'loculated', Label: 'OBS-DP', Frequency: 4
# Entity: 'areas', Label: 'OBS-DP', Frequency: 4
# Entity: 'elevated', Label: 'OBS-DP', Frequency: 4
# Entity: 'resolution', Label: 'OBS-DP', Frequency: 4
# Entity: 'Degenerative', Label: 'OBS-DP', Frequency: 4
# Entity: 'COPD', Label: 'OBS-DP', Frequency: 4
# Entity: 'multilevel', Label: 'OBS-DP', Frequency: 4
# Entity: 'port', Label: 'OBS-DP', Frequency: 4
# Entity: 'calcification', Label: 'OBS-DP', Frequency: 4
# Entity: 'placement', Label: 'OBS-DP', Frequency: 4
# Entity: 'minimally', Label: 'OBS-DP', Frequency: 4
# Entity: 'tips', Label: 'OBS-DP', Frequency: 4
# Entity: 'less', Label: 'OBS-DP', Frequency: 4
# Entity: 'pneumopericardium', Label: 'OBS-DP', Frequency: 4
# Entity: 'tiny', Label: 'OBS-DP', Frequency: 4
# Entity: 'area', Label: 'OBS-DP', Frequency: 4
# Entity: 'diameter', Label: 'OBS-DP', Frequency: 4
# Entity: 'lines', Label: 'OBS-DP', Frequency: 4
# Entity: 'Lines', Label: 'OBS-DP', Frequency: 4
# Entity: 'indistinctness', Label: 'OBS-DP', Frequency: 4
# Entity: 'Subtle', Label: 'OBS-DP', Frequency: 4
# Entity: 'patient', Label: 'OBS-DP', Frequency: 4
# Entity: 'adenopathy', Label: 'OBS-DP', Frequency: 4
# Entity: 'Worsening', Label: 'OBS-DP', Frequency: 4
# Entity: 'AICD', Label: 'OBS-DP', Frequency: 4
# Entity: 'Chain', Label: 'OBS-DP', Frequency: 4
# Entity: 'smaller', Label: 'OBS-DP', Frequency: 4
# Entity: 'CHF', Label: 'OBS-DA', Frequency: 4
# Entity: 'changed', Label: 'OBS-DA', Frequency: 4
# Entity: 'nasogastric', Label: 'OBS-DA', Frequency: 4
# Entity: 'enlarged', Label: 'OBS-DA', Frequency: 4
# Entity: 'consolidations', Label: 'OBS-DA', Frequency: 4
# Entity: 'pneumomediastinum', Label: 'OBS-DA', Frequency: 4
# Entity: 'malignancy', Label: 'OBS-DA', Frequency: 4
# Entity: 'shift', Label: 'OBS-DA', Frequency: 4
# Entity: 'tension', Label: 'OBS-DA', Frequency: 4
# Entity: 'interval', Label: 'OBS-DA', Frequency: 4
# Entity: 'other', Label: 'OBS-DA', Frequency: 4
# Entity: 'significant', Label: 'OBS-DA', Frequency: 4
# Entity: 'early', Label: 'OBS-U', Frequency: 4
# Entity: 'disease', Label: 'OBS-U', Frequency: 4
# Entity: 'congestion', Label: 'OBS-U', Frequency: 4
# Entity: 'thickening', Label: 'OBS-U', Frequency: 4
# Entity: 'body', Label: 'ANAT-DP', Frequency: 3
# Entity: 'esophagogastric', Label: 'ANAT-DP', Frequency: 3
# Entity: 'main', Label: 'ANAT-DP', Frequency: 3
# Entity: 'right sided', Label: 'ANAT-DP', Frequency: 3
# Entity: 'second', Label: 'ANAT-DP', Frequency: 3
# Entity: 'fourth', Label: 'ANAT-DP', Frequency: 3
# Entity: 'margin', Label: 'ANAT-DP', Frequency: 3
# Entity: 'ventricular', Label: 'ANAT-DP', Frequency: 3
# Entity: 'major', Label: 'ANAT-DP', Frequency: 3
# Entity: 'Right - sided', Label: 'ANAT-DP', Frequency: 3
# Entity: 'cavoatrial junction', Label: 'ANAT-DP', Frequency: 3
# Entity: 'position', Label: 'ANAT-DP', Frequency: 3
# Entity: 'paratracheal', Label: 'ANAT-DP', Frequency: 3
# Entity: 'axillary', Label: 'ANAT-DP', Frequency: 3
# Entity: 'beneath', Label: 'ANAT-DP', Frequency: 3
# Entity: 'eighth', Label: 'ANAT-DP', Frequency: 3
# Entity: 'Subcutaneous', Label: 'ANAT-DP', Frequency: 3
# Entity: 'within', Label: 'ANAT-DP', Frequency: 3
# Entity: 'soft tissues', Label: 'ANAT-DP', Frequency: 3
# Entity: 'sinus', Label: 'ANAT-DP', Frequency: 3
# Entity: 'minor', Label: 'ANAT-DP', Frequency: 3
# Entity: 'right side', Label: 'ANAT-DP', Frequency: 3
# Entity: 'soft tissue', Label: 'ANAT-DP', Frequency: 3
# Entity: 'Vertebral', Label: 'ANAT-DP', Frequency: 3
# Entity: 'patchy', Label: 'OBS-DP', Frequency: 3
# Entity: 'Patchy', Label: 'OBS-DP', Frequency: 3
# Entity: 'asymmetry', Label: 'OBS-DP', Frequency: 3
# Entity: 'largely', Label: 'OBS-DP', Frequency: 3
# Entity: 'cannot be assessed', Label: 'OBS-DP', Frequency: 3
# Entity: 'significant', Label: 'OBS-DP', Frequency: 3
# Entity: 'unfolded', Label: 'OBS-DP', Frequency: 3
# Entity: 'partially', Label: 'OBS-DP', Frequency: 3
# Entity: 'sharply', Label: 'OBS-DP', Frequency: 3
# Entity: 'top - normal', Label: 'OBS-DP', Frequency: 3
# Entity: 'Massive', Label: 'OBS-DP', Frequency: 3
# Entity: 'resolved', Label: 'OBS-DP', Frequency: 3
# Entity: 'aeration', Label: 'OBS-DP', Frequency: 3
# Entity: 'similar to prior', Label: 'OBS-DP', Frequency: 3
# Entity: 'Sternotomy', Label: 'OBS-DP', Frequency: 3
# Entity: 'along', Label: 'OBS-DP', Frequency: 3
# Entity: 'flattening', Label: 'OBS-DP', Frequency: 3
# Entity: 'secondary', Label: 'OBS-DP', Frequency: 3
# Entity: 'in position', Label: 'OBS-DP', Frequency: 3
# Entity: 'Multifocal', Label: 'OBS-DP', Frequency: 3
# Entity: 'infection', Label: 'OBS-DP', Frequency: 3
# Entity: 'drains', Label: 'OBS-DP', Frequency: 3
# Entity: 'Swan - Ganz', Label: 'OBS-DP', Frequency: 3
# Entity: 'constant', Label: 'OBS-DP', Frequency: 3
# Entity: 'CHF', Label: 'OBS-DP', Frequency: 3
# Entity: 'densities', Label: 'OBS-DP', Frequency: 3
# Entity: 'Blunting', Label: 'OBS-DP', Frequency: 3
# Entity: 'two', Label: 'OBS-DP', Frequency: 3
# Entity: 'atelectatic', Label: 'OBS-DP', Frequency: 3
# Entity: 'Pneumomediastinum', Label: 'OBS-DP', Frequency: 3
# Entity: 'markedly', Label: 'OBS-DP', Frequency: 3
# Entity: 'granuloma', Label: 'OBS-DP', Frequency: 3
# Entity: 'Feeding', Label: 'OBS-DP', Frequency: 3
# Entity: 'Moderately', Label: 'OBS-DP', Frequency: 3
# Entity: 'a', Label: 'OBS-DP', Frequency: 3
# Entity: 'persistent', Label: 'OBS-DP', Frequency: 3
# Entity: 'air bronchograms', Label: 'OBS-DP', Frequency: 3
# Entity: 'infiltrates', Label: 'OBS-DP', Frequency: 3
# Entity: 'Widened', Label: 'OBS-DP', Frequency: 3
# Entity: 'lymphadenopathy', Label: 'OBS-DP', Frequency: 3
# Entity: 'exaggerated', Label: 'OBS-DP', Frequency: 3
# Entity: 'approximately', Label: 'OBS-DP', Frequency: 3
# Entity: 'high', Label: 'OBS-DP', Frequency: 3
# Entity: 'Widening', Label: 'OBS-DP', Frequency: 3
# Entity: 'fullness', Label: 'OBS-DP', Frequency: 3
# Entity: 'Opacity', Label: 'OBS-DP', Frequency: 3
# Entity: 'stabilization', Label: 'OBS-DP', Frequency: 3
# Entity: 'pronounced', Label: 'OBS-DP', Frequency: 3
# Entity: 'rounded', Label: 'OBS-DP', Frequency: 3
# Entity: 'infiltrates', Label: 'OBS-DA', Frequency: 3
# Entity: 'widening', Label: 'OBS-DA', Frequency: 3
# Entity: 'changes', Label: 'OBS-DA', Frequency: 3
# Entity: 'lobe', Label: 'OBS-DA', Frequency: 3
# Entity: 'Endotracheal', Label: 'OBS-DA', Frequency: 3
# Entity: 'superimposed', Label: 'OBS-DA', Frequency: 3
# Entity: 'confluent', Label: 'OBS-DA', Frequency: 3
# Entity: 'fracture', Label: 'OBS-DA', Frequency: 3
# Entity: 'tubes', Label: 'OBS-DA', Frequency: 3
# Entity: 'nodules', Label: 'OBS-DA', Frequency: 3
# Entity: 'hypertension', Label: 'OBS-U', Frequency: 3
# Entity: 'layering', Label: 'OBS-U', Frequency: 3
# Entity: 'obstruction', Label: 'OBS-U', Frequency: 3
# Entity: 'CHF', Label: 'OBS-U', Frequency: 3
# Entity: 'normal', Label: 'OBS-U', Frequency: 3
# Entity: 'enlarged', Label: 'OBS-U', Frequency: 3
# Entity: 'minimal', Label: 'OBS-U', Frequency: 3
# Entity: 'overlying', Label: 'OBS-U', Frequency: 3
# Entity: 'severe', Label: 'OBS-U', Frequency: 3
# Entity: 'ribcage', Label: 'ANAT-DP', Frequency: 2
# Entity: 'laterally', Label: 'ANAT-DP', Frequency: 2
# Entity: 'mitral', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Aortic', Label: 'ANAT-DP', Frequency: 2
# Entity: 'knob', Label: 'ANAT-DP', Frequency: 2
# Entity: 'airway', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Vascular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'aspect', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Mediastinum', Label: 'ANAT-DP', Frequency: 2
# Entity: 'intravascular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'internal jugular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'parenchyma', Label: 'ANAT-DP', Frequency: 2
# Entity: 'biapical', Label: 'ANAT-DP', Frequency: 2
# Entity: 'thyroid', Label: 'ANAT-DP', Frequency: 2
# Entity: 'CARDIAC', Label: 'ANAT-DP', Frequency: 2
# Entity: 'SILHOUETTE', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Aorta', Label: 'ANAT-DP', Frequency: 2
# Entity: 'GE', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Rib', Label: 'ANAT-DP', Frequency: 2
# Entity: 'thorax', Label: 'ANAT-DP', Frequency: 2
# Entity: 'first', Label: 'ANAT-DP', Frequency: 2
# Entity: 'portions', Label: 'ANAT-DP', Frequency: 2
# Entity: 'third', Label: 'ANAT-DP', Frequency: 2
# Entity: 'scapula', Label: 'ANAT-DP', Frequency: 2
# Entity: 'left sided', Label: 'ANAT-DP', Frequency: 2
# Entity: 'humeral', Label: 'ANAT-DP', Frequency: 2
# Entity: 'head', Label: 'ANAT-DP', Frequency: 2
# Entity: 'peribronchial', Label: 'ANAT-DP', Frequency: 2
# Entity: 'azygos', Label: 'ANAT-DP', Frequency: 2
# Entity: 'spinal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Sternal', Label: 'ANAT-DP', Frequency: 2
# Entity: '3 cm above', Label: 'ANAT-DP', Frequency: 2
# Entity: 'lingula', Label: 'ANAT-DP', Frequency: 2
# Entity: 'lobes', Label: 'ANAT-DP', Frequency: 2
# Entity: 'cage', Label: 'ANAT-DP', Frequency: 2
# Entity: 'subdiaphragmatic', Label: 'ANAT-DP', Frequency: 2
# Entity: 'cervical', Label: 'ANAT-DP', Frequency: 2
# Entity: 'bony', Label: 'ANAT-DP', Frequency: 2
# Entity: 'over', Label: 'ANAT-DP', Frequency: 2
# Entity: 'gastric', Label: 'ANAT-DP', Frequency: 2
# Entity: 'area', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Bronchial', Label: 'ANAT-DP', Frequency: 2
# Entity: 'nipple', Label: 'ANAT-DP', Frequency: 2
# Entity: 'areas', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Spinal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'brachiocephalic', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Superiorly', Label: 'ANAT-DP', Frequency: 2
# Entity: 'axilla', Label: 'ANAT-DP', Frequency: 2
# Entity: 'bronchial', Label: 'ANAT-DP', Frequency: 2
# Entity: 'coronary', Label: 'ANAT-DP', Frequency: 2
# Entity: 'AC', Label: 'ANAT-DP', Frequency: 2
# Entity: 'joint', Label: 'ANAT-DP', Frequency: 2
# Entity: 'distention', Label: 'OBS-DP', Frequency: 2
# Entity: 'Otherwise', Label: 'OBS-DP', Frequency: 2
# Entity: 'malpositioned', Label: 'OBS-DP', Frequency: 2
# Entity: 'lateral', Label: 'OBS-DP', Frequency: 2
# Entity: 'radiograph', Label: 'OBS-DP', Frequency: 2
# Entity: 'conspicuous', Label: 'OBS-DP', Frequency: 2
# Entity: 'difficult to assess', Label: 'OBS-DP', Frequency: 2
# Entity: 'aerated', Label: 'OBS-DP', Frequency: 2
# Entity: 'round', Label: 'OBS-DP', Frequency: 2
# Entity: 'component', Label: 'OBS-DP', Frequency: 2
# Entity: 'post - operative', Label: 'OBS-DP', Frequency: 2
# Entity: 'alignment', Label: 'OBS-DP', Frequency: 2
# Entity: 'an', Label: 'OBS-DP', Frequency: 2
# Entity: 'underlying', Label: 'OBS-DP', Frequency: 2
# Entity: 'adjacent', Label: 'OBS-DP', Frequency: 2
# Entity: 'volume', Label: 'OBS-DP', Frequency: 2
# Entity: 'nearly', Label: 'OBS-DP', Frequency: 2
# Entity: 'old', Label: 'OBS-DP', Frequency: 2
# Entity: 'streaky', Label: 'OBS-DP', Frequency: 2
# Entity: 'trace', Label: 'OBS-DP', Frequency: 2
# Entity: 'aligned', Label: 'OBS-DP', Frequency: 2
# Entity: 'flattened', Label: 'OBS-DP', Frequency: 2
# Entity: '9 mm', Label: 'OBS-DP', Frequency: 2
# Entity: 'Scattered', Label: 'OBS-DP', Frequency: 2
# Entity: 'Continued', Label: 'OBS-DP', Frequency: 2
# Entity: 'fully', Label: 'OBS-DP', Frequency: 2
# Entity: 'Hyperinflated', Label: 'OBS-DP', Frequency: 2
# Entity: 'Increase', Label: 'OBS-DP', Frequency: 2
# Entity: 'Port - A - Cath', Label: 'OBS-DP', Frequency: 2
# Entity: 'inflated', Label: 'OBS-DP', Frequency: 2
# Entity: 'ill - defined', Label: 'OBS-DP', Frequency: 2
# Entity: 'severity', Label: 'OBS-DP', Frequency: 2
# Entity: 'replacement', Label: 'OBS-DP', Frequency: 2
# Entity: 'right internal jugular vein', Label: 'OBS-DP', Frequency: 2
# Entity: 'nondistended', Label: 'OBS-DP', Frequency: 2
# Entity: 'blurring', Label: 'OBS-DP', Frequency: 2
# Entity: 'proximal', Label: 'OBS-DP', Frequency: 2
# Entity: 'side port', Label: 'OBS-DP', Frequency: 2
# Entity: 'Trace', Label: 'OBS-DP', Frequency: 2
# Entity: 'deviation', Label: 'OBS-DP', Frequency: 2
# Entity: 'left', Label: 'OBS-DP', Frequency: 2
# Entity: 'atherosclerotic', Label: 'OBS-DP', Frequency: 2
# Entity: 'changed', Label: 'OBS-DP', Frequency: 2
# Entity: 'better', Label: 'OBS-DP', Frequency: 2
# Entity: 'pacemaker', Label: 'OBS-DP', Frequency: 2
# Entity: 'metallic', Label: 'OBS-DP', Frequency: 2
# Entity: 'advanced', Label: 'OBS-DP', Frequency: 2
# Entity: 'Atelectatic', Label: 'OBS-DP', Frequency: 2
# Entity: 'existing', Label: 'OBS-DP', Frequency: 2
# Entity: 'injury', Label: 'OBS-DP', Frequency: 2
# Entity: 'displacement', Label: 'OBS-DP', Frequency: 2
# Entity: 'lucency', Label: 'OBS-DP', Frequency: 2
# Entity: 'severely', Label: 'OBS-DP', Frequency: 2
# Entity: 'limited', Label: 'OBS-DP', Frequency: 2
# Entity: 'opacified', Label: 'OBS-DP', Frequency: 2
# Entity: 'elongated', Label: 'OBS-DP', Frequency: 2
# Entity: 'collections', Label: 'OBS-DP', Frequency: 2
# Entity: 'very', Label: 'OBS-DP', Frequency: 2
# Entity: 'Unremarkable', Label: 'OBS-DP', Frequency: 2
# Entity: 'Clear', Label: 'OBS-DP', Frequency: 2
# Entity: 'deformity', Label: 'OBS-DP', Frequency: 2
# Entity: 'Clips', Label: 'OBS-DP', Frequency: 2
# Entity: 'positions', Label: 'OBS-DP', Frequency: 2
# Entity: 'pneumothoraces', Label: 'OBS-DP', Frequency: 2
# Entity: 'over', Label: 'OBS-DP', Frequency: 2
# Entity: 'Calcified', Label: 'OBS-DP', Frequency: 2
# Entity: 'Streaky', Label: 'OBS-DP', Frequency: 2
# Entity: 'diffusely', Label: 'OBS-DP', Frequency: 2
# Entity: 'Deformity', Label: 'OBS-DP', Frequency: 2
# Entity: 'reticular', Label: 'OBS-DP', Frequency: 2
# Entity: 'moderate - sized', Label: 'OBS-DP', Frequency: 2
# Entity: 'granulomatous', Label: 'OBS-DP', Frequency: 2
# Entity: 'pre - existing', Label: 'OBS-DP', Frequency: 2
# Entity: 'obscures', Label: 'OBS-DP', Frequency: 2
# Entity: 'Improved', Label: 'OBS-DP', Frequency: 2
# Entity: 'fusion', Label: 'OBS-DP', Frequency: 2
# Entity: 'persistently', Label: 'OBS-DP', Frequency: 2
# Entity: 'fixation', Label: 'OBS-DP', Frequency: 2
# Entity: 'transesophageal', Label: 'OBS-DP', Frequency: 2
# Entity: 'developing', Label: 'OBS-DP', Frequency: 2
# Entity: 'widespread', Label: 'OBS-DP', Frequency: 2
# Entity: 'process', Label: 'OBS-DP', Frequency: 2
# Entity: 'stably', Label: 'OBS-DP', Frequency: 2
# Entity: 'plate - like', Label: 'OBS-DP', Frequency: 2
# Entity: 'extubated', Label: 'OBS-DP', Frequency: 2
# Entity: 'catheters', Label: 'OBS-DP', Frequency: 2
# Entity: 'satisfactory', Label: 'OBS-DP', Frequency: 2
# Entity: 'small - to - moderate', Label: 'OBS-DP', Frequency: 2
# Entity: 'leftward', Label: 'OBS-DP', Frequency: 2
# Entity: 'shift', Label: 'OBS-DP', Frequency: 2
# Entity: 'Little', Label: 'OBS-DP', Frequency: 2
# Entity: 'extubation', Label: 'OBS-DP', Frequency: 2
# Entity: 'orogastric', Label: 'OBS-DP', Frequency: 2
# Entity: 'out of view', Label: 'OBS-DP', Frequency: 2
# Entity: 'cardiac', Label: 'OBS-DP', Frequency: 2
# Entity: 'free', Label: 'OBS-DP', Frequency: 2
# Entity: 'expected', Label: 'OBS-DP', Frequency: 2
# Entity: 'widening', Label: 'OBS-DP', Frequency: 2
# Entity: 'single', Label: 'OBS-DP', Frequency: 2
# Entity: 'wedge', Label: 'OBS-DP', Frequency: 2
# Entity: 'resection', Label: 'OBS-DP', Frequency: 2
# Entity: 'suture', Label: 'OBS-DP', Frequency: 2
# Entity: 'nodule', Label: 'OBS-DP', Frequency: 2
# Entity: 'rightward', Label: 'OBS-DP', Frequency: 2
# Entity: 'sarcoidosis', Label: 'OBS-DP', Frequency: 2
# Entity: 'surgery', Label: 'OBS-DP', Frequency: 2
# Entity: 'fibrosis', Label: 'OBS-DP', Frequency: 2
# Entity: 'it', Label: 'OBS-DP', Frequency: 2
# Entity: 'Substantial', Label: 'OBS-DP', Frequency: 2
# Entity: 'hemorrhage', Label: 'OBS-DP', Frequency: 2
# Entity: 'Scoliosis', Label: 'OBS-DP', Frequency: 2
# Entity: 'Hazy', Label: 'OBS-DP', Frequency: 2
# Entity: 'improving', Label: 'OBS-DP', Frequency: 2
# Entity: 'Left', Label: 'OBS-DP', Frequency: 2
# Entity: 'PIC', Label: 'OBS-DP', Frequency: 2
# Entity: 'pigtail', Label: 'OBS-DP', Frequency: 2
# Entity: 'Triple', Label: 'OBS-DP', Frequency: 2
# Entity: 'hyperexpansion', Label: 'OBS-DP', Frequency: 2
# Entity: 'lucencies', Label: 'OBS-DP', Frequency: 2
# Entity: 'superimposed', Label: 'OBS-DP', Frequency: 2
# Entity: 'engorged', Label: 'OBS-DA', Frequency: 2
# Entity: 'relevant', Label: 'OBS-DA', Frequency: 2
# Entity: 'infectious', Label: 'OBS-DA', Frequency: 2
# Entity: 'infiltrate', Label: 'OBS-DA', Frequency: 2
# Entity: 'frank', Label: 'OBS-DA', Frequency: 2
# Entity: 'mild', Label: 'OBS-DA', Frequency: 2
# Entity: 'central', Label: 'OBS-DA', Frequency: 2
# Entity: 'drain', Label: 'OBS-DA', Frequency: 2
# Entity: 'areas', Label: 'OBS-DA', Frequency: 2
# Entity: 'PICC', Label: 'OBS-DA', Frequency: 2
# Entity: 'atelectasis', Label: 'OBS-DA', Frequency: 2
# Entity: 'endotracheal', Label: 'OBS-DA', Frequency: 2
# Entity: 'substantial', Label: 'OBS-DA', Frequency: 2
# Entity: 'appreciable', Label: 'OBS-DA', Frequency: 2
# Entity: 'residual', Label: 'OBS-DA', Frequency: 2
# Entity: 'gross', Label: 'OBS-DA', Frequency: 2
# Entity: 'rightward', Label: 'OBS-DA', Frequency: 2
# Entity: 'feeding', Label: 'OBS-DA', Frequency: 2
# Entity: 'collapse', Label: 'OBS-DA', Frequency: 2
# Entity: 'fluid', Label: 'OBS-DA', Frequency: 2
# Entity: 'line', Label: 'OBS-DA', Frequency: 2
# Entity: 'lesions', Label: 'OBS-DA', Frequency: 2
# Entity: 'increased', Label: 'OBS-DA', Frequency: 2
# Entity: 'congested', Label: 'OBS-DA', Frequency: 2
# Entity: 'infiltrate', Label: 'OBS-U', Frequency: 2
# Entity: 'resolving', Label: 'OBS-U', Frequency: 2
# Entity: 'limits', Label: 'OBS-U', Frequency: 2
# Entity: 'mildly', Label: 'OBS-U', Frequency: 2
# Entity: 'focus', Label: 'OBS-U', Frequency: 2
# Entity: 'tiny', Label: 'OBS-U', Frequency: 2
# Entity: 'residual', Label: 'OBS-U', Frequency: 2
# Entity: 'bleeding', Label: 'OBS-U', Frequency: 2
# Entity: 'low', Label: 'OBS-U', Frequency: 2
# Entity: 'fracture', Label: 'OBS-U', Frequency: 2
# Entity: 'changes', Label: 'OBS-U', Frequency: 2
# Entity: 'Minimal', Label: 'OBS-U', Frequency: 2
# Entity: 'area', Label: 'OBS-U', Frequency: 2
# Entity: 'secondary', Label: 'OBS-U', Frequency: 2
# Entity: 'improved', Label: 'OBS-U', Frequency: 2
# Entity: 'obscured', Label: 'OBS-U', Frequency: 2
# Entity: 'shadow', Label: 'OBS-U', Frequency: 2
# Entity: 'Underlying', Label: 'OBS-U', Frequency: 2
# Entity: 'tip', Label: 'OBS-U', Frequency: 2
# Entity: 'findings', Label: 'OBS-U', Frequency: 2
# Entity: 'amount', Label: 'OBS-U', Frequency: 2
# Entity: 'tube', Label: 'OBS-U', Frequency: 2
# Entity: 'acute', Label: 'OBS-U', Frequency: 2
# Entity: 'fibrotic', Label: 'OBS-U', Frequency: 2
# Entity: 'lymphadenopathy', Label: 'OBS-U', Frequency: 2
# Entity: 'loculated', Label: 'OBS-U', Frequency: 2
# Entity: 'approximately a 4.6 cm', Label: 'ANAT-DP', Frequency: 1
# Entity: 'extreme', Label: 'ANAT-DP', Frequency: 1
# Entity: '4.3 cm', Label: 'ANAT-DP', Frequency: 1
# Entity: 'approximately 1.8 cm', Label: 'ANAT-DP', Frequency: 1
# Entity: 'barely', Label: 'ANAT-DP', Frequency: 1
# Entity: 'approximately 12 cm', Label: 'ANAT-DP', Frequency: 1
# Entity: 'approximately 2 cm', Label: 'ANAT-DP', Frequency: 1
# Entity: 'apices', Label: 'ANAT-DP', Frequency: 1
# Entity: 'loculated', Label: 'ANAT-DP', Frequency: 1
# Entity: 'fifith', Label: 'ANAT-DP', Frequency: 1
# Entity: 'configuration', Label: 'ANAT-DP', Frequency: 1
# Entity: 'skin', Label: 'ANAT-DP', Frequency: 1
# Entity: 'institial', Label: 'ANAT-DP', Frequency: 1
# Entity: 'AP', Label: 'ANAT-DP', Frequency: 1
# Entity: 'diameter', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Lower', Label: 'ANAT-DP', Frequency: 1
# Entity: 'superior vena cava', Label: 'ANAT-DP', Frequency: 1
# Entity: 'veins', Label: 'ANAT-DP', Frequency: 1
# Entity: 'knuckle', Label: 'ANAT-DP', Frequency: 1
# Entity: 'fifth', Label: 'ANAT-DP', Frequency: 1
# Entity: 'lingular', Label: 'ANAT-DP', Frequency: 1
# Entity: 'valvular', Label: 'ANAT-DP', Frequency: 1
# Entity: 'infrahilar', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Midline', Label: 'ANAT-DP', Frequency: 1
# Entity: 'pulmonic', Label: 'ANAT-DP', Frequency: 1
# Entity: '5 cm above', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Median', Label: 'ANAT-DP', Frequency: 1
# Entity: 'cardia', Label: 'ANAT-DP', Frequency: 1
# Entity: 'mild', Label: 'ANAT-DP', Frequency: 1
# Entity: 'shape', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Thoracic', Label: 'ANAT-DP', Frequency: 1
# Entity: 'PARENCHYMAL', Label: 'ANAT-DP', Frequency: 1
# Entity: 'LUNG', Label: 'ANAT-DP', Frequency: 1
# Entity: 'SIZE', Label: 'ANAT-DP', Frequency: 1
# Entity: 'HILAR', Label: 'ANAT-DP', Frequency: 1
# Entity: 'MEDIASTINAL', Label: 'ANAT-DP', Frequency: 1
# Entity: 'STRUCTURES', Label: 'ANAT-DP', Frequency: 1
# Entity: 'AZYGOS', Label: 'ANAT-DP', Frequency: 1
# Entity: 'LOBE', Label: 'ANAT-DP', Frequency: 1
# Entity: 'remainder', Label: 'ANAT-DP', Frequency: 1
# Entity: 'midlung', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Hemidiaphragm', Label: 'ANAT-DP', Frequency: 1
# Entity: 'mainstem', Label: 'ANAT-DP', Frequency: 1
# Entity: 'bronchus', Label: 'ANAT-DP', Frequency: 1
# Entity: 'medially', Label: 'ANAT-DP', Frequency: 1
# Entity: 'multiple', Label: 'ANAT-DP', Frequency: 1
# Entity: 'lateral structures', Label: 'ANAT-DP', Frequency: 1
# Entity: 'left arm', Label: 'ANAT-DP', Frequency: 1
# Entity: 'transverse', Label: 'ANAT-DP', Frequency: 1
# Entity: 'process', Label: 'ANAT-DP', Frequency: 1
# Entity: 'L 2 through L 4', Label: 'ANAT-DP', Frequency: 1
# Entity: 'posteriorly', Label: 'ANAT-DP', Frequency: 1
# Entity: 'ninth', Label: 'ANAT-DP', Frequency: 1
# Entity: 'contents', Label: 'ANAT-DP', Frequency: 1
# Entity: '4 cm above', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Apical', Label: 'ANAT-DP', Frequency: 1
# Entity: 'emphysema', Label: 'ANAT-DP', Frequency: 1
# Entity: 'inferior', Label: 'ANAT-DP', Frequency: 1
# Entity: 'field', Label: 'ANAT-DP', Frequency: 1
# Entity: 'normal', Label: 'ANAT-DP', Frequency: 1
# Entity: 'subcutaneus', Label: 'ANAT-DP', Frequency: 1
# Entity: 'otherwise', Label: 'ANAT-DP', Frequency: 1
# Entity: 'T 5 through T 9', Label: 'ANAT-DP', Frequency: 1
# Entity: 'of T 5 through T 9', Label: 'ANAT-DP', Frequency: 1
# Entity: 'intrafissural', Label: 'ANAT-DP', Frequency: 1
# Entity: 'pectus', Label: 'ANAT-DP', Frequency: 1
# Entity: 'excavatum', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Pectus', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Left sided', Label: 'ANAT-DP', Frequency: 1
# Entity: 'subpulmonic', Label: 'ANAT-DP', Frequency: 1
# Entity: 'structure', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Soft tissue', Label: 'ANAT-DP', Frequency: 1
# Entity: 'interspace', Label: 'ANAT-DP', Frequency: 1
# Entity: 'bibasal', Label: 'ANAT-DP', Frequency: 1
# Entity: 'rightward', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Vasculature', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Perihilar', Label: 'ANAT-DP', Frequency: 1
# Entity: 'pylorus', Label: 'ANAT-DP', Frequency: 1
# Entity: 'superior cavoatrial junction', Label: 'ANAT-DP', Frequency: 1
# Entity: 'subsegmental', Label: 'ANAT-DP', Frequency: 1
# Entity: 'grossly', Label: 'ANAT-DP', Frequency: 1
# Entity: 'predominantly', Label: 'ANAT-DP', Frequency: 1
# Entity: 'fissural', Label: 'ANAT-DP', Frequency: 1
# Entity: 'bones', Label: 'ANAT-DP', Frequency: 1
# Entity: 'in', Label: 'ANAT-DP', Frequency: 1
# Entity: 'duodenum', Label: 'ANAT-DP', Frequency: 1
# Entity: 'approximately 2.3 cm', Label: 'ANAT-DP', Frequency: 1
# Entity: '3.5 cm above', Label: 'ANAT-DP', Frequency: 1
# Entity: '4.7 cm above', Label: 'ANAT-DP', Frequency: 1
# Entity: '2.8 cm above', Label: 'ANAT-DP', Frequency: 1
# Entity: 'segment', Label: 'ANAT-DP', Frequency: 1
# Entity: 'out of view', Label: 'ANAT-DP', Frequency: 1
# Entity: 'withdrawn 1 cm', Label: 'ANAT-DP', Frequency: 1
# Entity: '2.9 cm above', Label: 'ANAT-DP', Frequency: 1
# Entity: '3.4 cm', Label: 'ANAT-DP', Frequency: 1
# Entity: '3.6 cm above', Label: 'ANAT-DP', Frequency: 1
# Entity: 'inlet', Label: 'ANAT-DP', Frequency: 1
# Entity: 'visualized', Label: 'ANAT-DP', Frequency: 1
# Entity: 'under', Label: 'ANAT-DP', Frequency: 1
# Entity: 'CP', Label: 'ANAT-DP', Frequency: 1
# Entity: 'infectious', Label: 'ANAT-DP', Frequency: 1
# Entity: 'great', Label: 'ANAT-DP', Frequency: 1
# Entity: 'vessel', Label: 'ANAT-DP', Frequency: 1
# Entity: '6 cm above', Label: 'ANAT-DP', Frequency: 1
# Entity: 'opacities', Label: 'ANAT-DP', Frequency: 1
# Entity: '7 cm', Label: 'ANAT-DP', Frequency: 1
# Entity: 'juxta', Label: 'ANAT-DP', Frequency: 1
# Entity: 'GE junction', Label: 'ANAT-DP', Frequency: 1
# Entity: 'parts', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Low', Label: 'ANAT-DP', Frequency: 1
# Entity: 'seventh', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Remainder', Label: 'ANAT-DP', Frequency: 1
# Entity: 'skeletal', Label: 'ANAT-DP', Frequency: 1
# Entity: 'pedicle', Label: 'ANAT-DP', Frequency: 1
# Entity: 'underneath', Label: 'ANAT-DP', Frequency: 1
# Entity: 'shadows', Label: 'ANAT-DP', Frequency: 1
# Entity: 'thoracolumbar junction', Label: 'ANAT-DP', Frequency: 1
# Entity: 'compartment', Label: 'ANAT-DP', Frequency: 1
# Entity: 'nodule', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Lateral', Label: 'ANAT-DP', Frequency: 1
# Entity: 'sinuses', Label: 'ANAT-DP', Frequency: 1
# Entity: 'dependent', Label: 'ANAT-DP', Frequency: 1
# Entity: 'posteroinferior', Label: 'ANAT-DP', Frequency: 1
# Entity: 'paraspinal', Label: 'ANAT-DP', Frequency: 1
# Entity: 'cutaneous', Label: 'ANAT-DP', Frequency: 1
# Entity: '8 cm above', Label: 'ANAT-DP', Frequency: 1
# Entity: 'dorsolateral part', Label: 'ANAT-DP', Frequency: 1
# Entity: 'enlarged', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Coronary', Label: 'ANAT-DP', Frequency: 1
# Entity: 'PULMONARY', Label: 'ANAT-DP', Frequency: 1
# Entity: 'BILATERAL', Label: 'ANAT-DP', Frequency: 1
# Entity: 'PLEURAL', Label: 'ANAT-DP', Frequency: 1
# Entity: 'BASILAR', Label: 'ANAT-DP', Frequency: 1
# Entity: 'peripherally', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Multiple', Label: 'ANAT-DP', Frequency: 1
# Entity: 'loops', Label: 'ANAT-DP', Frequency: 1
# Entity: 'small', Label: 'ANAT-DP', Frequency: 1
# Entity: 'bowel', Label: 'ANAT-DP', Frequency: 1
# Entity: '4.6 cm above', Label: 'ANAT-DP', Frequency: 1
# Entity: 'pleural - based', Label: 'ANAT-DP', Frequency: 1
# Entity: 'sided', Label: 'ANAT-DP', Frequency: 1
# Entity: 'approximately 5 cm', Label: 'ANAT-DP', Frequency: 1
# Entity: 'gastroesophageal', Label: 'ANAT-DP', Frequency: 1
# Entity: 'side port', Label: 'ANAT-DP', Frequency: 1
# Entity: '5.6 cm', Label: 'ANAT-DP', Frequency: 1
# Entity: '1.8 cm above', Label: 'ANAT-DP', Frequency: 1
# Entity: 'costal', Label: 'ANAT-DP', Frequency: 1
# Entity: 'cartilage', Label: 'ANAT-DP', Frequency: 1
# Entity: 'peripheral', Label: 'ANAT-DP', Frequency: 1
# Entity: 'mid - to - distal', Label: 'ANAT-DP', Frequency: 1
# Entity: 'side', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Hila', Label: 'ANAT-DP', Frequency: 1
# Entity: 'cavitary', Label: 'ANAT-DP', Frequency: 1
# Entity: 'plerual', Label: 'ANAT-DP', Frequency: 1
# Entity: 'outer margin', Label: 'ANAT-DP', Frequency: 1
# Entity: 'in the expected positions', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Central', Label: 'ANAT-DP', Frequency: 1
# Entity: 'biventricular', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Base', Label: 'ANAT-DP', Frequency: 1
# Entity: 'glenohumeral', Label: 'ANAT-DP', Frequency: 1
# Entity: 'acromioclavicular', Label: 'ANAT-DP', Frequency: 1
# Entity: 'joints', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Interstitial', Label: 'ANAT-DP', Frequency: 1
# Entity: 'angles', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Peripheral', Label: 'ANAT-DP', Frequency: 1
# Entity: 'interstitium', Label: 'ANAT-DP', Frequency: 1
# Entity: 'T 12 vertebral', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Thoracolumbar', Label: 'ANAT-DP', Frequency: 1
# Entity: 'scapular', Label: 'ANAT-DP', Frequency: 1
# Entity: 'other', Label: 'ANAT-DP', Frequency: 1
# Entity: 'locations', Label: 'ANAT-DP', Frequency: 1
# Entity: 'intersitial', Label: 'ANAT-DP', Frequency: 1
# Entity: 'tricuspid', Label: 'ANAT-DP', Frequency: 1
# Entity: 'takeoff', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Visceral', Label: 'ANAT-DP', Frequency: 1
# Entity: 'regions', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Trachea', Label: 'ANAT-DP', Frequency: 1
# Entity: 'deviated', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Both', Label: 'ANAT-DP', Frequency: 1
# Entity: 'appearance', Label: 'ANAT-DP', Frequency: 1
# Entity: 'Bronchovascular', Label: 'ANAT-DP', Frequency: 1
# Entity: 'advanced by at least 11 cm', Label: 'OBS-DP', Frequency: 1
# Entity: 'patient 's chin', Label: 'OBS-DP', Frequency: 1
# Entity: 'Gaseous', Label: 'OBS-DP', Frequency: 1
# Entity: 'distension', Label: 'OBS-DP', Frequency: 1
# Entity: 'Standard', Label: 'OBS-DP', Frequency: 1
# Entity: 'The side - port', Label: 'OBS-DP', Frequency: 1
# Entity: 'side ports', Label: 'OBS-DP', Frequency: 1
# Entity: 'Limited', Label: 'OBS-DP', Frequency: 1
# Entity: 'negative', Label: 'OBS-DP', Frequency: 1
# Entity: 'frontal', Label: 'OBS-DP', Frequency: 1
# Entity: 'underinflated', Label: 'OBS-DP', Frequency: 1
# Entity: 'The lateral view is limited', Label: 'OBS-DP', Frequency: 1
# Entity: 'patient 's arms', Label: 'OBS-DP', Frequency: 1
# Entity: 'They', Label: 'OBS-DP', Frequency: 1
# Entity: 'recent exam from ___', Label: 'OBS-DP', Frequency: 1
# Entity: 'previous exams from ___', Label: 'OBS-DP', Frequency: 1
# Entity: 'Old', Label: 'OBS-DP', Frequency: 1
# Entity: 'Overall', Label: 'OBS-DP', Frequency: 1
# Entity: 'Evaluation is limited', Label: 'OBS-DP', Frequency: 1
# Entity: 'patient 's head', Label: 'OBS-DP', Frequency: 1
# Entity: 'visualized', Label: 'OBS-DP', Frequency: 1
# Entity: 'increasing', Label: 'OBS-DP', Frequency: 1
# Entity: 'loculation', Label: 'OBS-DP', Frequency: 1
# Entity: 'subjacent', Label: 'OBS-DP', Frequency: 1
# Entity: 'TIPS', Label: 'OBS-DP', Frequency: 1
# Entity: 'not well assessed', Label: 'OBS-DP', Frequency: 1
# Entity: 'hypertension', Label: 'OBS-DP', Frequency: 1
# ...
#          ('component', 'OBS-DP'): 2,
#          ('post - operative', 'OBS-DP'): 2,
#          ('alignment', 'OBS-DP'): 2,
#          ('an', 'OBS-DP'): 2,
#          ('underlying', 'OBS-DP'): 2,
#          ('adjacent', 'OBS-DP'): 2,
#          ('volume', 'OBS-DP'): 2,
#          ('nearly', 'OBS-DP'): 2,
#          ('old', 'OBS-DP'): 2,
#          ('streaky', 'OBS-DP'): 2,
#          ('trace', 'OBS-DP'): 2,
#          ('aligned', 'OBS-DP'): 2,
#          ('flattened', 'OBS-DP'): 2,
#          ('9 mm', 'OBS-DP'): 2,
#          ('Scattered', 'OBS-DP'): 2,
#          ('Continued', 'OBS-DP'): 2,
#          ('fully', 'OBS-DP'): 2,
#          ('Hyperinflated', 'OBS-DP'): 2,
#          ('Increase', 'OBS-DP'): 2,
#          ('Port - A - Cath', 'OBS-DP'): 2,
#          ('inflated', 'OBS-DP'): 2,
#          ('ill - defined', 'OBS-DP'): 2,
#          ('severity', 'OBS-DP'): 2,
#          ('replacement', 'OBS-DP'): 2,
#          ('right internal jugular vein', 'OBS-DP'): 2,
#          ('nondistended', 'OBS-DP'): 2,
#          ('blurring', 'OBS-DP'): 2,
#          ('proximal', 'OBS-DP'): 2,
#          ('side port', 'OBS-DP'): 2,
#          ('Trace', 'OBS-DP'): 2,
#          ('deviation', 'OBS-DP'): 2,
#          ('left', 'OBS-DP'): 2,
#          ('atherosclerotic', 'OBS-DP'): 2,
#          ('changed', 'OBS-DP'): 2,
#          ('better', 'OBS-DP'): 2,
#          ('pacemaker', 'OBS-DP'): 2,
#          ('metallic', 'OBS-DP'): 2,
#          ('advanced', 'OBS-DP'): 2,
#          ('Atelectatic', 'OBS-DP'): 2,
#          ('existing', 'OBS-DP'): 2,
#          ('injury', 'OBS-DP'): 2,
#          ('displacement', 'OBS-DP'): 2,
#          ('lucency', 'OBS-DP'): 2,
#          ('severely', 'OBS-DP'): 2,
#          ('limited', 'OBS-DP'): 2,
#          ('opacified', 'OBS-DP'): 2,
#          ('elongated', 'OBS-DP'): 2,
#          ('collections', 'OBS-DP'): 2,
#          ('very', 'OBS-DP'): 2,
#          ('Unremarkable', 'OBS-DP'): 2,
#          ('Clear', 'OBS-DP'): 2,
#          ('deformity', 'OBS-DP'): 2,
#          ('Clips', 'OBS-DP'): 2,
#          ('positions', 'OBS-DP'): 2,
#          ('pneumothoraces', 'OBS-DP'): 2,
#          ('over', 'OBS-DP'): 2,
#          ('Calcified', 'OBS-DP'): 2,
#          ('Streaky', 'OBS-DP'): 2,
#          ('diffusely', 'OBS-DP'): 2,
#          ('Deformity', 'OBS-DP'): 2,
#          ('reticular', 'OBS-DP'): 2,
#          ('moderate - sized', 'OBS-DP'): 2,
#          ('granulomatous', 'OBS-DP'): 2,
#          ('pre - existing', 'OBS-DP'): 2,
#          ('obscures', 'OBS-DP'): 2,
#          ('Improved', 'OBS-DP'): 2,
#          ('fusion', 'OBS-DP'): 2,
#          ('persistently', 'OBS-DP'): 2,
#          ('fixation', 'OBS-DP'): 2,
#          ('transesophageal', 'OBS-DP'): 2,
#          ('developing', 'OBS-DP'): 2,
#          ('widespread', 'OBS-DP'): 2,
#          ('process', 'OBS-DP'): 2,
#          ('stably', 'OBS-DP'): 2,
#          ('plate - like', 'OBS-DP'): 2,
#          ('extubated', 'OBS-DP'): 2,
#          ('catheters', 'OBS-DP'): 2,
#          ('satisfactory', 'OBS-DP'): 2,
#          ('small - to - moderate', 'OBS-DP'): 2,
#          ('leftward', 'OBS-DP'): 2,
#          ('shift', 'OBS-DP'): 2,
#          ('Little', 'OBS-DP'): 2,
#          ('extubation', 'OBS-DP'): 2,
#          ('orogastric', 'OBS-DP'): 2,
#          ('out of view', 'OBS-DP'): 2,
#          ('cardiac', 'OBS-DP'): 2,
#          ('free', 'OBS-DP'): 2,
#          ('expected', 'OBS-DP'): 2,
#          ('widening', 'OBS-DP'): 2,
#          ('single', 'OBS-DP'): 2,
#          ('wedge', 'OBS-DP'): 2,
#          ('resection', 'OBS-DP'): 2,
#          ('suture', 'OBS-DP'): 2,
#          ('nodule', 'OBS-DP'): 2,
#          ('rightward', 'OBS-DP'): 2,
#          ('sarcoidosis', 'OBS-DP'): 2,
#          ('surgery', 'OBS-DP'): 2,
#          ('fibrosis', 'OBS-DP'): 2,
#          ('it', 'OBS-DP'): 2,
#          ('Substantial', 'OBS-DP'): 2,
#          ('hemorrhage', 'OBS-DP'): 2,
#          ('Scoliosis', 'OBS-DP'): 2,
#          ('Hazy', 'OBS-DP'): 2,
#          ('improving', 'OBS-DP'): 2,
#          ('Left', 'OBS-DP'): 2,
#          ('PIC', 'OBS-DP'): 2,
#          ('pigtail', 'OBS-DP'): 2,
#          ('Triple', 'OBS-DP'): 2,
#          ('hyperexpansion', 'OBS-DP'): 2,
#          ('lucencies', 'OBS-DP'): 2,
#          ('superimposed', 'OBS-DP'): 2,
#          ('engorged', 'OBS-DA'): 2,
#          ('relevant', 'OBS-DA'): 2,
#          ('infectious', 'OBS-DA'): 2,
#          ('infiltrate', 'OBS-DA'): 2,
#          ('frank', 'OBS-DA'): 2,
#          ('mild', 'OBS-DA'): 2,
#          ('central', 'OBS-DA'): 2,
#          ('drain', 'OBS-DA'): 2,
#          ('areas', 'OBS-DA'): 2,
#          ('PICC', 'OBS-DA'): 2,
#          ('atelectasis', 'OBS-DA'): 2,
#          ('endotracheal', 'OBS-DA'): 2,
#          ('substantial', 'OBS-DA'): 2,
#          ('appreciable', 'OBS-DA'): 2,
#          ('residual', 'OBS-DA'): 2,
#          ('gross', 'OBS-DA'): 2,
#          ('rightward', 'OBS-DA'): 2,
#          ('feeding', 'OBS-DA'): 2,
#          ('collapse', 'OBS-DA'): 2,
#          ('fluid', 'OBS-DA'): 2,
#          ('line', 'OBS-DA'): 2,
#          ('lesions', 'OBS-DA'): 2,
#          ('increased', 'OBS-DA'): 2,
#          ('congested', 'OBS-DA'): 2,
#          ('infiltrate', 'OBS-U'): 2,
#          ('resolving', 'OBS-U'): 2,
#          ('limits', 'OBS-U'): 2,
#          ('mildly', 'OBS-U'): 2,
#          ('focus', 'OBS-U'): 2,
#          ('tiny', 'OBS-U'): 2,
#          ('residual', 'OBS-U'): 2,
#          ('bleeding', 'OBS-U'): 2,
#          ('low', 'OBS-U'): 2,
#          ('fracture', 'OBS-U'): 2,
#          ('changes', 'OBS-U'): 2,
#          ('Minimal', 'OBS-U'): 2,
#          ('area', 'OBS-U'): 2,
#          ('secondary', 'OBS-U'): 2,
#          ('improved', 'OBS-U'): 2,
#          ('obscured', 'OBS-U'): 2,
#          ('shadow', 'OBS-U'): 2,
#          ('Underlying', 'OBS-U'): 2,
#          ('tip', 'OBS-U'): 2,
#          ('findings', 'OBS-U'): 2,
#          ('amount', 'OBS-U'): 2,
#          ('tube', 'OBS-U'): 2,
#          ('acute', 'OBS-U'): 2,
#          ('fibrotic', 'OBS-U'): 2,
#          ('lymphadenopathy', 'OBS-U'): 2,
#          ('loculated', 'OBS-U'): 2,
#          ('approximately a 4.6 cm', 'ANAT-DP'): 1,
#          ('extreme', 'ANAT-DP'): 1,
#          ('4.3 cm', 'ANAT-DP'): 1,
#          ('approximately 1.8 cm', 'ANAT-DP'): 1,
#          ('barely', 'ANAT-DP'): 1,
#          ('approximately 12 cm', 'ANAT-DP'): 1,
#          ('approximately 2 cm', 'ANAT-DP'): 1,
#          ('apices', 'ANAT-DP'): 1,
#          ('loculated', 'ANAT-DP'): 1,
#          ('fifith', 'ANAT-DP'): 1,
#          ('configuration', 'ANAT-DP'): 1,
#          ('skin', 'ANAT-DP'): 1,
#          ('institial', 'ANAT-DP'): 1,
#          ('AP', 'ANAT-DP'): 1,
#          ('diameter', 'ANAT-DP'): 1,
#          ('Lower', 'ANAT-DP'): 1,
#          ('superior vena cava', 'ANAT-DP'): 1,
#          ('veins', 'ANAT-DP'): 1,
#          ('knuckle', 'ANAT-DP'): 1,
#          ('fifth', 'ANAT-DP'): 1,
#          ('lingular', 'ANAT-DP'): 1,
#          ('valvular', 'ANAT-DP'): 1,
#          ('infrahilar', 'ANAT-DP'): 1,
#          ('Midline', 'ANAT-DP'): 1,
#          ('pulmonic', 'ANAT-DP'): 1,
#          ('5 cm above', 'ANAT-DP'): 1,
#          ('Median', 'ANAT-DP'): 1,
#          ('cardia', 'ANAT-DP'): 1,
#          ('mild', 'ANAT-DP'): 1,
#          ('shape', 'ANAT-DP'): 1,
#          ('Thoracic', 'ANAT-DP'): 1,
#          ('PARENCHYMAL', 'ANAT-DP'): 1,
#          ('LUNG', 'ANAT-DP'): 1,
#          ('SIZE', 'ANAT-DP'): 1,
#          ('HILAR', 'ANAT-DP'): 1,
#          ('MEDIASTINAL', 'ANAT-DP'): 1,
#          ('STRUCTURES', 'ANAT-DP'): 1,
#          ('AZYGOS', 'ANAT-DP'): 1,
#          ('LOBE', 'ANAT-DP'): 1,
#          ('remainder', 'ANAT-DP'): 1,
#          ('midlung', 'ANAT-DP'): 1,
#          ('Hemidiaphragm', 'ANAT-DP'): 1,
#          ('mainstem', 'ANAT-DP'): 1,
#          ('bronchus', 'ANAT-DP'): 1,
#          ('medially', 'ANAT-DP'): 1,
#          ('multiple', 'ANAT-DP'): 1,
#          ('lateral structures', 'ANAT-DP'): 1,
#          ('left arm', 'ANAT-DP'): 1,
#          ('transverse', 'ANAT-DP'): 1,
#          ('process', 'ANAT-DP'): 1,
#          ('L 2 through L 4', 'ANAT-DP'): 1,
#          ('posteriorly', 'ANAT-DP'): 1,
#          ('ninth', 'ANAT-DP'): 1,
#          ('contents', 'ANAT-DP'): 1,
#          ('4 cm above', 'ANAT-DP'): 1,
#          ('Apical', 'ANAT-DP'): 1,
#          ('emphysema', 'ANAT-DP'): 1,
#          ('inferior', 'ANAT-DP'): 1,
#          ('field', 'ANAT-DP'): 1,
#          ('normal', 'ANAT-DP'): 1,
#          ('subcutaneus', 'ANAT-DP'): 1,
#          ('otherwise', 'ANAT-DP'): 1,
#          ('T 5 through T 9', 'ANAT-DP'): 1,
#          ('of T 5 through T 9', 'ANAT-DP'): 1,
#          ('intrafissural', 'ANAT-DP'): 1,
#          ('pectus', 'ANAT-DP'): 1,
#          ('excavatum', 'ANAT-DP'): 1,
#          ('Pectus', 'ANAT-DP'): 1,
#          ('Left sided', 'ANAT-DP'): 1,
#          ('subpulmonic', 'ANAT-DP'): 1,
#          ('structure', 'ANAT-DP'): 1,
#          ('Soft tissue', 'ANAT-DP'): 1,
#          ('interspace', 'ANAT-DP'): 1,
#          ('bibasal', 'ANAT-DP'): 1,
#          ('rightward', 'ANAT-DP'): 1,
#          ('Vasculature', 'ANAT-DP'): 1,
#          ('Perihilar', 'ANAT-DP'): 1,
#          ('pylorus', 'ANAT-DP'): 1,
#          ('superior cavoatrial junction', 'ANAT-DP'): 1,
#          ('subsegmental', 'ANAT-DP'): 1,
#          ('grossly', 'ANAT-DP'): 1,
#          ('predominantly', 'ANAT-DP'): 1,
#          ('fissural', 'ANAT-DP'): 1,
#          ('bones', 'ANAT-DP'): 1,
#          ('in', 'ANAT-DP'): 1,
#          ('duodenum', 'ANAT-DP'): 1,
#          ('approximately 2.3 cm', 'ANAT-DP'): 1,
#          ('3.5 cm above', 'ANAT-DP'): 1,
#          ('4.7 cm above', 'ANAT-DP'): 1,
#          ('2.8 cm above', 'ANAT-DP'): 1,
#          ('segment', 'ANAT-DP'): 1,
#          ('out of view', 'ANAT-DP'): 1,
#          ('withdrawn 1 cm', 'ANAT-DP'): 1,
#          ('2.9 cm above', 'ANAT-DP'): 1,
#          ('3.4 cm', 'ANAT-DP'): 1,
#          ('3.6 cm above', 'ANAT-DP'): 1,
#          ('inlet', 'ANAT-DP'): 1,
#          ('visualized', 'ANAT-DP'): 1,
#          ('under', 'ANAT-DP'): 1,
#          ('CP', 'ANAT-DP'): 1,
#          ('infectious', 'ANAT-DP'): 1,
#          ('great', 'ANAT-DP'): 1,
#          ('vessel', 'ANAT-DP'): 1,
#          ('6 cm above', 'ANAT-DP'): 1,
#          ('opacities', 'ANAT-DP'): 1,
#          ('7 cm', 'ANAT-DP'): 1,
#          ('juxta', 'ANAT-DP'): 1,
#          ('GE junction', 'ANAT-DP'): 1,
#          ('parts', 'ANAT-DP'): 1,
#          ('Low', 'ANAT-DP'): 1,
#          ('seventh', 'ANAT-DP'): 1,
#          ('Remainder', 'ANAT-DP'): 1,
#          ('skeletal', 'ANAT-DP'): 1,
#          ('pedicle', 'ANAT-DP'): 1,
#          ('underneath', 'ANAT-DP'): 1,
#          ('shadows', 'ANAT-DP'): 1,
#          ('thoracolumbar junction', 'ANAT-DP'): 1,
#          ('compartment', 'ANAT-DP'): 1,
#          ('nodule', 'ANAT-DP'): 1,
#          ('Lateral', 'ANAT-DP'): 1,
#          ('sinuses', 'ANAT-DP'): 1,
#          ('dependent', 'ANAT-DP'): 1,
#          ('posteroinferior', 'ANAT-DP'): 1,
#          ('paraspinal', 'ANAT-DP'): 1,
#          ('cutaneous', 'ANAT-DP'): 1,
#          ('8 cm above', 'ANAT-DP'): 1,
#          ('dorsolateral part', 'ANAT-DP'): 1,
#          ('enlarged', 'ANAT-DP'): 1,
#          ('Coronary', 'ANAT-DP'): 1,
#          ('PULMONARY', 'ANAT-DP'): 1,
#          ('BILATERAL', 'ANAT-DP'): 1,
#          ('PLEURAL', 'ANAT-DP'): 1,
#          ('BASILAR', 'ANAT-DP'): 1,
#          ('peripherally', 'ANAT-DP'): 1,
#          ('Multiple', 'ANAT-DP'): 1,
#          ('loops', 'ANAT-DP'): 1,
#          ('small', 'ANAT-DP'): 1,
#          ('bowel', 'ANAT-DP'): 1,
#          ('4.6 cm above', 'ANAT-DP'): 1,
#          ('pleural - based', 'ANAT-DP'): 1,
#          ('sided', 'ANAT-DP'): 1,
#          ('approximately 5 cm', 'ANAT-DP'): 1,
#          ('gastroesophageal', 'ANAT-DP'): 1,
#          ('side port', 'ANAT-DP'): 1,
#          ('5.6 cm', 'ANAT-DP'): 1,
#          ('1.8 cm above', 'ANAT-DP'): 1,
#          ('costal', 'ANAT-DP'): 1,
#          ('cartilage', 'ANAT-DP'): 1,
#          ('peripheral', 'ANAT-DP'): 1,
#          ('mid - to - distal', 'ANAT-DP'): 1,
#          ('side', 'ANAT-DP'): 1,
#          ('Hila', 'ANAT-DP'): 1,
#          ('cavitary', 'ANAT-DP'): 1,
#          ('plerual', 'ANAT-DP'): 1,
#          ('outer margin', 'ANAT-DP'): 1,
#          ('in the expected positions', 'ANAT-DP'): 1,
#          ('Central', 'ANAT-DP'): 1,
#          ('biventricular', 'ANAT-DP'): 1,
#          ('Base', 'ANAT-DP'): 1,
#          ('glenohumeral', 'ANAT-DP'): 1,
#          ('acromioclavicular', 'ANAT-DP'): 1,
#          ('joints', 'ANAT-DP'): 1,
#          ('Interstitial', 'ANAT-DP'): 1,
#          ('angles', 'ANAT-DP'): 1,
#          ('Peripheral', 'ANAT-DP'): 1,
#          ('interstitium', 'ANAT-DP'): 1,
#          ('T 12 vertebral', 'ANAT-DP'): 1,
#          ('Thoracolumbar', 'ANAT-DP'): 1,
#          ('scapular', 'ANAT-DP'): 1,
#          ('other', 'ANAT-DP'): 1,
#          ('locations', 'ANAT-DP'): 1,
#          ('intersitial', 'ANAT-DP'): 1,
#          ('tricuspid', 'ANAT-DP'): 1,
#          ('takeoff', 'ANAT-DP'): 1,
#          ('Visceral', 'ANAT-DP'): 1,
#          ('regions', 'ANAT-DP'): 1,
#          ('Trachea', 'ANAT-DP'): 1,
#          ('deviated', 'ANAT-DP'): 1,
#          ('Both', 'ANAT-DP'): 1,
#          ('appearance', 'ANAT-DP'): 1,
#          ('Bronchovascular', 'ANAT-DP'): 1,
#          ('advanced by at least 11 cm', 'OBS-DP'): 1,
#          ("patient 's chin", 'OBS-DP'): 1,
#          ('Gaseous', 'OBS-DP'): 1,
#          ('distension', 'OBS-DP'): 1,
#          ('Standard', 'OBS-DP'): 1,
#          ('The side - port', 'OBS-DP'): 1,
#          ('side ports', 'OBS-DP'): 1,
#          ('Limited', 'OBS-DP'): 1,
#          ('negative', 'OBS-DP'): 1,
#          ('frontal', 'OBS-DP'): 1,
#          ('underinflated', 'OBS-DP'): 1,
#          ('The lateral view is limited', 'OBS-DP'): 1,
#          ("patient 's arms", 'OBS-DP'): 1,
#          ('They', 'OBS-DP'): 1,
#          ('recent exam from ___', 'OBS-DP'): 1,
#          ('previous exams from ___', 'OBS-DP'): 1,
#          ('Old', 'OBS-DP'): 1,
#          ('Overall', 'OBS-DP'): 1,
#          ('Evaluation is limited', 'OBS-DP'): 1,
#          ("patient 's head", 'OBS-DP'): 1,
#          ('visualized', 'OBS-DP'): 1,
#          ('increasing', 'OBS-DP'): 1,
#          ('loculation', 'OBS-DP'): 1,
#          ('subjacent', 'OBS-DP'): 1,
#          ('TIPS', 'OBS-DP'): 1,
#          ('not well assessed', 'OBS-DP'): 1,
#          ('hypertension', 'OBS-DP'): 1,
#          ('Enlarged', 'OBS-DP'): 1,
#          ('atrium', 'OBS-DP'): 1,
#          ('failure', 'OBS-DP'): 1,
#          ('layer', 'OBS-DP'): 1,
#          ('dependently', 'OBS-DP'): 1,
#          ('peculiar', 'OBS-DP'): 1,
#          ('shape', 'OBS-DP'): 1,
#          ('not less distinct', 'OBS-DP'): 1,
#          ('out of review', 'OBS-DP'): 1,
#          ('lower', 'OBS-DP'): 1,
#          ('posttraumatic', 'OBS-DP'): 1,
#          ('Nonspecific', 'OBS-DP'): 1,
#          ('convex', 'OBS-DP'): 1,
#          ('S type', 'OBS-DP'): 1,
#          ('Elevation', 'OBS-DP'): 1,
#          ('Air', 'OBS-DP'): 1,
#          ('obstructive', 'OBS-DP'): 1,
#          ('post CABG', 'OBS-DP'): 1,
#          ('appropriately', 'OBS-DP'): 1,
#          ('elongation', 'OBS-DP'): 1,
#          ('Improving', 'OBS-DP'): 1,
#          ('accentuation', 'OBS-DP'): 1,
#          ('Tortuosity', 'OBS-DP'): 1,
#          ('Ovoid', 'OBS-DP'): 1,
#          ('Supportive', 'OBS-DP'): 1,
#          ('midline', 'OBS-DP'): 1,
#          ('Opacification', 'OBS-DP'): 1,
#          ('Monitoring', 'OBS-DP'): 1,
#          ('caliber', 'OBS-DP'): 1,
#          ('demineralization', 'OBS-DP'): 1,
#          ('Well', 'OBS-DP'): 1,
#          ('vascularity', 'OBS-DP'): 1,
#          ('faint', 'OBS-DP'): 1,
#          ('in extent', 'OBS-DP'): 1,
#          ('Discrete', 'OBS-DP'): 1,
#          ('migrated', 'OBS-DP'): 1,
#          ('proximally', 'OBS-DP'): 1,
#          ('horizontal', 'OBS-DP'): 1,
#          ('other', 'OBS-DP'): 1,
#          ('homogeneous', 'OBS-DP'): 1,
#          ('symmetrical', 'OBS-DP'): 1,
#          ('vessel on end', 'OBS-DP'): 1,
#          ('Consolidative', 'OBS-DP'): 1,
#          ('NORMAL', 'OBS-DP'): 1,
#          ('accessory', 'OBS-DP'): 1,
#          ('azygos', 'OBS-DP'): 1,
#          ('fissure', 'OBS-DP'): 1,
#          ('Crowding', 'OBS-DP'): 1,
#          ('decompensated', 'OBS-DP'): 1,
#          ('Calcific', 'OBS-DP'): 1,
#          ('gallbladder', 'OBS-DP'): 1,
#          ('crowding of', 'OBS-DP'): 1,
#          ('crowd', 'OBS-DP'): 1,
#          ('vasculature', 'OBS-DP'): 1,
#          ('in standard position', 'OBS-DP'): 1,
#          ('side holes', 'OBS-DP'): 1,
#          ('dual', 'OBS-DP'): 1,
#          ('3.5 cm', 'OBS-DP'): 1,
#          ...})

# %% [markdown]
# ## Discussion about the result from RadGraph
#
# cardiomediastinal
# 要被分成carido，mediastinal
# Heart (C0018787)
# Mediastinal (C1522718)
#
#
# 这里的500标准数据，其实也不可靠，没有考虑到嵌套和后续的可能的标准花处理，比如分割复合单词。
# - 是个很rough的数据。
#
# 我们在这里要多做一步。我称之为 简单实体 to 标准化实体。
# - 这一步用生产式AI，就像上面的例子，很好用。
# - 或者用规则，也可以。
#
# 为后续的normalization做准备。

# %% [markdown]
# 鉴于这个结果，我们可以做一些更实际的应用层面上的工作。

# %%
unique_second_elements = {token[1] for token in all_tokens}

print(unique_second_elements)

num_unique_second_elements = len(unique_second_elements)
print(num_unique_second_elements)

type_counts = {}
for token in all_tokens:
    token_type = token[1]
    if token_type in type_counts:
        type_counts[token_type] += 1
    else:
        type_counts[token_type] = 1

print(type_counts)

# Filter the tokens to include only ANAT-DP tokens
anat_dp_tokens = [token for token in all_tokens if token[1] == 'ANAT-DP']

# Print the content of ANAT-DP tokens
for token in anat_dp_tokens:
    print(token[0])
# Out:
# {'ANAT-DP', 'OBS-DP', 'OBS-U', 'OBS-DA'}
# 4
# {'OBS-DP': 812, 'ANAT-DP': 398, 'OBS-DA': 153, 'OBS-U': 190}
# superior
# of T 5 through T 9
# structures
# knuckle
# pectus
# internal jugular
# lower
# diameter
# valve
# volumes
# fifith
# heart
# barely
# vascularity
# AP
# Cardiac
# cutaneous
# nodule
# CP
# sided
# gastroesophageal
# AZYGOS
# CARDIAC
# border
# Vasculature
# first
# infectious
# skin
# near
# Median
# aorta
# L 2 through L 4
# BASILAR
# axilla
# contour
# Lower
# paratracheal
# hilus
# locations
# margin
# left arm
# bases
# valvular
# Interstitial
# spine
# esophagus
# lateral structures
# subpulmonic
# superior cavoatrial junction
# 3.4 cm
# mid - to - distal
# interspace
# lingula
# duodenum
# Bibasilar
# basilar
# adjacent
# Pectus
# 4 cm above
# mediastinum
# thoracolumbar junction
# biapical
# LOBE
# cardiac
# Pleural
# costal
# apex
# angle
# right
# aspect
# atrium
# vertebral
# medial
# hilar
# posteriorly
# alveolar
# loculated
# excavatum
# Left sided
# vein
# 5.6 cm
# coronary
# contents
# Multiple
# approximately 2.3 cm
# biventricular
# beneath
# mild
# Bronchial
# spinal
# Lateral
# bones
# peripherally
# cardia
# other
# chest
# tricuspid
# Sternal
# transverse
# Left - sided
# bibasilar
# Heart
# seventh
# STRUCTURES
# both
# thorax
# retrocardiac
# Mediastinal
# fissural
# area
# hemithorax
# bronchial
# pleural
# 4.3 cm
# ribs
# middle
# Trachea
# lungs
# skeletal
# approximately 12 cm
# multiple
# otherwise
# Rib
# joints
# stomach
# within
# visualized
# grossly
# soft tissues
# pericardial
# shape
# osseous
# Vascular
# 7 cm
# 6 cm above
# upper
# major
# cavoatrial
# thyroid
# midlung
# Retrocardiac
# thoracic
# rib
# process
# ventricular
# Thoracolumbar
# zone
# 5 cm above
# wall
# low
# BILATERAL
# Left
# Right
# sternal
# surfaces
# approximately 5 cm
# diaphragms
# withdrawn 1 cm
# infrahilar
# great
# approximately 1.8 cm
# Hemidiaphragm
# Bony
# posteroinferior
# Lung
# under
# below
# juxta
# GE
# region
# vessels
# cartilage
# interstitium
# Hila
# 4.6 cm above
# approximately a 4.6 cm
# interstitial
# artery
# volume
# midline
# peripheral
# eighth
# Right - sided
# portion
# hila
# out of view
# Bronchovascular
# scapula
# third
# outer margin
# Visceral
# airspace
# lumbar
# deviated
# side
# PARENCHYMAL
# contours
# parenchymal
# size
# SIZE
# proximal
# Peripheral
# subcutaneous
# PULMONARY
# AC
# pleural - based
# apical
# glenohumeral
# bilaterally
# internal
# pedicle
# Lungs
# 3 cm above
# normal
# subdiaphragmatic
# 3.5 cm above
# intravascular
# fifth
# fissure
# bony
# approximately 2 cm
# distal
# acromioclavicular
# second
# humeral
# dorsolateral part
# bodies
# position
# Osseous
# brachiocephalic
# bronchovascular
# pylorus
# superior vena cava
# dependent
# sinus
# Biapical
# subclavian
# bronchus
# body
# configuration
# arteries
# institial
# posterior
# axillary
# T 5 through T 9
# areas
# Base
# bilateral
# vasculature
# silhouettes
# 2.9 cm above
# paraspinal
# lingular
# Both
# right sided
# emphysema
# 3.6 cm above
# SILHOUETTE
# compartment
# ninth
# loops
# segment
# enlarged
# laterally
# abdomen
# Mediastinum
# diaphragm
# arch
# sinuses
# side port
# intrathoracic
# clavicle
# intrafissural
# HILAR
# junction
# Coronary
# in
# mid
# rightward
# Soft tissue
# Spinal
# cavitary
# Upper
# bibasal
# joint
# Subcutaneous
# mainstem
# apices
# Thoracic
# Hilar
# fourth
# aortic
# Pulmonary
# periphery
# appearance
# 8 cm above
# underneath
# Vertebral
# plerual
# main
# Midline
# extreme
# silhouette
# nipple
# regions
# azygos
# trachea
# hemidiaphragm
# inferior
# Bilateral
# shadows
# esophagogastric
# 4.7 cm above
# knob
# intersitial
# subcutaneus
# right side
# vascular
# medially
# ribcage
# venous
# MEDIASTINAL
# LUNG
# remainder
# parts
# pulmonic
# pulmonary
# cage
# ventricle
# basal
# SVC
# 1.8 cm above
# costophrenic
# takeoff
# portions
# jugular
# left
# central
# fundus
# minor
# peribronchial
# GE junction
# carina
# lateral
# suprahilar
# left sided
# neck
# 2.8 cm above
# mediastinal
# left - sided
# quadrant
# cavoatrial junction
# PLEURAL
# vessel
# Aorta
# scapular
# lobes
# parenchyma
# Low
# perihilar
# anterior
# IJ
# head
# gastric
# Remainder
# Cardiomediastinal
# predominantly
# Aortic
# T 12 vertebral
# small
# bowel
# soft tissue
# lung
# airway
# structure
# opacities
# angles
# Apical
# lobe
# subsegmental
# right - sided
# Central
# lobar
# in the expected positions
# cardiomediastinal
# cardiopulmonary
# base
# Perihilar
# inlet
# field
# cervical
# over
# hemidiaphragms
# Superiorly
# descending
# mitral
# veins
# thoracolumbar

# %% [markdown]
# entity: 12388
# unique: 1250

# %%
relations = set()

i = 0

# Step 1: Iterate through each document in train_data
for document_key in train_data:
    # Access the 'entities' for the current document
    entities = train_data[document_key]['entities']
    
    # Step 2: Iterate through each entity in 'entities'
    for entity_key in entities:
        # Access the entity and its relations
        entity = entities[entity_key]
        entity_relations = entity['relations']
        
        # Step 3: Iterate through each relation in 'entity_relations'
        for relation in entity_relations:
            # Extract the related entity key and relation type
            related_entity_key = relation[1]
            relation_type = relation[0]
            
            # Get the related entity
            related_entity = entities[related_entity_key]
            
            # Create a tuple with entity1, entity2, and relation
            relation_tuple = (entity['tokens'], related_entity['tokens'], relation_type)
            
            # Add the relation tuple to the set of relations
            relations.add(relation_tuple)

            i += 1

# At this point, 'relations' contains all the relations between entities in the 'train_data'
print(len(relations))
print(i)
# print(relations)
# Out:
# 3363
# 9251

# %% [markdown]
# 3300 relations

# %% [markdown]
# ## neo4j database setup

# %%
from py2neo import Graph, Node, Relationship

# 连接到Neo4j数据库
# graph = Graph("bolt://localhost:7689", auth=("neo4j", "neo4j"))

# 创建节点
# alice = Node("Person", name="Alice", age=25)
# bob = Node("Person", name="Bob", age=30)
# graph.create(alice)
# graph.create(bob)

# # 创建关系
# alice_knows_bob = Relationship(alice, "KNOWS", bob)
# graph.create(alice_knows_bob)

# %% [markdown]
# # RadGraph 75 dev set

# %%
import json
from pprint import pprint

# path = '/DATA1/llm-research/RadGraph/physionet.org/files/radgraph/1.0.0/train.json'
path = '/DATA1/llm-research/RadGraph/physionet.org/files/radgraph/1.0.0/dev.json'


with open(path, 'r') as f:
    train_data = json.load(f)
# Out:
# Length of data: 75
# First 10 keys of data: ['p10/p10003412/s59172281.txt', 'p18/p18001816/s54309228.txt', 'p15/p15003878/s57380048.txt', 'p15/p15003878/s59424963.txt', 'p15/p15003878/s54410100.txt', 'p15/p15003878/s56836141.txt', 'p15/p15003878/s55982972.txt', 'p15/p15003878/s55991257.txt', 'p15/p15003878/s51651577.txt', 'p15/p15003878/s51266756.txt']

# %% [markdown]
# ## to nen file

# %%
import json
import pprint

# Step 1: Initialize an empty dictionary to store all unique entities
# structure: label: {entity: {normalization: null, reports: list}}
all_unique_entities_dict = {}

# list of all entities
i = 0

# Step 2: Iterate through each report in the train_data
for report_key, report_data in train_data.items():
    for entity_id, entity_info in report_data['entities'].items():
        i += 1
        entity = entity_info['tokens']
        label = entity_info['label']
        start_ix = entity_info['start_ix']
        end_ix = entity_info['end_ix']



        if entity not in all_unique_entities_dict:
            all_unique_entities_dict[entity] = {
                'label': label,
                'reports': [
                    {report_key: 
                        {   'start_ix': start_ix, 
                            'end_ix': end_ix
                        }
                    }
                ],
                'normalization': None
            }
        else:
            all_unique_entities_dict[entity]['reports'].append(
                {report_key: 
                    {   'start_ix': start_ix, 
                        'end_ix': end_ix
                    }
                }
            )

# len of all_unique_entities_dict
print('Length of all_unique_entities_dict:', len(all_unique_entities_dict))
print('Number of entities:', i)

# Save Output all_entities to a JSON file
path = '../resource/all_unique_entities_dev.json'
with open(path , 'w', encoding='utf-8') as f:
    json.dump(all_unique_entities_dict, f, ensure_ascii=False, indent=4)

print(f"All entities have been saved to '{path}'")
# Out:
# Length of all_unique_entities_dict: 482
# Number of entities: 2191
# All entities have been saved to '../resource/all_unique_entities_dev.json'

# %% [markdown]
# ## from dev.json to unique_entities_dev.csv

# %%
# all_unique_entities_dict is json
# json has entity, (label, reports: list, normalization)
# csv has name,ui,normalized_name,semanticTypes,definition

import csv
import json
import pprint

all_unique_entities_dict

# creat csv, entity = name
file_path = '../resource/not_normalized_dev.csv'
with open(file_path, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['name', 'ui', 'normalized_name', 'semanticTypes', 'definition'])
    for entity, entity_info in all_unique_entities_dict.items():
        writer.writerow([entity, '', '', '', ''])

print(f"CSV file has been saved to '{file_path}'")
# Out:
# CSV file has been saved to '../resource/not_normalized_dev.csv'

# %% [markdown]
# # whole RadGraph 500

# %%
import json
from pprint import pprint

path = '/DATA1/llm-research/RadGraph/physionet.org/files/radgraph/1.0.0/train.json'


with open(path, 'r') as f:
    train_data = json.load(f)

path = '/DATA1/llm-research/RadGraph/physionet.org/files/radgraph/1.0.0/dev.json'
with open(path, 'r') as f:
    dev_data = json.load(f)

# combine train_data and dev_data
train_data.update(dev_data)

# len of data
print('Length of data:', len(train_data))
# Out:
# Length of data: 500

# %%
import json
import pprint

train_data

# Step 1: Initialize an empty dictionary to store all unique entities
# structure: label: {entity: {normalization: null, reports: list}}
all_unique_entities_dict = {}

# list of all entities
i = 0

# Step 2: Iterate through each report in the train_data
for report_key, report_data in train_data.items():
    for entity_id, entity_info in report_data['entities'].items():
        i += 1
        entity = entity_info['tokens']
        label = entity_info['label']
        start_ix = entity_info['start_ix']
        end_ix = entity_info['end_ix']


        if entity not in all_unique_entities_dict:
            all_unique_entities_dict[entity] = {
                'label': label,
                'reports': [
                    {report_key: 
                        {   'start_ix': start_ix, 
                            'end_ix': end_ix
                        }
                    }
                ],
                'normalization': None
            }
        else:
            all_unique_entities_dict[entity]['reports'].append(
                {report_key: 
                    {   'start_ix': start_ix, 
                        'end_ix': end_ix
                    }
                }
            )

# len of all_unique_entities_dict
print('Length of all_unique_entities_dict:', len(all_unique_entities_dict))
print('Number of entities:', i)


# creat csv, entity = name
# file_path = '../resource/not_normalized.csv'
# with open(file_path, 'w', newline='') as f:
#     writer = csv.writer(f)
#     writer.writerow(['name', 'ui', 'normalized_name', 'semanticTypes', 'definition'])
#     for entity, entity_info in all_unique_entities_dict.items():
#         writer.writerow([entity, '', '', '', ''])

# print(f"CSV file has been saved to '{file_path}'")
# Out:
# Length of all_unique_entities_dict: 1353
# Number of entities: 14579

# %% [markdown]
# ## read from train.js

# %%
file_path = '../resource/not_normalized.csv'
# Read the data from the CSV file
data = []
with open(file_path, 'r', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        data.append(row)

    
# Print the length of the data
print(f"Length of data: {len(data)}")
# Out:
# Length of data: 1353
