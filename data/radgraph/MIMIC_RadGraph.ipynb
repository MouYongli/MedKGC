# %% [markdown]
# # MIMIC
# location:
# - /DATA1/llm-research/MIMIC-CXR
#
# number of studies:
# - 227,835 radiology studies

# %% [markdown]
# # Chexpert

# %% [markdown]
# # RadGraph
# location:
# - /DATA1/llm-research/RadGraph/physionet.org/files/radgraph/1.0.0/
#
# file:
# - train.json
# - 425 reports
# - source: {'MIMIC-CXR'}
#
# file:
# - dev.json
# - 75 reports (15%)
# - source: {'MIMIC-CXR'}
#
# file:
# - test.json
# - 100 reports
# - source: {'MIMIC-CXR', 'CheXpert'}
#
# Paper RadGraph
# > We release a development dataset, which contains board-certified radiologist annotations for 500 radiology reports from the MIMIC-CXR dataset (14,579 entities and 10,889 relations), and a test dataset, which contains two independent sets of board-certified radiologist annotations for 100 radiology reports split equally across the MIMIC-CXR and CheXpert datasets.
#
# ## Summary of train.json

# %%
path = 'original/train.json'
# path = '/DATA1/llm-research/RadGraph/physionet.org/files/radgraph/1.0.0/dev.json'
# path = '../resource/radgraph/train_dev.json'

import json
from pprint import pprint

with open(path, 'r') as f:
    reports = json.load(f)

# Length of data
print('Length of data:', len(reports))

# Check the first report
# pprint(reports['p10/p10002428/s50444997.txt'])
# Out:
# Length of data: 425

# %% [markdown]
# ## Unique labels
# Unique labels: {'OBS-DP', 'ANAT-DP', 'OBS-U', 'OBS-DA'}

# %% [markdown]
# ## Unique entities in training.json
# Length of all_unique_entities_dict: 1250

# %%
print('Length of data:', len(reports))


import json
import pprint

all_unique_entities_dict = {}

i = 0

########## Iterate reports
for report_key, report_data in reports.items():

    # ############ retrieve entities
    for entity_id, entity_info in report_data['entities'].items():
        i += 1

        entity = entity_info['tokens']
        label = entity_info['label']
        start_ix = entity_info['start_ix']
        end_ix = entity_info['end_ix']

        if entity not in all_unique_entities_dict:
            all_unique_entities_dict[entity] = {
                'label': label,
                'reports': {
                    report_key: {
                        'start_ix': start_ix,
                        'end_ix': end_ix,
                        'text': report_data['text']
                    }
                }
            }
        else:
            all_unique_entities_dict[entity]['reports'][report_key] = {
                'start_ix': start_ix,
                'end_ix': end_ix,
                'text': report_data['text']
            }

# len of all_unique_entities_dict
print('Length of all_unique_entities_dict:', len(all_unique_entities_dict))
print('Number of entities:', i)

################ Save Output all_entities to a JSON file
# path = '../resource/all_unique_entities.json'
# with open(path, 'w', encoding='utf-8') as f:
#     json.dump(all_unique_entities_dict, f, ensure_ascii=False, indent=4)

# print(f"All entities have been saved to {path}")
# Out:
# Length of data: 425
# Length of all_unique_entities_dict: 1250
# Number of entities: 12388

# %% [markdown]
# ## sorted by label (e.g. ANATOMY, OBSERVATION, etc.)

# %%
import json
import pprint

# Step 1: Initialize an empty dictionary to store all unique entities
# structure: label: {entity: {normalization: null, reports: list}}
all_entities = {}

# Step 2: Iterate through each report in the train_data
for report_key, report_data in train_data.items():
    if 'entities' in report_data:
        # Step 3: Iterate through each entity in 'entities'
        for entity_id, entity_info in report_data['entities'].items():
            # get 'tokens' as entity
            entity = entity_info['tokens']
            # get 'label' as label
            label = entity_info['label']
            
            # if label not in all_entities
            if label not in all_entities:
                # add new label with entity, normalization, and report_key
                all_entities[label] = {entity: {'normalization': None, 'reports': [report_key]}}
            else:
                # if entity not in all_entities[label]
                if entity not in all_entities[label]:
                    # add new entity with normalization and report_key
                    all_entities[label][entity] = {'normalization': None, 'reports': [report_key]}
                else:
                    # update existing entity with new report_key
                    all_entities[label][entity]['reports'].append(report_key)

# Print the results for 'ANAT-DP' label
pprint.pprint(all_entities['ANAT-DP'])

# Print the number of unique entities for 'ANAT-DP' label
print(f"Number of unique 'ANAT-DP' entities: {len(all_entities['ANAT-DP'])}")

# Output all_entities to a JSON file
with open('all_entities.json', 'w', encoding='utf-8') as f:
    json.dump(all_entities, f, ensure_ascii=False, indent=4)

print("All entities have been saved to 'all_entities.json'")
# Out:
# {'1.8 cm above': {'normalization': None,
#                   'reports': ['p10/p10002428/s59659695.txt',
#                               'p10/p10002428/s59659695.txt']},
#  '2.8 cm above': {'normalization': None,
#                   'reports': ['p15/p15007517/s52317711.txt']},
#  '2.9 cm above': {'normalization': None,
#                   'reports': ['p15/p15009504/s51227163.txt']},
#  '3 cm above': {'normalization': None,
#                 'reports': ['p15/p15006483/s59006665.txt',
#                             'p15/p15006483/s57012181.txt']},
#  '3.4 cm': {'normalization': None, 'reports': ['p15/p15009504/s58857907.txt']},
#  '3.5 cm above': {'normalization': None,
#                   'reports': ['p15/p15007517/s59416262.txt']},
#  '3.6 cm above': {'normalization': None,
#                   'reports': ['p15/p15009504/s52538987.txt']},
#  '4 cm above': {'normalization': None,
#                 'reports': ['p18/p18010079/s55080309.txt']},
#  '4.3 cm': {'normalization': None, 'reports': ['p18/p18004941/s52289350.txt']},
#  '4.6 cm above': {'normalization': None,
#                   'reports': ['p10/p10002428/s56836542.txt']},
#  '4.7 cm above': {'normalization': None,
#                   'reports': ['p15/p15007517/s50648100.txt']},
#  '5 cm above': {'normalization': None,
#                 'reports': ['p18/p18026902/s57297476.txt']},
#  '5.6 cm': {'normalization': None, 'reports': ['p10/p10002428/s56597576.txt']},
#  '6 cm above': {'normalization': None,
#                 'reports': ['p10/p10004235/s52379321.txt',
#                             'p10/p10004235/s52379321.txt']},
#  '7 cm': {'normalization': None,
#           'reports': ['p10/p10004235/s57318275.txt',
#                       'p10/p10004235/s57318275.txt']},
#  '8 cm above': {'normalization': None,
#                 'reports': ['p18/p18003402/s52034419.txt']},
#  'AC': {'normalization': None,
#         'reports': ['p15/p15001834/s54486241.txt',
#                     'p15/p15001834/s58938701.txt',
#                     'p15/p15001834/s58938701.txt']},
#  'AP': {'normalization': None, 'reports': ['p15/p15165563/s54509771.txt']},
#  'AZYGOS': {'normalization': None, 'reports': ['p18/p18012427/s52470431.txt']},
#  'Aorta': {'normalization': None,
#            'reports': ['p15/p15003296/s54535760.txt',
#                        'p15/p15007487/s57478149.txt']},
#  'Aortic': {'normalization': None,
#             'reports': ['p10/p10005749/s53170451.txt',
#                         'p18/p18001922/s51753105.txt']},
#  'Apical': {'normalization': None, 'reports': ['p18/p18010079/s55080309.txt']},
#  'BASILAR': {'normalization': None, 'reports': ['p15/p15009233/s50208186.txt']},
#  'BILATERAL': {'normalization': None,
#                'reports': ['p15/p15009233/s50208186.txt']},
#  'Base': {'normalization': None, 'reports': ['p15/p15002496/s51438936.txt']},
#  'Biapical': {'normalization': None,
#               'reports': ['p15/p15003294/s51224077.txt',
#                           'p15/p15003294/s51225513.txt',
#                           'p15/p15003294/s58755630.txt',
#                           'p15/p15003294/s57007434.txt',
#                           'p18/p18003894/s58464660.txt',
#                           'p15/p15001393/s54726934.txt',
#                           'p18/p18028180/s53423151.txt']},
#  'Bibasilar': {'normalization': None,
#                'reports': ['p15/p15024484/s55357745.txt',
#                            'p15/p15024484/s55357745.txt',
#                            'p10/p10005749/s53170451.txt',
#                            'p15/p15001136/s50077246.txt',
#                            'p18/p18001922/s51753105.txt',
#                            'p15/p15003296/s54535760.txt',
#                            'p15/p15003296/s54535760.txt',
#                            'p18/p18022445/s52389030.txt',
#                            'p18/p18003894/s58464660.txt',
#                            'p10/p10003502/s53282957.txt',
#                            'p18/p18022983/s57985067.txt',
#                            'p18/p18022983/s57381264.txt',
#                            'p10/p10004235/s52379321.txt',
#                            'p10/p10004235/s52379321.txt',
#                            'p10/p10004235/s57318275.txt',
#                            'p18/p18001157/s57119564.txt',
#                            'p15/p15009233/s59402206.txt',
#                            'p15/p15009233/s59402206.txt',
#                            'p10/p10002428/s56100138.txt',
#                            'p10/p10002428/s57506266.txt']},
#  'Bilateral': {'normalization': None,
#                'reports': ['p15/p15024484/s55162960.txt',
#                            'p15/p15024484/s59036766.txt',
#                            'p10/p10004457/s55439624.txt',
#                            'p10/p10005749/s57249718.txt',
#                            'p10/p10005749/s58865310.txt',
#                            'p10/p10003502/s52139270.txt',
#                            'p18/p18000745/s59579972.txt',
#                            'p18/p18000745/s52172170.txt',
#                            'p10/p10007795/s54581957.txt',
#                            'p10/p10007795/s57677975.txt',
#                            'p15/p15007517/s50648100.txt',
#                            'p15/p15007517/s52317711.txt',
#                            'p15/p15009504/s55274948.txt',
#                            'p10/p10005368/s57426090.txt',
#                            'p18/p18001157/s59771012.txt',
#                            'p18/p18017189/s55185780.txt',
#                            'p10/p10002428/s50292543.txt',
#                            'p10/p10002428/s59015983.txt',
#                            'p10/p10002428/s57506266.txt',
#                            'p10/p10002428/s59659695.txt',
#                            'p15/p15007710/s51338738.txt',
#                            'p10/p10005024/s59581256.txt',
#                            'p15/p15001203/s50723040.txt']},
#  'Bony': {'normalization': None,
#           'reports': ['p15/p15024484/s59036766.txt',
#                       'p10/p10003956/s53245562.txt',
#                       'p10/p10002930/s55885481.txt',
#                       'p10/p10002661/s53368584.txt',
#                       'p15/p15009233/s54027174.txt',
#                       'p15/p15000393/s52116555.txt',
#                       'p15/p15001834/s58938701.txt']},
#  'Both': {'normalization': None, 'reports': ['p15/p15002643/s51061808.txt']},
#  'Bronchial': {'normalization': None,
#                'reports': ['p10/p10003019/s58365492.txt',
#                            'p18/p18011616/s59704184.txt']},
#  'Bronchovascular': {'normalization': None,
#                      'reports': ['p15/p15001834/s58938701.txt']},
#  'CARDIAC': {'normalization': None,
#              'reports': ['p18/p18012427/s52470431.txt',
#                          'p15/p15009233/s50208186.txt']},
#  'CP': {'normalization': None,
#         'reports': ['p10/p10005368/s54510564.txt',
#                     'p10/p10005368/s54510564.txt']},
#  'Cardiac': {'normalization': None,
#              'reports': ['p10/p10005749/s59735352.txt',
#                          'p10/p10005749/s53170451.txt',
#                          'p18/p18023211/s56555187.txt',
#                          'p15/p15001136/s52592881.txt',
#                          'p18/p18001922/s52288833.txt',
#                          'p15/p15165563/s57194811.txt',
#                          'p15/p15078112/s56824160.txt',
#                          'p15/p15003294/s57007434.txt',
#                          'p18/p18012427/s54748444.txt',
#                          'p15/p15003296/s54535760.txt',
#                          'p15/p15003296/s51554855.txt',
#                          'p18/p18022445/s51773947.txt',
#                          'p18/p18001942/s56433237.txt',
#                          'p15/p15002678/s54040323.txt',
#                          'p10/p10003502/s57641661.txt',
#                          'p10/p10003502/s52309364.txt',
#                          'p10/p10003502/s50084553.txt',
#                          'p18/p18028999/s58738737.txt',
#                          'p18/p18020943/s55270846.txt',
#                          'p18/p18020943/s56433279.txt',
#                          'p18/p18022983/s57985067.txt',
#                          'p15/p15009504/s55274948.txt',
#                          'p15/p15009504/s51227163.txt',
#                          'p18/p18015004/s59622916.txt',
#                          'p10/p10003637/s57024735.txt',
#                          'p10/p10003019/s53098685.txt',
#                          'p18/p18003402/s55894071.txt',
#                          'p10/p10002428/s52460896.txt',
#                          'p10/p10002428/s59891001.txt',
#                          'p10/p10002428/s55758034.txt',
#                          'p10/p10002428/s59414737.txt',
#                          'p10/p10002428/s58838312.txt',
#                          'p10/p10002428/s58851198.txt',
#                          'p10/p10002428/s54020701.txt',
#                          'p10/p10002428/s59098825.txt',
#                          'p15/p15002496/s52886085.txt',
#                          'p15/p15001474/s58221226.txt',
#                          'p15/p15002397/s57752049.txt',
#                          'p18/p18000379/s55748408.txt']},
#  'Cardiomediastinal': {'normalization': None,
#                        'reports': ['p15/p15024484/s55162960.txt',
#                                    'p15/p15024484/s59429123.txt',
#                                    'p15/p15024484/s54162490.txt',
#                                    'p18/p18023211/s59956583.txt',
#                                    'p15/p15004061/s56845046.txt',
#                                    'p15/p15078112/s59479753.txt',
#                                    'p18/p18026902/s51741672.txt',
#                                    'p15/p15007487/s53221126.txt',
#                                    'p15/p15002678/s56528605.txt',
#                                    'p15/p15002678/s50618143.txt',
#                                    'p18/p18022983/s51605945.txt',
#                                    'p15/p15006483/s57974872.txt',
#                                    'p10/p10002930/s55885481.txt',
#                                    'p10/p10007795/s54492585.txt',
#                                    'p10/p10007795/s56375093.txt',
#                                    'p15/p15007517/s58745793.txt',
#                                    'p10/p10002661/s53368584.txt',
#                                    'p15/p15003988/s51924979.txt',
#                                    'p10/p10004235/s59895508.txt',
#                                    'p10/p10003019/s58365492.txt',
#                                    'p10/p10003019/s55931751.txt',
#                                    'p18/p18001529/s58906888.txt',
#                                    'p15/p15000393/s51634677.txt',
#                                    'p15/p15000393/s52116555.txt',
#                                    'p10/p10002428/s50862960.txt',
#                                    'p10/p10002428/s51574899.txt',
#                                    'p15/p15007710/s57053735.txt',
#                                    'p18/p18000379/s57516501.txt',
#                                    'p15/p15001834/s52944718.txt',
#                                    'p15/p15001834/s50931830.txt']},
#  'Central': {'normalization': None, 'reports': ['p18/p18006842/s56350245.txt']},
#  'Coronary': {'normalization': None,
#               'reports': ['p18/p18017189/s55185780.txt']},
#  'GE': {'normalization': None,
#         'reports': ['p18/p18022445/s56006486.txt',
#                     'p10/p10002428/s56597576.txt']},
#  'GE junction': {'normalization': None,
#                  'reports': ['p18/p18015004/s57985812.txt']},
#  'HILAR': {'normalization': None, 'reports': ['p18/p18012427/s52470431.txt']},
#  'Heart': {'normalization': None,
#            'reports': ['p18/p18004941/s58034164.txt',
#                        'p18/p18003081/s52532534.txt',
#                        'p18/p18003081/s52648242.txt',
#                        'p18/p18003081/s53302126.txt',
#                        'p10/p10005749/s58865310.txt',
#                        'p18/p18001922/s51753105.txt',
#                        'p15/p15078112/s53214365.txt',
#                        'p15/p15078112/s51228277.txt',
#                        'p15/p15078112/s58703686.txt',
#                        'p18/p18026902/s59872068.txt',
#                        'p15/p15003294/s58755630.txt',
#                        'p15/p15003296/s58235657.txt',
#                        'p18/p18010079/s53957050.txt',
#                        'p18/p18010079/s55080309.txt',
#                        'p15/p15007487/s52305139.txt',
#                        'p15/p15007487/s57478149.txt',
#                        'p15/p15002538/s51219765.txt',
#                        'p15/p15002538/s51219765.txt',
#                        'p18/p18019295/s57254021.txt',
#                        'p18/p18019295/s52492192.txt',
#                        'p18/p18003894/s50954658.txt',
#                        'p15/p15002678/s59989751.txt',
#                        'p15/p15002678/s54481740.txt',
#                        'p15/p15002678/s54481740.txt',
#                        'p10/p10003502/s53282957.txt',
#                        'p18/p18022983/s57381264.txt',
#                        'p10/p10007795/s57677975.txt',
#                        'p10/p10005866/s56175428.txt',
#                        'p15/p15007517/s59740051.txt',
#                        'p15/p15003988/s51924979.txt',
#                        'p15/p15002074/s52562523.txt',
#                        'p10/p10005368/s56689183.txt',
#                        'p18/p18015004/s58110495.txt',
#                        'p18/p18015004/s56533254.txt',
#                        'p18/p18015004/s54721527.txt',
#                        'p18/p18015004/s51210113.txt',
#                        'p10/p10003637/s51461467.txt',
#                        'p10/p10003019/s55487822.txt',
#                        'p10/p10003019/s55487822.txt',
#                        'p10/p10003019/s59635047.txt',
#                        'p10/p10003019/s59607556.txt',
#                        'p15/p15001393/s54726934.txt',
#                        'p18/p18001157/s59771012.txt',
#                        'p10/p10004322/s57662923.txt',
#                        'p18/p18003402/s58269004.txt',
#                        'p18/p18017189/s55185780.txt',
#                        'p15/p15000393/s58990129.txt',
#                        'p15/p15000393/s53701643.txt',
#                        'p15/p15000393/s59128455.txt',
#                        'p15/p15000393/s59788459.txt',
#                        'p15/p15000393/s57099953.txt',
#                        'p10/p10002428/s56100138.txt',
#                        'p10/p10002428/s59258773.txt',
#                        'p10/p10002428/s58581921.txt',
#                        'p10/p10002428/s57064083.txt',
#                        'p15/p15002496/s51438936.txt',
#                        'p15/p15001474/s51737379.txt',
#                        'p15/p15007710/s57675460.txt',
#                        'p18/p18011616/s57021204.txt',
#                        'p18/p18028180/s53423151.txt',
#                        'p18/p18028180/s57601456.txt',
#                        'p18/p18028180/s55973443.txt',
#                        'p18/p18000379/s59391463.txt',
#                        'p18/p18000379/s53632378.txt']},
#  'Hemidiaphragm': {'normalization': None,
#                    'reports': ['p18/p18022445/s55421520.txt']},
#  'Hila': {'normalization': None, 'reports': ['p10/p10002428/s50027225.txt']},
#  'Hilar': {'normalization': None,
#            'reports': ['p15/p15009504/s58857907.txt',
#                        'p10/p10005368/s56689183.txt',
#                        'p18/p18017189/s54781713.txt',
#                        'p15/p15009233/s51745487.txt',
#                        'p18/p18001786/s51462360.txt',
#                        'p15/p15002397/s57752049.txt']},
#  'IJ': {'normalization': None,
#         'reports': ['p15/p15004061/s51985597.txt',
#                     'p18/p18003894/s53451407.txt',
#                     'p18/p18003894/s58464660.txt',
#                     'p18/p18028999/s57987829.txt',
#                     'p18/p18028999/s57987829.txt',
#                     'p18/p18028999/s57987829.txt',
#                     'p18/p18028999/s53725346.txt',
#                     'p15/p15007517/s58608641.txt',
#                     'p15/p15009504/s55274948.txt',
#                     'p15/p15009504/s59292871.txt',
#                     'p15/p15009504/s59292871.txt',
#                     'p15/p15009504/s51227163.txt',
#                     'p15/p15009504/s56362726.txt',
#                     'p10/p10002428/s59098825.txt']},
#  'Interstitial': {'normalization': None,
#                   'reports': ['p15/p15002496/s52886085.txt']},
#  'L 2 through L 4': {'normalization': None,
#                      'reports': ['p18/p18010079/s53957050.txt']},
#  'LOBE': {'normalization': None, 'reports': ['p18/p18012427/s52470431.txt']},
#  'LUNG': {'normalization': None, 'reports': ['p18/p18012427/s52470431.txt']},
#  'Lateral': {'normalization': None, 'reports': ['p18/p18001157/s59771012.txt']},
#  'Left': {'normalization': None,
#           'reports': ['p18/p18003081/s51438902.txt',
#                       'p10/p10005749/s54060141.txt',
#                       'p18/p18001922/s57925491.txt',
#                       'p15/p15004061/s50854153.txt',
#                       'p15/p15004061/s50854153.txt',
#                       'p15/p15078112/s59839693.txt',
#                       'p15/p15078112/s58166907.txt',
#                       'p15/p15078112/s59479753.txt',
#                       'p15/p15078112/s56824160.txt',
#                       'p18/p18026902/s58219787.txt',
#                       'p18/p18026902/s57297476.txt',
#                       'p18/p18012427/s54748444.txt',
#                       'p15/p15003296/s56457261.txt',
#                       'p18/p18010079/s59097048.txt',
#                       'p18/p18010079/s53957050.txt',
#                       'p15/p15007487/s59926921.txt',
#                       'p15/p15007487/s52305139.txt',
#                       'p15/p15007487/s57478149.txt',
#                       'p15/p15007487/s53221126.txt',
#                       'p15/p15007487/s59752695.txt',
#                       'p15/p15007487/s55512501.txt',
#                       'p15/p15007487/s58025316.txt',
#                       'p18/p18003894/s54842645.txt',
#                       'p10/p10007795/s54581957.txt',
#                       'p10/p10005866/s56175428.txt',
#                       'p15/p15007517/s51550673.txt',
#                       'p18/p18017363/s54401973.txt',
#                       'p10/p10003019/s55931751.txt',
#                       'p10/p10003019/s58505074.txt',
#                       'p15/p15000393/s58990129.txt',
#                       'p15/p15000393/s53701643.txt',
#                       'p15/p15000393/s52929930.txt',
#                       'p15/p15000393/s57099953.txt',
#                       'p15/p15000393/s55479181.txt',
#                       'p15/p15000393/s55723653.txt',
#                       'p10/p10002428/s51574899.txt',
#                       'p10/p10002428/s58838312.txt',
#                       'p10/p10002428/s50027225.txt',
#                       'p18/p18006842/s50471520.txt',
#                       'p15/p15002496/s51438936.txt',
#                       'p15/p15002496/s52886085.txt',
#                       'p15/p15001203/s50723040.txt']},
#  'Left - sided': {'normalization': None,
#                   'reports': ['p15/p15004061/s51985597.txt',
#                               'p15/p15078112/s59479753.txt',
#                               'p10/p10007795/s54054513.txt',
#                               'p10/p10003637/s51461467.txt']},
#  'Left sided': {'normalization': None,
#                 'reports': ['p18/p18003894/s53451407.txt']},
#  'Low': {'normalization': None, 'reports': ['p10/p10003637/s51371378.txt']},
#  'Lower': {'normalization': None, 'reports': ['p15/p15165563/s53383993.txt']},
#  'Lung': {'normalization': None,
#           'reports': ['p18/p18003081/s57007000.txt',
#                       'p10/p10005749/s54060141.txt',
#                       'p18/p18023211/s56555187.txt',
#                       'p15/p15004061/s51985597.txt',
#                       'p15/p15078112/s53834915.txt',
#                       'p15/p15003296/s51554855.txt',
#                       'p15/p15003296/s55162880.txt',
#                       'p15/p15007487/s53221126.txt',
#                       'p15/p15002678/s50618143.txt',
#                       'p18/p18022983/s51605945.txt',
#                       'p18/p18022983/s57985067.txt',
#                       'p18/p18017363/s54401973.txt',
#                       'p18/p18017363/s55076850.txt',
#                       'p18/p18015004/s56533254.txt',
#                       'p18/p18015004/s51210113.txt',
#                       'p18/p18015004/s51210113.txt',
#                       'p10/p10003019/s59829602.txt',
#                       'p18/p18001157/s57119564.txt',
#                       'p15/p15009233/s57930478.txt',
#                       'p15/p15001834/s58938701.txt']},
#  'Lungs': {'normalization': None,
#            'reports': ['p18/p18004941/s58821758.txt',
#                        'p18/p18003081/s53302126.txt',
#                        'p18/p18001922/s52638004.txt',
#                        'p18/p18001922/s52288833.txt',
#                        'p15/p15165563/s51659523.txt',
#                        'p15/p15004061/s56845046.txt',
#                        'p15/p15078112/s51228277.txt',
#                        'p15/p15078112/s58703686.txt',
#                        'p18/p18026902/s53920289.txt',
#                        'p18/p18026902/s51741672.txt',
#                        'p15/p15002538/s51219765.txt',
#                        'p18/p18019295/s57254021.txt',
#                        'p18/p18019295/s52492192.txt',
#                        'p10/p10002930/s55885481.txt',
#                        'p15/p15003988/s51924979.txt',
#                        'p15/p15002074/s52562523.txt',
#                        'p10/p10003637/s51461467.txt',
#                        'p15/p15000393/s59128455.txt',
#                        'p10/p10002428/s58581921.txt',
#                        'p15/p15003026/s53882677.txt',
#                        'p18/p18011616/s50630819.txt',
#                        'p18/p18028180/s53423151.txt',
#                        'p18/p18028180/s57601456.txt',
#                        'p18/p18000379/s59391463.txt',
#                        'p18/p18000379/s58920421.txt']},
#  'MEDIASTINAL': {'normalization': None,
#                  'reports': ['p18/p18012427/s52470431.txt']},
#  'Median': {'normalization': None, 'reports': ['p18/p18026902/s57297476.txt']},
#  'Mediastinal': {'normalization': None,
#                  'reports': ['p18/p18003081/s55159460.txt',
#                              'p15/p15001136/s50077246.txt',
#                              'p15/p15165563/s57008959.txt',
#                              'p15/p15003294/s58755630.txt',
#                              'p15/p15003294/s57007434.txt',
#                              'p18/p18012427/s55382203.txt',
#                              'p15/p15003296/s54535760.txt',
#                              'p10/p10003502/s57812613.txt',
#                              'p18/p18020943/s56320518.txt',
#                              'p18/p18020943/s56433279.txt',
#                              'p10/p10005866/s56175428.txt',
#                              'p18/p18015004/s59622916.txt',
#                              'p10/p10003637/s51461467.txt',
#                              'p10/p10004322/s57662923.txt',
#                              'p15/p15002496/s52886085.txt',
#                              'p15/p15007710/s57675460.txt',
#                              'p18/p18011616/s57021204.txt',
#                              'p18/p18000379/s59391463.txt',
#                              'p15/p15002643/s51061808.txt']},
#  'Mediastinum': {'normalization': None,
#                  'reports': ['p15/p15165563/s51659523.txt',
#                              'p15/p15002678/s59989751.txt']},
#  'Midline': {'normalization': None, 'reports': ['p18/p18026902/s51741672.txt']},
#  'Multiple': {'normalization': None,
#               'reports': ['p10/p10002428/s56100138.txt',
#                           'p10/p10002428/s56100138.txt']},
#  'Osseous': {'normalization': None,
#              'reports': ['p18/p18003081/s52532534.txt',
#                          'p15/p15078112/s53214365.txt',
#                          'p15/p15002957/s50480029.txt',
#                          'p10/p10002428/s58838312.txt',
#                          'p15/p15001474/s58221226.txt']},
#  'PARENCHYMAL': {'normalization': None,
#                  'reports': ['p18/p18012427/s52470431.txt',
#                              'p18/p18012427/s52470431.txt']},
#  'PLEURAL': {'normalization': None, 'reports': ['p15/p15009233/s50208186.txt']},
#  'PULMONARY': {'normalization': None,
#                'reports': ['p15/p15009233/s50208186.txt']},
#  'Pectus': {'normalization': None, 'reports': ['p10/p10003255/s52843603.txt']},
#  'Perihilar': {'normalization': None,
#                'reports': ['p10/p10003502/s53282957.txt']},
#  'Peripheral': {'normalization': None,
#                 'reports': ['p15/p15007710/s57053735.txt']},
#  'Pleural': {'normalization': None,
#              'reports': ['p10/p10007795/s56375093.txt',
#                          'p15/p15009504/s59050955.txt',
#                          'p18/p18015004/s54721527.txt',
#                          'p18/p18015004/s51210113.txt',
#                          'p10/p10002428/s59891001.txt',
#                          'p15/p15007710/s57675460.txt']},
#  'Pulmonary': {'normalization': None,
#                'reports': ['p18/p18004941/s58034164.txt',
#                            'p15/p15024484/s55357745.txt',
#                            'p15/p15165563/s57194811.txt',
#                            'p18/p18012427/s54748444.txt',
#                            'p15/p15003296/s52507068.txt',
#                            'p18/p18022445/s56006486.txt',
#                            'p18/p18022445/s51773947.txt',
#                            'p10/p10003502/s50084553.txt',
#                            'p18/p18022983/s57985067.txt',
#                            'p15/p15007517/s55042886.txt',
#                            'p10/p10004235/s52379321.txt',
#                            'p10/p10004235/s52379321.txt',
#                            'p10/p10004235/s52379321.txt',
#                            'p18/p18015004/s54721527.txt',
#                            'p18/p18001157/s59771012.txt',
#                            'p18/p18006842/s50230234.txt',
#                            'p15/p15001474/s51737379.txt',
#                            'p18/p18011616/s57021204.txt',
#                            'p18/p18028180/s57844688.txt',
#                            'p18/p18000379/s59391463.txt',
#                            'p18/p18000379/s55748408.txt']},
#  'Remainder': {'normalization': None,
#                'reports': ['p10/p10003019/s58365492.txt']},
#  'Retrocardiac': {'normalization': None,
#                   'reports': ['p18/p18026902/s55810062.txt',
#                               'p18/p18026902/s59872068.txt',
#                               'p18/p18028999/s56651721.txt',
#                               'p10/p10007795/s54317369.txt',
#                               'p15/p15007517/s55042886.txt',
#                               'p15/p15007517/s55042886.txt',
#                               'p15/p15009504/s58857907.txt',
#                               'p18/p18017363/s55076850.txt',
#                               'p18/p18017363/s55076850.txt',
#                               'p18/p18015004/s51210113.txt',
#                               'p18/p18003402/s52034419.txt',
#                               'p18/p18006842/s59376580.txt']},
#  'Rib': {'normalization': None,
#          'reports': ['p18/p18010079/s59097048.txt',
#                      'p18/p18010079/s53957050.txt']},
#  'Right': {'normalization': None,
#            'reports': ['p18/p18023211/s56555187.txt',
#                        'p15/p15165563/s53383993.txt',
#                        'p15/p15078112/s52859232.txt',
#                        'p15/p15078112/s56824160.txt',
#                        'p18/p18026902/s58219787.txt',
#                        'p18/p18026902/s57297476.txt',
#                        'p18/p18026902/s57297476.txt',
#                        'p15/p15003294/s55968942.txt',
#                        'p18/p18012427/s54748444.txt',
#                        'p15/p15003296/s58235657.txt',
#                        'p18/p18003894/s58777551.txt',
#                        'p18/p18003894/s58464660.txt',
#                        'p15/p15002678/s59989751.txt',
#                        'p15/p15002678/s50508258.txt',
#                        'p18/p18028999/s57987829.txt',
#                        'p18/p18028999/s57987829.txt',
#                        'p18/p18028999/s58738737.txt',
#                        'p18/p18020943/s55270846.txt',
#                        'p18/p18020943/s55270846.txt',
#                        'p18/p18020943/s56433279.txt',
#                        'p18/p18020943/s56433279.txt',
#                        'p18/p18022983/s52601618.txt',
#                        'p18/p18000745/s59984925.txt',
#                        'p18/p18000745/s52172170.txt',
#                        'p10/p10007795/s57677975.txt',
#                        'p15/p15007517/s58608641.txt',
#                        'p15/p15009504/s55274948.txt',
#                        'p15/p15009504/s51227163.txt',
#                        'p18/p18017363/s54401973.txt',
#                        'p10/p10005368/s57426090.txt',
#                        'p10/p10004235/s52604377.txt',
#                        'p10/p10003019/s56635465.txt',
#                        'p10/p10003019/s56635465.txt',
#                        'p10/p10003019/s55487822.txt',
#                        'p10/p10003019/s55487822.txt',
#                        'p10/p10003019/s55931751.txt',
#                        'p18/p18003402/s58269004.txt',
#                        'p15/p15009233/s51745487.txt',
#                        'p15/p15000393/s53701643.txt',
#                        'p10/p10002428/s52460896.txt',
#                        'p10/p10002428/s59891001.txt',
#                        'p10/p10002428/s59659695.txt',
#                        'p10/p10002428/s58581921.txt',
#                        'p10/p10002428/s57064083.txt',
#                        'p18/p18006842/s55078395.txt',
#                        'p15/p15002496/s50531159.txt',
#                        'p15/p15002496/s52886085.txt',
#                        'p15/p15007710/s53832381.txt',
#                        'p18/p18011616/s57021204.txt',
#                        'p18/p18000379/s53632378.txt',
#                        'p18/p18017572/s56064830.txt']},
#  'Right - sided': {'normalization': None,
#                    'reports': ['p15/p15078112/s56882127.txt',
#                                'p18/p18003894/s53451407.txt',
#                                'p18/p18000379/s57516501.txt']},
#  'SILHOUETTE': {'normalization': None,
#                 'reports': ['p18/p18012427/s52470431.txt',
#                             'p15/p15009233/s50208186.txt']},
#  'SIZE': {'normalization': None, 'reports': ['p18/p18012427/s52470431.txt']},
#  'STRUCTURES': {'normalization': None,
#                 'reports': ['p18/p18012427/s52470431.txt']},
#  'SVC': {'normalization': None,
#          'reports': ['p10/p10005749/s54040624.txt',
#                      'p15/p15004061/s51985597.txt',
#                      'p15/p15078112/s56357121.txt',
#                      'p15/p15078112/s56357121.txt',
#                      'p15/p15078112/s58166907.txt',
#                      'p15/p15078112/s59479753.txt',
#                      'p15/p15078112/s59479753.txt',
#                      'p15/p15078112/s56824160.txt',
#                      'p18/p18026902/s58219787.txt',
#                      'p18/p18026902/s59872068.txt',
#                      'p15/p15002678/s50508258.txt',
#                      'p18/p18028999/s57987829.txt',
#                      'p18/p18028999/s57987829.txt',
#                      'p18/p18028999/s57987829.txt',
#                      'p18/p18028999/s53725346.txt',
#                      'p18/p18020943/s55270846.txt',
#                      'p18/p18020943/s55270846.txt',
#                      'p15/p15006483/s59006665.txt',
#                      'p10/p10007795/s54492585.txt',
#                      'p10/p10007795/s54317369.txt',
#                      'p10/p10007795/s57677975.txt',
#                      'p10/p10007795/s57677975.txt',
#                      'p10/p10007795/s58754452.txt',
#                      'p10/p10007795/s54054513.txt',
#                      'p10/p10007795/s56375093.txt',
#                      'p10/p10004235/s52604377.txt',
#                      'p10/p10004235/s52604377.txt',
#                      'p10/p10004235/s58604118.txt',
#                      'p10/p10003019/s59339276.txt',
#                      'p18/p18003402/s52418327.txt',
#                      'p10/p10002428/s56836542.txt',
#                      'p10/p10002428/s56597576.txt',
#                      'p10/p10002428/s50027225.txt',
#                      'p18/p18028180/s50287111.txt',
#                      'p15/p15002852/s58489231.txt']},
#  'Soft tissue': {'normalization': None,
#                  'reports': ['p18/p18001942/s56433237.txt']},
#  'Spinal': {'normalization': None,
#             'reports': ['p18/p18003402/s59341192.txt',
#                         'p18/p18003402/s55894071.txt']},
#  'Sternal': {'normalization': None,
#              'reports': ['p18/p18022983/s57381264.txt',
#                          'p18/p18000745/s59579972.txt']},
#  'Subcutaneous': {'normalization': None,
#                   'reports': ['p18/p18010079/s55080309.txt',
#                               'p15/p15000393/s59788459.txt',
#                               'p18/p18017572/s51869019.txt']},
#  'Superiorly': {'normalization': None,
#                 'reports': ['p10/p10002428/s58838312.txt',
#                             'p15/p15002496/s53190310.txt']},
#  'T 12 vertebral': {'normalization': None,
#                     'reports': ['p18/p18011616/s55142338.txt']},
#  'T 5 through T 9': {'normalization': None,
#                      'reports': ['p18/p18002106/s56517301.txt',
#                                  'p18/p18002106/s56517301.txt']},
#  'Thoracic': {'normalization': None,
#               'reports': ['p15/p15002035/s52843277.txt']},
#  'Thoracolumbar': {'normalization': None,
#                    'reports': ['p18/p18011616/s50630819.txt']},
#  'Trachea': {'normalization': None, 'reports': ['p15/p15002643/s51061808.txt']},
#  'Upper': {'normalization': None,
#            'reports': ['p15/p15003294/s54302152.txt',
#                        'p10/p10004235/s58604118.txt',
#                        'p18/p18015004/s58110495.txt',
#                        'p18/p18015004/s56533254.txt',
#                        'p10/p10002428/s59258773.txt',
#                        'p18/p18000379/s56020891.txt',
#                        'p18/p18017572/s56064830.txt']},
#  'Vascular': {'normalization': None,
#               'reports': ['p18/p18001922/s50114627.txt',
#                           'p18/p18000379/s51568340.txt']},
#  'Vasculature': {'normalization': None,
#                  'reports': ['p10/p10003502/s52309364.txt']},
#  'Vertebral': {'normalization': None,
#                'reports': ['p18/p18003402/s58269004.txt',
#                            'p18/p18003402/s55894071.txt',
#                            'p18/p18003402/s52034419.txt']},
#  'Visceral': {'normalization': None,
#               'reports': ['p18/p18000379/s57516501.txt']},
#  'abdomen': {'normalization': None,
#              'reports': ['p15/p15002183/s52341485.txt',
#                          'p10/p10007795/s57491780.txt',
#                          'p10/p10007795/s54317369.txt',
#                          'p15/p15007517/s59740051.txt',
#                          'p18/p18017363/s55076850.txt',
#                          'p15/p15009233/s58131029.txt',
#                          'p15/p15002496/s52862073.txt',
#                          'p15/p15001474/s51737379.txt',
#                          'p18/p18011616/s59704184.txt',
#                          'p15/p15001834/s54265476.txt']},
#  'acromioclavicular': {'normalization': None,
#                        'reports': ['p15/p15002496/s55461318.txt']},
#  'adjacent': {'normalization': None,
#               'reports': ['p10/p10005749/s57249718.txt',
#                           'p18/p18001942/s56433237.txt',
#                           'p10/p10005866/s56175428.txt',
#                           'p10/p10003019/s59005604.txt',
#                           'p10/p10003019/s59607556.txt',
#                           'p15/p15000393/s52929930.txt']},
#  'airspace': {'normalization': None,
#               'reports': ['p15/p15024484/s55357745.txt',
#                           'p15/p15024484/s55357745.txt',
#                           'p15/p15003296/s55100464.txt',
#                           'p15/p15003296/s55100464.txt',
#                           'p15/p15006483/s54362708.txt',
#                           'p15/p15006483/s54362708.txt',
#                           'p18/p18000745/s53121171.txt',
#                           'p18/p18000745/s59984925.txt',
#                           'p18/p18000745/s52172170.txt',
#                           'p15/p15007517/s59740051.txt',
#                           'p15/p15009504/s58857907.txt',
#                           'p15/p15009504/s52538987.txt',
#                           'p15/p15009504/s52538987.txt',
#                           'p10/p10004235/s52379321.txt',
#                           'p10/p10003019/s53934356.txt',
#                           'p18/p18003402/s59341192.txt',
#                           'p15/p15007710/s51338738.txt']},
#  'airway': {'normalization': None,
#             'reports': ['p18/p18001922/s52326539.txt',
#                         'p10/p10002428/s58581921.txt']},
#  'alveolar': {'normalization': None,
#               'reports': ['p10/p10003502/s53282957.txt',
#                           'p18/p18000745/s51763935.txt',
#                           'p15/p15007517/s58745793.txt',
#                           'p15/p15007517/s58745793.txt',
#                           'p15/p15007517/s58608641.txt',
#                           'p15/p15007517/s58608641.txt',
#                           'p10/p10004235/s52962553.txt',
#                           'p10/p10004235/s52962553.txt']},
#  'angle': {'normalization': None,
#            'reports': ['p15/p15024484/s55357745.txt',
#                        'p15/p15024484/s55357745.txt',
#                        'p18/p18001922/s52288833.txt',
#                        'p18/p18001922/s52288833.txt',
#                        'p18/p18022445/s55421520.txt',
#                        'p15/p15002678/s56528605.txt',
#                        'p10/p10005866/s56175428.txt',
#                        'p10/p10005368/s54510564.txt',
#                        'p10/p10005368/s54510564.txt',
#                        'p15/p15002496/s52886085.txt',
#                        'p15/p15002496/s52886085.txt',
#                        'p15/p15002496/s53190310.txt',
#                        'p15/p15002496/s53190310.txt',
#                        'p18/p18011616/s59704184.txt']},
#  'angles': {'normalization': None, 'reports': ['p15/p15001474/s58221226.txt']},
#  'anterior': {'normalization': None,
#               'reports': ['p15/p15078112/s58703686.txt',
#                           'p15/p15002678/s54481740.txt',
#                           'p10/p10003019/s53934356.txt',
#                           'p15/p15000485/s56074305.txt',
#                           'p18/p18028180/s55973443.txt']},
#  'aorta': {'normalization': None,
#            'reports': ['p15/p15024484/s55357745.txt',
#                        'p18/p18023211/s58462799.txt',
#                        'p15/p15001136/s50077246.txt',
#                        'p15/p15165563/s54307084.txt',
#                        'p15/p15165563/s54509771.txt',
#                        'p15/p15165563/s53383993.txt',
#                        'p18/p18001942/s56433237.txt',
#                        'p10/p10003502/s51180958.txt',
#                        'p10/p10003502/s57812613.txt',
#                        'p18/p18020943/s53949676.txt',
#                        'p10/p10003052/s58630288.txt',
#                        'p10/p10003019/s52117631.txt',
#                        'p10/p10003019/s59730608.txt',
#                        'p18/p18001157/s57119564.txt',
#                        'p15/p15009233/s54785596.txt',
#                        'p15/p15002496/s54741884.txt',
#                        'p15/p15002496/s55461318.txt',
#                        'p15/p15001474/s51737379.txt',
#                        'p15/p15001474/s51737379.txt',
#                        'p15/p15007710/s53803512.txt',
#                        'p15/p15007710/s57053735.txt',
#                        'p15/p15007710/s57053735.txt',
#                        'p15/p15007710/s57053735.txt',
#                        'p15/p15007710/s57377858.txt',
#                        'p18/p18011616/s57021204.txt',
#                        'p18/p18011616/s50686187.txt',
#                        'p18/p18028180/s57826518.txt']},
#  'aortic': {'normalization': None,
#             'reports': ['p15/p15078112/s59479753.txt',
#                         'p18/p18026902/s59872068.txt',
#                         'p15/p15007487/s57478149.txt',
#                         'p18/p18017189/s55185780.txt',
#                         'p15/p15002496/s53190310.txt',
#                         'p15/p15002496/s54796318.txt',
#                         'p18/p18028180/s53423151.txt',
#                         'p15/p15002852/s58489231.txt']},
#  'apex': {'normalization': None,
#           'reports': ['p18/p18004941/s58034164.txt',
#                       'p18/p18010079/s55080309.txt',
#                       'p15/p15007487/s59034151.txt',
#                       'p15/p15007487/s53221126.txt',
#                       'p18/p18003894/s58464660.txt',
#                       'p15/p15002678/s54481740.txt',
#                       'p15/p15002678/s50618143.txt',
#                       'p15/p15002678/s50618143.txt',
#                       'p18/p18028999/s58738737.txt',
#                       'p10/p10005368/s57426090.txt',
#                       'p10/p10003637/s57024735.txt',
#                       'p15/p15000393/s57099953.txt',
#                       'p15/p15000393/s57099953.txt',
#                       'p18/p18006842/s54156702.txt',
#                       'p18/p18017572/s56064830.txt']},
#  'apical': {'normalization': None,
#             'reports': ['p15/p15003294/s50875241.txt',
#                         'p18/p18010079/s59097048.txt',
#                         'p18/p18010079/s56436361.txt',
#                         'p18/p18010079/s53957050.txt',
#                         'p15/p15007487/s54185768.txt',
#                         'p15/p15007487/s59752695.txt',
#                         'p15/p15007487/s59752695.txt',
#                         'p15/p15007487/s53197725.txt',
#                         'p15/p15007487/s58357685.txt',
#                         'p15/p15001501/s55616331.txt',
#                         'p18/p18003894/s58777551.txt',
#                         'p18/p18003894/s53451407.txt',
#                         'p18/p18003894/s53451407.txt',
#                         'p18/p18003894/s56902065.txt',
#                         'p15/p15002678/s53430015.txt',
#                         'p15/p15003988/s50511251.txt',
#                         'p10/p10005368/s56689183.txt',
#                         'p10/p10005368/s56689183.txt',
#                         'p10/p10005368/s57426090.txt',
#                         'p18/p18001157/s59771012.txt',
#                         'p15/p15000393/s53701643.txt',
#                         'p15/p15000393/s59128455.txt',
#                         'p15/p15000393/s57099953.txt',
#                         'p15/p15000393/s55723653.txt',
#                         'p10/p10002428/s58838312.txt',
#                         'p10/p10002428/s58838312.txt',
#                         'p18/p18000379/s59261316.txt',
#                         'p18/p18000379/s59261316.txt',
#                         'p18/p18000379/s58920421.txt',
#                         'p18/p18000379/s58920421.txt',
#                         'p18/p18000379/s57516501.txt',
#                         'p18/p18000379/s57516501.txt',
#                         'p18/p18000379/s51817182.txt',
#                         'p18/p18000379/s56020891.txt',
#                         'p18/p18000379/s53632378.txt',
#                         'p18/p18017572/s52030715.txt',
#                         'p18/p18017572/s51869019.txt',
#                         'p18/p18017572/s54836720.txt']},
#  'apices': {'normalization': None, 'reports': ['p18/p18003081/s50577366.txt']},
#  'appearance': {'normalization': None,
#                 'reports': ['p10/p10002559/s52212843.txt']},
#  'approximately 1.8 cm': {'normalization': None,
#                           'reports': ['p18/p18004941/s55576421.txt']},
#  'approximately 12 cm': {'normalization': None,
#                          'reports': ['p18/p18004941/s55576421.txt']},
#  'approximately 2 cm': {'normalization': None,
#                         'reports': ['p18/p18004941/s55576421.txt']},
#  'approximately 2.3 cm': {'normalization': None,
#                           'reports': ['p10/p10005866/s56175428.txt',
#                                       'p10/p10005866/s56175428.txt']},
#  'approximately 5 cm': {'normalization': None,
#                         'reports': ['p10/p10002428/s57506266.txt',
#                                     'p10/p10002428/s57506266.txt']},
#  'approximately a 4.6 cm': {'normalization': None,
#                             'reports': ['p18/p18004941/s58034164.txt']},
#  'arch': {'normalization': None,
#           'reports': ['p15/p15003296/s54535760.txt',
#                       'p15/p15007487/s57478149.txt',
#                       'p15/p15002496/s53190310.txt',
#                       'p15/p15002496/s54796318.txt',
#                       'p18/p18028180/s53423151.txt',
#                       'p18/p18028180/s57826518.txt']},
#  'area': {'normalization': None,
#           'reports': ['p10/p10003637/s51371378.txt',
#                       'p18/p18001157/s59771012.txt']},
#  'areas': {'normalization': None,
#            'reports': ['p10/p10003019/s52117631.txt',
#                        'p10/p10003019/s59607556.txt']},
#  'arteries': {'normalization': None,
#               'reports': ['p15/p15009504/s55274948.txt',
#                           'p15/p15009504/s51227163.txt',
#                           'p18/p18017189/s55185780.txt',
#                           'p18/p18017189/s55185780.txt',
#                           'p18/p18017189/s59226684.txt',
#                           'p15/p15001474/s58221226.txt',
#                           'p15/p15007710/s57053735.txt']},
#  'artery': {'normalization': None,
#             'reports': ['p10/p10005749/s54060141.txt',
#                         'p10/p10005749/s54060141.txt',
#                         'p10/p10005749/s54060141.txt',
#                         'p10/p10005749/s57249718.txt',
#                         'p10/p10005749/s57249718.txt',
#                         'p10/p10005749/s58865310.txt',
#                         'p18/p18017189/s59226684.txt',
#                         'p18/p18000379/s51568340.txt',
#                         'p18/p18000379/s51568340.txt']},
#  'aspect': {'normalization': None,
#             'reports': ['p15/p15165563/s54307084.txt',
#                         'p10/p10002428/s57887188.txt']},
#  'atrium': {'normalization': None,
#             'reports': ['p15/p15002183/s52341485.txt',
#                         'p18/p18022445/s56006486.txt',
#                         'p18/p18003894/s58777551.txt',
#                         'p18/p18003894/s58464660.txt',
#                         'p18/p18003894/s56064707.txt',
#                         'p18/p18028999/s57987829.txt',
#                         'p18/p18028999/s57987829.txt',
#                         'p18/p18028999/s57987829.txt',
#                         'p15/p15007517/s59740051.txt',
#                         'p15/p15009504/s55274948.txt',
#                         'p15/p15009504/s59292871.txt',
#                         'p15/p15009504/s51227163.txt',
#                         'p15/p15009504/s56362726.txt',
#                         'p15/p15009504/s54918382.txt',
#                         'p15/p15009504/s59050955.txt',
#                         'p18/p18017363/s53531162.txt',
#                         'p18/p18017363/s54401973.txt',
#                         'p18/p18017363/s55076850.txt',
#                         'p10/p10002428/s58851198.txt',
#                         'p18/p18006842/s54156702.txt',
#                         'p18/p18006842/s56350245.txt',
#                         'p18/p18006842/s59597753.txt']},
#  'axilla': {'normalization': None,
#             'reports': ['p10/p10002428/s59659695.txt',
#                         'p10/p10002428/s59659695.txt',
# ...
#                           'p15/p15078112/s55285875.txt',
#                           'p15/p15078112/s53834915.txt',
#                           'p15/p15078112/s56357121.txt',
#                           'p15/p15078112/s56357121.txt',
#                           'p15/p15078112/s59839693.txt',
#                           'p15/p15078112/s52859232.txt',
#                           'p15/p15003296/s58126961.txt',
#                           'p15/p15003296/s58126961.txt',
#                           'p15/p15003296/s52507068.txt',
#                           'p15/p15003296/s52507068.txt',
#                           'p15/p15003296/s55100464.txt',
#                           'p15/p15003296/s55162880.txt',
#                           'p15/p15003296/s58235657.txt',
#                           'p15/p15003296/s58235657.txt',
#                           'p18/p18022445/s51773947.txt',
#                           'p10/p10002804/s53422998.txt',
#                           'p15/p15002678/s50618143.txt',
#                           'p15/p15002678/s50618143.txt',
#                           'p10/p10003502/s57641661.txt',
#                           'p10/p10003502/s57641661.txt',
#                           'p10/p10003502/s53836463.txt',
#                           'p10/p10003502/s53282957.txt',
#                           'p18/p18020943/s55270846.txt',
#                           'p18/p18020943/s53949676.txt',
#                           'p18/p18020943/s57074556.txt',
#                           'p18/p18020943/s57074556.txt',
#                           'p18/p18022983/s52601618.txt',
#                           'p15/p15006483/s54362708.txt',
#                           'p18/p18000745/s59652189.txt',
#                           'p10/p10005866/s56175428.txt',
#                           'p10/p10005866/s56175428.txt',
#                           'p10/p10005866/s56175428.txt',
#                           'p15/p15007517/s50648100.txt',
#                           'p15/p15007517/s58608641.txt',
#                           'p15/p15003988/s50511251.txt',
#                           'p10/p10004235/s52379321.txt',
#                           'p10/p10004235/s52379321.txt',
#                           'p10/p10004235/s52379321.txt',
#                           'p10/p10004235/s52379321.txt',
#                           'p10/p10004235/s57318275.txt',
#                           'p10/p10004235/s57318275.txt',
#                           'p10/p10004235/s58604118.txt',
#                           'p10/p10004235/s59895508.txt',
#                           'p18/p18015004/s54721527.txt',
#                           'p10/p10003637/s57024735.txt',
#                           'p10/p10003019/s59829602.txt',
#                           'p10/p10003019/s59829602.txt',
#                           'p10/p10003019/s59829602.txt',
#                           'p10/p10003019/s59730608.txt',
#                           'p10/p10004322/s57662923.txt',
#                           'p18/p18017189/s54781713.txt',
#                           'p15/p15009233/s57256545.txt',
#                           'p15/p15009233/s57930478.txt',
#                           'p15/p15009233/s57930478.txt',
#                           'p15/p15009233/s58131029.txt',
#                           'p15/p15009233/s54889621.txt',
#                           'p10/p10002428/s59891001.txt',
#                           'p10/p10002428/s56100138.txt',
#                           'p10/p10002428/s57506266.txt',
#                           'p18/p18006842/s50471520.txt',
#                           'p18/p18006842/s56350245.txt',
#                           'p18/p18006842/s56350245.txt',
#                           'p18/p18006842/s56350245.txt',
#                           'p18/p18006842/s56350245.txt',
#                           'p15/p15002496/s50531159.txt',
#                           'p15/p15002496/s52886085.txt',
#                           'p15/p15002496/s55374744.txt',
#                           'p15/p15000485/s56074305.txt',
#                           'p18/p18000379/s51062789.txt',
#                           'p18/p18000379/s55748408.txt',
#                           'p10/p10002559/s59849480.txt',
#                           'p15/p15001834/s56269673.txt']},
#  'vascularity': {'normalization': None,
#                  'reports': ['p15/p15024484/s55357745.txt',
#                              'p18/p18026902/s57297476.txt',
#                              'p18/p18012427/s54748444.txt',
#                              'p15/p15009233/s54618867.txt']},
#  'vasculature': {'normalization': None,
#                  'reports': ['p18/p18004941/s58034164.txt',
#                              'p10/p10005749/s53170451.txt',
#                              'p10/p10005749/s53170451.txt',
#                              'p15/p15165563/s56337929.txt',
#                              'p15/p15165563/s59506127.txt',
#                              'p15/p15078112/s58166907.txt',
#                              'p15/p15078112/s58703686.txt',
#                              'p18/p18000735/s50785186.txt',
#                              'p18/p18019295/s57254021.txt',
#                              'p18/p18001942/s56433237.txt',
#                              'p15/p15002678/s56528605.txt',
#                              'p18/p18022983/s57985067.txt',
#                              'p18/p18022983/s57381264.txt',
#                              'p15/p15006483/s59006665.txt',
#                              'p10/p10003019/s59339276.txt',
#                              'p18/p18001157/s59771012.txt',
#                              'p10/p10002428/s58581921.txt',
#                              'p18/p18006842/s55078395.txt',
#                              'p18/p18006842/s56350245.txt',
#                              'p18/p18006842/s59597753.txt',
#                              'p15/p15001474/s51737379.txt',
#                              'p18/p18011616/s57021204.txt',
#                              'p18/p18011616/s56212412.txt',
#                              'p18/p18028180/s57844688.txt',
#                              'p18/p18028180/s57826518.txt',
#                              'p18/p18000379/s59391463.txt']},
#  'vein': {'normalization': None,
#           'reports': ['p18/p18020943/s57074556.txt',
#                       'p10/p10003019/s59607556.txt',
#                       'p10/p10002428/s52460896.txt',
#                       'p10/p10002428/s59258773.txt',
#                       'p10/p10002428/s58851198.txt',
#                       'p10/p10002428/s57506266.txt']},
#  'veins': {'normalization': None, 'reports': ['p15/p15078112/s58166907.txt']},
#  'venous': {'normalization': None,
#             'reports': ['p10/p10005749/s54040624.txt',
#                         'p15/p15004061/s56845046.txt',
#                         'p15/p15078112/s56357121.txt',
#                         'p15/p15078112/s56357121.txt',
#                         'p15/p15078112/s56357121.txt',
#                         'p15/p15078112/s56357121.txt',
#                         'p15/p15078112/s56824160.txt',
#                         'p15/p15002678/s53430015.txt',
#                         'p15/p15007517/s50648100.txt',
#                         'p15/p15007517/s51550673.txt',
#                         'p10/p10003637/s51371378.txt',
#                         'p18/p18017189/s59226684.txt',
#                         'p10/p10002428/s57887188.txt',
#                         'p10/p10002428/s50444997.txt']},
#  'ventricle': {'normalization': None,
#                'reports': ['p18/p18022445/s56006486.txt',
#                            'p18/p18017363/s53531162.txt',
#                            'p18/p18017363/s54401973.txt',
#                            'p18/p18017363/s55076850.txt',
#                            'p10/p10003637/s51461467.txt',
#                            'p10/p10003637/s57024735.txt',
#                            'p18/p18006842/s54156702.txt',
#                            'p18/p18006842/s54156702.txt',
#                            'p18/p18006842/s56350245.txt',
#                            'p18/p18006842/s59597753.txt',
#                            'p18/p18006842/s59597753.txt']},
#  'ventricular': {'normalization': None,
#                  'reports': ['p15/p15001136/s50077246.txt',
#                              'p18/p18001942/s56433237.txt',
#                              'p15/p15007517/s50648100.txt']},
#  'vertebral': {'normalization': None,
#                'reports': ['p18/p18001942/s56433237.txt',
#                            'p10/p10003019/s52117631.txt',
#                            'p10/p10003019/s52117631.txt',
#                            'p10/p10003019/s52117631.txt',
#                            'p10/p10003019/s58505074.txt',
#                            'p18/p18028180/s55973443.txt']},
#  'vessel': {'normalization': None,
#             'reports': ['p10/p10004235/s52379321.txt',
#                         'p10/p10004235/s52379321.txt']},
#  'vessels': {'normalization': None,
#              'reports': ['p15/p15002678/s53430015.txt',
#                          'p18/p18020943/s57074556.txt',
#                          'p10/p10003637/s51371378.txt',
#                          'p10/p10002428/s57887188.txt']},
#  'visualized': {'normalization': None,
#                 'reports': ['p18/p18017363/s55076850.txt']},
#  'volume': {'normalization': None,
#             'reports': ['p18/p18003081/s53302126.txt',
#                         'p15/p15004061/s50854153.txt',
#                         'p15/p15004061/s51985597.txt',
#                         'p15/p15004061/s50269894.txt',
#                         'p15/p15078112/s58166907.txt',
#                         'p15/p15078112/s52859232.txt',
#                         'p18/p18026902/s51741672.txt',
#                         'p18/p18022445/s55421520.txt',
#                         'p18/p18022445/s51773947.txt',
#                         'p15/p15007487/s57478149.txt',
#                         'p15/p15007487/s53221126.txt',
#                         'p10/p10003502/s53836463.txt',
#                         'p10/p10003502/s53836463.txt',
#                         'p18/p18028999/s57987829.txt',
#                         'p18/p18028999/s53725346.txt',
#                         'p10/p10003019/s58365492.txt',
#                         'p10/p10003019/s59829602.txt',
#                         'p10/p10003019/s59829602.txt',
#                         'p10/p10003019/s59635047.txt',
#                         'p15/p15009233/s54889621.txt',
#                         'p15/p15000393/s55843146.txt',
#                         'p15/p15000393/s52929930.txt',
#                         'p15/p15000393/s57099953.txt',
#                         'p10/p10002428/s57887188.txt',
#                         'p15/p15002496/s51438936.txt',
#                         'p18/p18017572/s54836720.txt']},
#  'volumes': {'normalization': None,
#              'reports': ['p18/p18004941/s52289350.txt',
#                          'p18/p18004941/s55576421.txt',
#                          'p18/p18003081/s57007000.txt',
#                          'p18/p18003081/s51239857.txt',
#                          'p18/p18003081/s51239857.txt',
#                          'p18/p18003081/s52648242.txt',
#                          'p18/p18003081/s55159460.txt',
#                          'p10/p10005749/s54060141.txt',
#                          'p18/p18023211/s58130107.txt',
#                          'p18/p18023211/s56555187.txt',
#                          'p15/p15165563/s53383993.txt',
#                          'p15/p15004061/s51985597.txt',
#                          'p15/p15078112/s53834915.txt',
#                          'p15/p15078112/s56882127.txt',
#                          'p18/p18026902/s55739083.txt',
#                          'p15/p15003296/s58126961.txt',
#                          'p15/p15003296/s58126961.txt',
#                          'p15/p15003296/s52507068.txt',
#                          'p15/p15003296/s52507068.txt',
#                          'p15/p15003296/s51554855.txt',
#                          'p15/p15003296/s55162880.txt',
#                          'p15/p15003296/s55162880.txt',
#                          'p15/p15003296/s51481960.txt',
#                          'p15/p15003296/s58235657.txt',
#                          'p15/p15003296/s58235657.txt',
#                          'p18/p18010079/s56436361.txt',
#                          'p15/p15002538/s51219765.txt',
#                          'p18/p18019295/s52492192.txt',
#                          'p15/p15002678/s54137434.txt',
#                          'p15/p15002678/s50618143.txt',
#                          'p18/p18022983/s51605945.txt',
#                          'p18/p18022983/s57985067.txt',
#                          'p18/p18022983/s57985067.txt',
#                          'p18/p18022983/s52601618.txt',
#                          'p18/p18022983/s57381264.txt',
#                          'p15/p15007517/s59740051.txt',
#                          'p10/p10003052/s58630288.txt',
#                          'p15/p15009504/s53368774.txt',
#                          'p18/p18017363/s54401973.txt',
#                          'p18/p18017363/s55076850.txt',
#                          'p10/p10005368/s56689183.txt',
#                          'p10/p10004235/s52379321.txt',
#                          'p10/p10004235/s52379321.txt',
#                          'p10/p10004235/s52379321.txt',
#                          'p10/p10004235/s52379321.txt',
#                          'p10/p10004235/s57318275.txt',
#                          'p18/p18015004/s57985812.txt',
#                          'p18/p18015004/s57985812.txt',
#                          'p18/p18015004/s52149254.txt',
#                          'p18/p18015004/s56533254.txt',
#                          'p18/p18015004/s56533254.txt',
#                          'p18/p18015004/s51210113.txt',
#                          'p18/p18015004/s51210113.txt',
#                          'p10/p10003637/s51371378.txt',
#                          'p10/p10003019/s59829602.txt',
#                          'p10/p10003019/s59829602.txt',
#                          'p10/p10003019/s59829602.txt',
#                          'p10/p10003019/s52117631.txt',
#                          'p10/p10003019/s59730608.txt',
#                          'p18/p18001157/s57119564.txt',
#                          'p15/p15009233/s57930478.txt',
#                          'p10/p10002428/s56100138.txt',
#                          'p18/p18006842/s55078395.txt',
#                          'p18/p18006842/s59597753.txt',
#                          'p18/p18011616/s59704184.txt',
#                          'p18/p18011616/s50686187.txt',
#                          'p10/p10002559/s52212843.txt',
#                          'p15/p15001203/s50723040.txt',
#                          'p15/p15001834/s58938701.txt']},
#  'wall': {'normalization': None,
#           'reports': ['p15/p15001136/s52592881.txt',
#                       'p15/p15165563/s54307084.txt',
#                       'p18/p18010079/s55080309.txt',
#                       'p15/p15007487/s54185768.txt',
#                       'p15/p15007487/s59034151.txt',
#                       'p15/p15007487/s52305139.txt',
#                       'p10/p10005368/s56689183.txt',
#                       'p10/p10003019/s58365492.txt',
#                       'p10/p10002428/s58581921.txt',
#                       'p18/p18006842/s50471520.txt',
#                       'p18/p18006842/s59597753.txt',
#                       'p18/p18011616/s59704184.txt',
#                       'p18/p18011616/s59704184.txt',
#                       'p18/p18028180/s57826518.txt',
#                       'p18/p18017572/s54836720.txt']},
#  'withdrawn 1 cm': {'normalization': None,
#                     'reports': ['p15/p15009504/s51227163.txt']},
#  'within': {'normalization': None,
#             'reports': ['p15/p15007487/s54185768.txt',
#                         'p10/p10007795/s54317369.txt',
#                         'p10/p10005866/s56175428.txt',
#                         'p10/p10005866/s56175428.txt']},
#  'zone': {'normalization': None,
#           'reports': ['p10/p10003502/s57812613.txt',
#                       'p10/p10005866/s56175428.txt',
#                       'p10/p10004235/s58604118.txt',
#                       'p18/p18003402/s52418327.txt',
#                       'p10/p10002428/s50444997.txt']}}
# Number of unique 'ANAT-DP' entities: 398
# All entities have been saved to 'all_entities.json'

# %% [markdown]
# ## 统计all_entities中每个entity出现的次数

# %%
from collections import Counter

def analyze_entity_frequency(all_entities):
    # Initialize a Counter to store entity frequencies
    entity_frequency = Counter()

    # Iterate through all labels and entities
    for label, entities in all_entities.items():
        for entity, document_keys in entities.items():
            # Count the number of documents for each entity
            entity_frequency[(entity, label)] += len(document_keys)

    # Print the results
    print("Entity Frequency Analysis:")
    for (entity, label), count in entity_frequency.most_common():
        print(f"Entity: '{entity}', Label: '{label}', Frequency: {count}")

    # Optional: Return the Counter object for further analysis if needed
    return entity_frequency

# Assuming all_entities is already defined and populated
analyze_entity_frequency(all_entities)
# Out:
# Entity Frequency Analysis:
# Entity: 'Lungs', Label: 'ANAT-DP', Frequency: 2
# Entity: 'cardiomediastinal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'hilar', Label: 'ANAT-DP', Frequency: 2
# Entity: 'silhouettes', Label: 'ANAT-DP', Frequency: 2
# Entity: 'pleural', Label: 'ANAT-DP', Frequency: 2
# Entity: 'surfaces', Label: 'ANAT-DP', Frequency: 2
# Entity: 'approximately a 4.6 cm', Label: 'ANAT-DP', Frequency: 2
# Entity: 'carina', Label: 'ANAT-DP', Frequency: 2
# Entity: 'distal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'esophagus', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Heart', Label: 'ANAT-DP', Frequency: 2
# Entity: 'size', Label: 'ANAT-DP', Frequency: 2
# Entity: 'mediastinal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'contours', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Pulmonary', Label: 'ANAT-DP', Frequency: 2
# Entity: 'vasculature', Label: 'ANAT-DP', Frequency: 2
# Entity: 'lung', Label: 'ANAT-DP', Frequency: 2
# Entity: 'bases', Label: 'ANAT-DP', Frequency: 2
# Entity: 'lungs', Label: 'ANAT-DP', Frequency: 2
# Entity: 'extreme', Label: 'ANAT-DP', Frequency: 2
# Entity: 'right', Label: 'ANAT-DP', Frequency: 2
# Entity: 'apex', Label: 'ANAT-DP', Frequency: 2
# Entity: 'osseous', Label: 'ANAT-DP', Frequency: 2
# Entity: 'stomach', Label: 'ANAT-DP', Frequency: 2
# Entity: 'mid', Label: 'ANAT-DP', Frequency: 2
# Entity: 'portion', Label: 'ANAT-DP', Frequency: 2
# Entity: 'body', Label: 'ANAT-DP', Frequency: 2
# Entity: 'esophagogastric', Label: 'ANAT-DP', Frequency: 2
# Entity: 'junction', Label: 'ANAT-DP', Frequency: 2
# Entity: 'volumes', Label: 'ANAT-DP', Frequency: 2
# Entity: '4.3 cm', Label: 'ANAT-DP', Frequency: 2
# Entity: 'near', Label: 'ANAT-DP', Frequency: 2
# Entity: 'cardiopulmonary', Label: 'ANAT-DP', Frequency: 2
# Entity: 'vascular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'approximately 1.8 cm', Label: 'ANAT-DP', Frequency: 2
# Entity: 'barely', Label: 'ANAT-DP', Frequency: 2
# Entity: 'proximal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'approximately 12 cm', Label: 'ANAT-DP', Frequency: 2
# Entity: 'approximately 2 cm', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Lung', Label: 'ANAT-DP', Frequency: 2
# Entity: 'silhouette', Label: 'ANAT-DP', Frequency: 2
# Entity: 'structures', Label: 'ANAT-DP', Frequency: 2
# Entity: 'cardiac', Label: 'ANAT-DP', Frequency: 2
# Entity: 'bronchovascular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'pulmonary', Label: 'ANAT-DP', Frequency: 2
# Entity: 'bibasilar', Label: 'ANAT-DP', Frequency: 2
# Entity: 'left', Label: 'ANAT-DP', Frequency: 2
# Entity: 'basal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'parenchymal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'ribcage', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Osseous', Label: 'ANAT-DP', Frequency: 2
# Entity: 'lower', Label: 'ANAT-DP', Frequency: 2
# Entity: 'rib', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Left', Label: 'ANAT-DP', Frequency: 2
# Entity: 'mediastinum', Label: 'ANAT-DP', Frequency: 2
# Entity: 'upper', Label: 'ANAT-DP', Frequency: 2
# Entity: 'chest', Label: 'ANAT-DP', Frequency: 2
# Entity: 'lobe', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Mediastinal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'apices', Label: 'ANAT-DP', Frequency: 2
# Entity: 'heart', Label: 'ANAT-DP', Frequency: 2
# Entity: 'volume', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Bilateral', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Cardiomediastinal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'border', Label: 'ANAT-DP', Frequency: 2
# Entity: 'right - sided', Label: 'ANAT-DP', Frequency: 2
# Entity: 'loculated', Label: 'ANAT-DP', Frequency: 2
# Entity: 'bilateral', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Bony', Label: 'ANAT-DP', Frequency: 2
# Entity: 'quadrant', Label: 'ANAT-DP', Frequency: 2
# Entity: 'aorta', Label: 'ANAT-DP', Frequency: 2
# Entity: 'vascularity', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Bibasilar', Label: 'ANAT-DP', Frequency: 2
# Entity: 'airspace', Label: 'ANAT-DP', Frequency: 2
# Entity: 'costophrenic', Label: 'ANAT-DP', Frequency: 2
# Entity: 'angle', Label: 'ANAT-DP', Frequency: 2
# Entity: 'laterally', Label: 'ANAT-DP', Frequency: 2
# Entity: 'sternal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'retrocardiac', Label: 'ANAT-DP', Frequency: 2
# Entity: 'artery', Label: 'ANAT-DP', Frequency: 2
# Entity: 'main', Label: 'ANAT-DP', Frequency: 2
# Entity: 'subclavian', Label: 'ANAT-DP', Frequency: 2
# Entity: 'SVC', Label: 'ANAT-DP', Frequency: 2
# Entity: 'venous', Label: 'ANAT-DP', Frequency: 2
# Entity: 'hemidiaphragm', Label: 'ANAT-DP', Frequency: 2
# Entity: 'base', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Cardiac', Label: 'ANAT-DP', Frequency: 2
# Entity: 'adjacent', Label: 'ANAT-DP', Frequency: 2
# Entity: 'mitral', Label: 'ANAT-DP', Frequency: 2
# Entity: 'valve', Label: 'ANAT-DP', Frequency: 2
# Entity: 'pericardial', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Aortic', Label: 'ANAT-DP', Frequency: 2
# Entity: 'contour', Label: 'ANAT-DP', Frequency: 2
# Entity: 'hilus', Label: 'ANAT-DP', Frequency: 2
# Entity: 'interstitial', Label: 'ANAT-DP', Frequency: 2
# Entity: 'right sided', Label: 'ANAT-DP', Frequency: 2
# Entity: 'thoracic', Label: 'ANAT-DP', Frequency: 2
# Entity: 'ribs', Label: 'ANAT-DP', Frequency: 2
# Entity: 'second', Label: 'ANAT-DP', Frequency: 2
# Entity: 'fifith', Label: 'ANAT-DP', Frequency: 2
# Entity: 'posterior', Label: 'ANAT-DP', Frequency: 2
# Entity: 'fourth', Label: 'ANAT-DP', Frequency: 2
# Entity: 'below', Label: 'ANAT-DP', Frequency: 2
# Entity: 'diaphragm', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Right', Label: 'ANAT-DP', Frequency: 2
# Entity: 'margin', Label: 'ANAT-DP', Frequency: 2
# Entity: 'ventricular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'configuration', Label: 'ANAT-DP', Frequency: 2
# Entity: 'basilar', Label: 'ANAT-DP', Frequency: 2
# Entity: 'wall', Label: 'ANAT-DP', Frequency: 2
# Entity: 'skin', Label: 'ANAT-DP', Frequency: 2
# Entity: 'spine', Label: 'ANAT-DP', Frequency: 2
# Entity: 'knob', Label: 'ANAT-DP', Frequency: 2
# Entity: 'airway', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Vascular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'diaphragms', Label: 'ANAT-DP', Frequency: 2
# Entity: 'institial', Label: 'ANAT-DP', Frequency: 2
# Entity: 'lobar', Label: 'ANAT-DP', Frequency: 2
# Entity: 'lateral', Label: 'ANAT-DP', Frequency: 2
# Entity: 'aspect', Label: 'ANAT-DP', Frequency: 2
# Entity: 'descending', Label: 'ANAT-DP', Frequency: 2
# Entity: 'hemidiaphragms', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Mediastinum', Label: 'ANAT-DP', Frequency: 2
# Entity: 'hila', Label: 'ANAT-DP', Frequency: 2
# Entity: 'AP', Label: 'ANAT-DP', Frequency: 2
# Entity: 'diameter', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Lower', Label: 'ANAT-DP', Frequency: 2
# Entity: 'bilaterally', Label: 'ANAT-DP', Frequency: 2
# Entity: 'IJ', Label: 'ANAT-DP', Frequency: 2
# Entity: 'major', Label: 'ANAT-DP', Frequency: 2
# Entity: 'fissure', Label: 'ANAT-DP', Frequency: 2
# Entity: 'both', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Left - sided', Label: 'ANAT-DP', Frequency: 2
# Entity: 'atrium', Label: 'ANAT-DP', Frequency: 2
# Entity: 'abdomen', Label: 'ANAT-DP', Frequency: 2
# Entity: 'low', Label: 'ANAT-DP', Frequency: 2
# Entity: 'superior vena cava', Label: 'ANAT-DP', Frequency: 2
# Entity: 'intrathoracic', Label: 'ANAT-DP', Frequency: 2
# Entity: 'internal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'jugular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'trachea', Label: 'ANAT-DP', Frequency: 2
# Entity: 'central', Label: 'ANAT-DP', Frequency: 2
# Entity: 'superior', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Right - sided', Label: 'ANAT-DP', Frequency: 2
# Entity: 'cavoatrial', Label: 'ANAT-DP', Frequency: 2
# Entity: 'veins', Label: 'ANAT-DP', Frequency: 2
# Entity: 'intravascular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'cavoatrial junction', Label: 'ANAT-DP', Frequency: 2
# Entity: 'aortic', Label: 'ANAT-DP', Frequency: 2
# Entity: 'knuckle', Label: 'ANAT-DP', Frequency: 2
# Entity: 'fifth', Label: 'ANAT-DP', Frequency: 2
# Entity: 'anterior', Label: 'ANAT-DP', Frequency: 2
# Entity: 'lingular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'perihilar', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Retrocardiac', Label: 'ANAT-DP', Frequency: 2
# Entity: 'valvular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'position', Label: 'ANAT-DP', Frequency: 2
# Entity: 'infrahilar', Label: 'ANAT-DP', Frequency: 2
# Entity: 'internal jugular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Midline', Label: 'ANAT-DP', Frequency: 2
# Entity: 'pulmonic', Label: 'ANAT-DP', Frequency: 2
# Entity: '5 cm above', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Median', Label: 'ANAT-DP', Frequency: 2
# Entity: 'cardia', Label: 'ANAT-DP', Frequency: 2
# Entity: 'mild', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Biapical', Label: 'ANAT-DP', Frequency: 2
# Entity: 'neck', Label: 'ANAT-DP', Frequency: 2
# Entity: 'apical', Label: 'ANAT-DP', Frequency: 2
# Entity: 'parenchyma', Label: 'ANAT-DP', Frequency: 2
# Entity: 'shape', Label: 'ANAT-DP', Frequency: 2
# Entity: 'biapical', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Upper', Label: 'ANAT-DP', Frequency: 2
# Entity: 'paratracheal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'thyroid', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Thoracic', Label: 'ANAT-DP', Frequency: 2
# Entity: 'PARENCHYMAL', Label: 'ANAT-DP', Frequency: 2
# Entity: 'LUNG', Label: 'ANAT-DP', Frequency: 2
# Entity: 'SIZE', Label: 'ANAT-DP', Frequency: 2
# Entity: 'CARDIAC', Label: 'ANAT-DP', Frequency: 2
# Entity: 'SILHOUETTE', Label: 'ANAT-DP', Frequency: 2
# Entity: 'HILAR', Label: 'ANAT-DP', Frequency: 2
# Entity: 'MEDIASTINAL', Label: 'ANAT-DP', Frequency: 2
# Entity: 'STRUCTURES', Label: 'ANAT-DP', Frequency: 2
# Entity: 'AZYGOS', Label: 'ANAT-DP', Frequency: 2
# Entity: 'LOBE', Label: 'ANAT-DP', Frequency: 2
# Entity: 'remainder', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Aorta', Label: 'ANAT-DP', Frequency: 2
# Entity: 'arch', Label: 'ANAT-DP', Frequency: 2
# Entity: 'midlung', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Hemidiaphragm', Label: 'ANAT-DP', Frequency: 2
# Entity: 'GE', Label: 'ANAT-DP', Frequency: 2
# Entity: 'axillary', Label: 'ANAT-DP', Frequency: 2
# Entity: 'ventricle', Label: 'ANAT-DP', Frequency: 2
# Entity: 'beneath', Label: 'ANAT-DP', Frequency: 2
# Entity: 'mainstem', Label: 'ANAT-DP', Frequency: 2
# Entity: 'bronchus', Label: 'ANAT-DP', Frequency: 2
# Entity: 'medially', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Rib', Label: 'ANAT-DP', Frequency: 2
# Entity: 'multiple', Label: 'ANAT-DP', Frequency: 2
# Entity: 'lateral structures', Label: 'ANAT-DP', Frequency: 2
# Entity: 'thorax', Label: 'ANAT-DP', Frequency: 2
# Entity: 'left arm', Label: 'ANAT-DP', Frequency: 2
# Entity: 'transverse', Label: 'ANAT-DP', Frequency: 2
# Entity: 'process', Label: 'ANAT-DP', Frequency: 2
# Entity: 'L 2 through L 4', Label: 'ANAT-DP', Frequency: 2
# Entity: 'first', Label: 'ANAT-DP', Frequency: 2
# Entity: 'medial', Label: 'ANAT-DP', Frequency: 2
# Entity: 'portions', Label: 'ANAT-DP', Frequency: 2
# Entity: 'third', Label: 'ANAT-DP', Frequency: 2
# Entity: 'posteriorly', Label: 'ANAT-DP', Frequency: 2
# Entity: 'eighth', Label: 'ANAT-DP', Frequency: 2
# Entity: 'ninth', Label: 'ANAT-DP', Frequency: 2
# Entity: 'scapula', Label: 'ANAT-DP', Frequency: 2
# Entity: 'hemithorax', Label: 'ANAT-DP', Frequency: 2
# Entity: 'contents', Label: 'ANAT-DP', Frequency: 2
# Entity: 'clavicle', Label: 'ANAT-DP', Frequency: 2
# Entity: '4 cm above', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Subcutaneous', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Apical', Label: 'ANAT-DP', Frequency: 2
# Entity: 'subcutaneous', Label: 'ANAT-DP', Frequency: 2
# Entity: 'within', Label: 'ANAT-DP', Frequency: 2
# Entity: 'left sided', Label: 'ANAT-DP', Frequency: 2
# Entity: 'left - sided', Label: 'ANAT-DP', Frequency: 2
# Entity: 'emphysema', Label: 'ANAT-DP', Frequency: 2
# Entity: 'inferior', Label: 'ANAT-DP', Frequency: 2
# Entity: 'field', Label: 'ANAT-DP', Frequency: 2
# Entity: 'soft tissues', Label: 'ANAT-DP', Frequency: 2
# Entity: 'normal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'subcutaneus', Label: 'ANAT-DP', Frequency: 2
# Entity: 'otherwise', Label: 'ANAT-DP', Frequency: 2
# Entity: 'T 5 through T 9', Label: 'ANAT-DP', Frequency: 2
# Entity: 'of T 5 through T 9', Label: 'ANAT-DP', Frequency: 2
# Entity: 'intrafissural', Label: 'ANAT-DP', Frequency: 2
# Entity: 'pectus', Label: 'ANAT-DP', Frequency: 2
# Entity: 'excavatum', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Pectus', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Left sided', Label: 'ANAT-DP', Frequency: 2
# Entity: 'subpulmonic', Label: 'ANAT-DP', Frequency: 2
# Entity: 'structure', Label: 'ANAT-DP', Frequency: 2
# Entity: 'vertebral', Label: 'ANAT-DP', Frequency: 2
# Entity: 'bodies', Label: 'ANAT-DP', Frequency: 2
# Entity: 'thoracolumbar', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Soft tissue', Label: 'ANAT-DP', Frequency: 2
# Entity: 'humeral', Label: 'ANAT-DP', Frequency: 2
# Entity: 'head', Label: 'ANAT-DP', Frequency: 2
# Entity: 'vessels', Label: 'ANAT-DP', Frequency: 2
# Entity: 'region', Label: 'ANAT-DP', Frequency: 2
# Entity: 'sinus', Label: 'ANAT-DP', Frequency: 2
# Entity: 'peribronchial', Label: 'ANAT-DP', Frequency: 2
# Entity: 'interspace', Label: 'ANAT-DP', Frequency: 2
# Entity: 'bibasal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'rightward', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Vasculature', Label: 'ANAT-DP', Frequency: 2
# Entity: 'zone', Label: 'ANAT-DP', Frequency: 2
# Entity: 'lumbar', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Perihilar', Label: 'ANAT-DP', Frequency: 2
# Entity: 'alveolar', Label: 'ANAT-DP', Frequency: 2
# Entity: 'pylorus', Label: 'ANAT-DP', Frequency: 2
# Entity: 'superior cavoatrial junction', Label: 'ANAT-DP', Frequency: 2
# Entity: 'minor', Label: 'ANAT-DP', Frequency: 2
# Entity: 'azygos', Label: 'ANAT-DP', Frequency: 2
# Entity: 'vein', Label: 'ANAT-DP', Frequency: 2
# Entity: 'spinal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'subsegmental', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Sternal', Label: 'ANAT-DP', Frequency: 2
# Entity: '3 cm above', Label: 'ANAT-DP', Frequency: 2
# Entity: 'grossly', Label: 'ANAT-DP', Frequency: 2
# Entity: 'periphery', Label: 'ANAT-DP', Frequency: 2
# Entity: 'predominantly', Label: 'ANAT-DP', Frequency: 2
# Entity: 'fissural', Label: 'ANAT-DP', Frequency: 2
# Entity: 'midline', Label: 'ANAT-DP', Frequency: 2
# Entity: 'bones', Label: 'ANAT-DP', Frequency: 2
# Entity: 'in', Label: 'ANAT-DP', Frequency: 2
# Entity: 'lingula', Label: 'ANAT-DP', Frequency: 2
# Entity: 'middle', Label: 'ANAT-DP', Frequency: 2
# Entity: 'duodenum', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Pleural', Label: 'ANAT-DP', Frequency: 2
# Entity: 'approximately 2.3 cm', Label: 'ANAT-DP', Frequency: 2
# Entity: '3.5 cm above', Label: 'ANAT-DP', Frequency: 2
# Entity: '4.7 cm above', Label: 'ANAT-DP', Frequency: 2
# Entity: 'fundus', Label: 'ANAT-DP', Frequency: 2
# Entity: '2.8 cm above', Label: 'ANAT-DP', Frequency: 2
# Entity: 'segment', Label: 'ANAT-DP', Frequency: 2
# Entity: 'arteries', Label: 'ANAT-DP', Frequency: 2
# Entity: 'out of view', Label: 'ANAT-DP', Frequency: 2
# Entity: 'lobes', Label: 'ANAT-DP', Frequency: 2
# Entity: 'withdrawn 1 cm', Label: 'ANAT-DP', Frequency: 2
# Entity: '2.9 cm above', Label: 'ANAT-DP', Frequency: 2
# Entity: '3.4 cm', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Hilar', Label: 'ANAT-DP', Frequency: 2
# Entity: '3.6 cm above', Label: 'ANAT-DP', Frequency: 2
# Entity: 'right side', Label: 'ANAT-DP', Frequency: 2
# Entity: 'inlet', Label: 'ANAT-DP', Frequency: 2
# Entity: 'visualized', Label: 'ANAT-DP', Frequency: 2
# Entity: 'cage', Label: 'ANAT-DP', Frequency: 2
# Entity: 'under', Label: 'ANAT-DP', Frequency: 2
# Entity: 'subdiaphragmatic', Label: 'ANAT-DP', Frequency: 2
# Entity: 'cervical', Label: 'ANAT-DP', Frequency: 2
# Entity: 'soft tissue', Label: 'ANAT-DP', Frequency: 2
# Entity: 'CP', Label: 'ANAT-DP', Frequency: 2
# Entity: 'bony', Label: 'ANAT-DP', Frequency: 2
# Entity: 'infectious', Label: 'ANAT-DP', Frequency: 2
# Entity: 'great', Label: 'ANAT-DP', Frequency: 2
# Entity: 'vessel', Label: 'ANAT-DP', Frequency: 2
# Entity: '6 cm above', Label: 'ANAT-DP', Frequency: 2
# Entity: 'over', Label: 'ANAT-DP', Frequency: 2
# Entity: 'opacities', Label: 'ANAT-DP', Frequency: 2
# Entity: '7 cm', Label: 'ANAT-DP', Frequency: 2
# Entity: 'juxta', Label: 'ANAT-DP', Frequency: 2
# Entity: 'GE junction', Label: 'ANAT-DP', Frequency: 2
# Entity: 'parts', Label: 'ANAT-DP', Frequency: 2
# Entity: 'gastric', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Low', Label: 'ANAT-DP', Frequency: 2
# Entity: 'area', Label: 'ANAT-DP', Frequency: 2
# Entity: 'seventh', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Remainder', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Bronchial', Label: 'ANAT-DP', Frequency: 2
# Entity: 'skeletal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'pedicle', Label: 'ANAT-DP', Frequency: 2
# Entity: 'underneath', Label: 'ANAT-DP', Frequency: 2
# Entity: 'nipple', Label: 'ANAT-DP', Frequency: 2
# Entity: 'shadows', Label: 'ANAT-DP', Frequency: 2
# Entity: 'suprahilar', Label: 'ANAT-DP', Frequency: 2
# Entity: 'areas', Label: 'ANAT-DP', Frequency: 2
# Entity: 'thoracolumbar junction', Label: 'ANAT-DP', Frequency: 2
# Entity: 'compartment', Label: 'ANAT-DP', Frequency: 2
# Entity: 'nodule', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Lateral', Label: 'ANAT-DP', Frequency: 2
# Entity: 'sinuses', Label: 'ANAT-DP', Frequency: 2
# Entity: 'dependent', Label: 'ANAT-DP', Frequency: 2
# Entity: 'posteroinferior', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Vertebral', Label: 'ANAT-DP', Frequency: 2
# Entity: 'paraspinal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Spinal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'cutaneous', Label: 'ANAT-DP', Frequency: 2
# Entity: '8 cm above', Label: 'ANAT-DP', Frequency: 2
# Entity: 'dorsolateral part', Label: 'ANAT-DP', Frequency: 2
# Entity: 'enlarged', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Coronary', Label: 'ANAT-DP', Frequency: 2
# Entity: 'PULMONARY', Label: 'ANAT-DP', Frequency: 2
# Entity: 'BILATERAL', Label: 'ANAT-DP', Frequency: 2
# Entity: 'PLEURAL', Label: 'ANAT-DP', Frequency: 2
# Entity: 'BASILAR', Label: 'ANAT-DP', Frequency: 2
# Entity: 'peripherally', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Multiple', Label: 'ANAT-DP', Frequency: 2
# Entity: 'loops', Label: 'ANAT-DP', Frequency: 2
# Entity: 'small', Label: 'ANAT-DP', Frequency: 2
# Entity: 'bowel', Label: 'ANAT-DP', Frequency: 2
# Entity: 'brachiocephalic', Label: 'ANAT-DP', Frequency: 2
# Entity: '4.6 cm above', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Superiorly', Label: 'ANAT-DP', Frequency: 2
# Entity: 'pleural - based', Label: 'ANAT-DP', Frequency: 2
# Entity: 'sided', Label: 'ANAT-DP', Frequency: 2
# Entity: 'approximately 5 cm', Label: 'ANAT-DP', Frequency: 2
# Entity: 'gastroesophageal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'side port', Label: 'ANAT-DP', Frequency: 2
# Entity: '5.6 cm', Label: 'ANAT-DP', Frequency: 2
# Entity: 'axilla', Label: 'ANAT-DP', Frequency: 2
# Entity: '1.8 cm above', Label: 'ANAT-DP', Frequency: 2
# Entity: 'costal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'cartilage', Label: 'ANAT-DP', Frequency: 2
# Entity: 'bronchial', Label: 'ANAT-DP', Frequency: 2
# Entity: 'peripheral', Label: 'ANAT-DP', Frequency: 2
# Entity: 'mid - to - distal', Label: 'ANAT-DP', Frequency: 2
# Entity: 'side', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Hila', Label: 'ANAT-DP', Frequency: 2
# Entity: 'cavitary', Label: 'ANAT-DP', Frequency: 2
# Entity: 'plerual', Label: 'ANAT-DP', Frequency: 2
# Entity: 'outer margin', Label: 'ANAT-DP', Frequency: 2
# Entity: 'in the expected positions', Label: 'ANAT-DP', Frequency: 2
# Entity: 'coronary', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Central', Label: 'ANAT-DP', Frequency: 2
# Entity: 'biventricular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Base', Label: 'ANAT-DP', Frequency: 2
# Entity: 'glenohumeral', Label: 'ANAT-DP', Frequency: 2
# Entity: 'acromioclavicular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'joints', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Interstitial', Label: 'ANAT-DP', Frequency: 2
# Entity: 'angles', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Peripheral', Label: 'ANAT-DP', Frequency: 2
# Entity: 'interstitium', Label: 'ANAT-DP', Frequency: 2
# Entity: 'T 12 vertebral', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Thoracolumbar', Label: 'ANAT-DP', Frequency: 2
# Entity: 'scapular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'other', Label: 'ANAT-DP', Frequency: 2
# Entity: 'locations', Label: 'ANAT-DP', Frequency: 2
# Entity: 'intersitial', Label: 'ANAT-DP', Frequency: 2
# Entity: 'tricuspid', Label: 'ANAT-DP', Frequency: 2
# Entity: 'takeoff', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Visceral', Label: 'ANAT-DP', Frequency: 2
# Entity: 'regions', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Trachea', Label: 'ANAT-DP', Frequency: 2
# Entity: 'deviated', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Both', Label: 'ANAT-DP', Frequency: 2
# Entity: 'appearance', Label: 'ANAT-DP', Frequency: 2
# Entity: 'AC', Label: 'ANAT-DP', Frequency: 2
# Entity: 'joint', Label: 'ANAT-DP', Frequency: 2
# Entity: 'Bronchovascular', Label: 'ANAT-DP', Frequency: 2
# Entity: 'clear', Label: 'OBS-DP', Frequency: 2
# Entity: 'Normal', Label: 'OBS-DP', Frequency: 2
# Entity: 'Endotracheal', Label: 'OBS-DP', Frequency: 2
# Entity: 'tube', Label: 'OBS-DP', Frequency: 2
# Entity: 'tip', Label: 'OBS-DP', Frequency: 2
# Entity: 'Enteric', Label: 'OBS-DP', Frequency: 2
# Entity: 'advanced by at least 11 cm', Label: 'OBS-DP', Frequency: 2
# Entity: 'normal', Label: 'OBS-DP', Frequency: 2
# Entity: 'grossly', Label: 'OBS-DP', Frequency: 2
# Entity: 'unremarkable', Label: 'OBS-DP', Frequency: 2
# Entity: 'minimal', Label: 'OBS-DP', Frequency: 2
# Entity: 'atelectasis', Label: 'OBS-DP', Frequency: 2
# Entity: 'slightly', Label: 'OBS-DP', Frequency: 2
# Entity: 'obscured', Label: 'OBS-DP', Frequency: 2
# Entity: 'patient 's chin', Label: 'OBS-DP', Frequency: 2
# Entity: 'Gaseous', Label: 'OBS-DP', Frequency: 2
# Entity: 'distension', Label: 'OBS-DP', Frequency: 2
# Entity: 'Standard', Label: 'OBS-DP', Frequency: 2
# Entity: 'positioning', Label: 'OBS-DP', Frequency: 2
# Entity: 'endotracheal', Label: 'OBS-DP', Frequency: 2
# Entity: 'distention', Label: 'OBS-DP', Frequency: 2
# Entity: 'nasogastric', Label: 'OBS-DP', Frequency: 2
# Entity: 'The side - port', Label: 'OBS-DP', Frequency: 2
# Entity: 'Otherwise', Label: 'OBS-DP', Frequency: 2
# Entity: 'little', Label: 'OBS-DP', Frequency: 2
# Entity: 'change', Label: 'OBS-DP', Frequency: 2
# Entity: 'stable', Label: 'OBS-DP', Frequency: 2
# Entity: 'ET', Label: 'OBS-DP', Frequency: 2
# Entity: 'NG', Label: 'OBS-DP', Frequency: 2
# Entity: 'malpositioned', Label: 'OBS-DP', Frequency: 2
# Entity: 'appropriate', Label: 'OBS-DP', Frequency: 2
# Entity: 'position', Label: 'OBS-DP', Frequency: 2
# Entity: 'enteric', Label: 'OBS-DP', Frequency: 2
# Entity: 'side ports', Label: 'OBS-DP', Frequency: 2
# Entity: 'low', Label: 'OBS-DP', Frequency: 2
# Entity: 'intact', Label: 'OBS-DP', Frequency: 2
# Entity: 'Limited', Label: 'OBS-DP', Frequency: 2
# Entity: 'negative', Label: 'OBS-DP', Frequency: 2
# Entity: 'Low', Label: 'OBS-DP', Frequency: 2
# Entity: 'This', Label: 'OBS-DP', Frequency: 2
# Entity: 'mildly', Label: 'OBS-DP', Frequency: 2
# Entity: 'enlarged', Label: 'OBS-DP', Frequency: 2
# Entity: 'unchanged', Label: 'OBS-DP', Frequency: 2
# Entity: 'crowding', Label: 'OBS-DP', Frequency: 2
# Entity: 'Minimal', Label: 'OBS-DP', Frequency: 2
# Entity: 'patchy', Label: 'OBS-DP', Frequency: 2
# Entity: 'opacities', Label: 'OBS-DP', Frequency: 2
# Entity: 'Patchy', Label: 'OBS-DP', Frequency: 2
# Entity: 'Borderline', Label: 'OBS-DP', Frequency: 2
# Entity: 'frontal', Label: 'OBS-DP', Frequency: 2
# Entity: 'lateral', Label: 'OBS-DP', Frequency: 2
# Entity: 'radiograph', Label: 'OBS-DP', Frequency: 2
# Entity: 'Moderate', Label: 'OBS-DP', Frequency: 2
# Entity: 'scoliosis', Label: 'OBS-DP', Frequency: 2
# Entity: 'asymmetry', Label: 'OBS-DP', Frequency: 2
# Entity: 'Mildly', Label: 'OBS-DP', Frequency: 2
# Entity: 'underinflated', Label: 'OBS-DP', Frequency: 2
# Entity: 'largely', Label: 'OBS-DP', Frequency: 2
# Entity: 'The lateral view is limited', Label: 'OBS-DP', Frequency: 2
# Entity: 'patient 's arms', Label: 'OBS-DP', Frequency: 2
# Entity: 'increased', Label: 'OBS-DP', Frequency: 2
# Entity: 'opacity', Label: 'OBS-DP', Frequency: 2
# Entity: 'They', Label: 'OBS-DP', Frequency: 2
# Entity: 'more', Label: 'OBS-DP', Frequency: 2
# Entity: 'conspicuous', Label: 'OBS-DP', Frequency: 2
# Entity: 'recent exam from ___', Label: 'OBS-DP', Frequency: 2
# Entity: 'similar', Label: 'OBS-DP', Frequency: 2
# Entity: 'previous exams from ___', Label: 'OBS-DP', Frequency: 2
# Entity: 'Old', Label: 'OBS-DP', Frequency: 2
# Entity: 'fractures', Label: 'OBS-DP', Frequency: 2
# Entity: 'difficult to assess', Label: 'OBS-DP', Frequency: 2
# Entity: 'overall', Label: 'OBS-DP', Frequency: 2
# Entity: 'appearance', Label: 'OBS-DP', Frequency: 2
# Entity: 'obscuring', Label: 'OBS-DP', Frequency: 2
# Entity: 'cannot be assessed', Label: 'OBS-DP', Frequency: 2
# Entity: 'Overall', Label: 'OBS-DP', Frequency: 2
# Entity: 'findings', Label: 'OBS-DP', Frequency: 2
# Entity: 'pneumonia', Label: 'OBS-DP', Frequency: 2
# Entity: 'New', Label: 'OBS-DP', Frequency: 2
# Entity: 'significant', Label: 'OBS-DP', Frequency: 2
# Entity: 'Evaluation is limited', Label: 'OBS-DP', Frequency: 2
# Entity: 'patient 's head', Label: 'OBS-DP', Frequency: 2
# Entity: 'visualized', Label: 'OBS-DP', Frequency: 2
# Entity: 'increasing', Label: 'OBS-DP', Frequency: 2
# Entity: 'edema', Label: 'OBS-DP', Frequency: 2
# Entity: 'substantial', Label: 'OBS-DP', Frequency: 2
# Entity: 'layering', Label: 'OBS-DP', Frequency: 2
# Entity: 'effusions', Label: 'OBS-DP', Frequency: 2
# Entity: 'compressive', Label: 'OBS-DP', Frequency: 2
# Entity: 'worse', Label: 'OBS-DP', Frequency: 2
# Entity: 'loculation', Label: 'OBS-DP', Frequency: 2
# Entity: 'device', Label: 'OBS-DP', Frequency: 2
# Entity: 'subjacent', Label: 'OBS-DP', Frequency: 2
# Entity: 'well', Label: 'OBS-DP', Frequency: 2
# Entity: 'aerated', Label: 'OBS-DP', Frequency: 2
# Entity: 'TIPS', Label: 'OBS-DP', Frequency: 2
# Entity: 'consolidations', Label: 'OBS-DP', Frequency: 2
# Entity: 'loculated', Label: 'OBS-DP', Frequency: 2
# Entity: 'effusion', Label: 'OBS-DP', Frequency: 2
# Entity: 'areas', Label: 'OBS-DP', Frequency: 2
# Entity: 'round', Label: 'OBS-DP', Frequency: 2
# Entity: 'larger', Label: 'OBS-DP', Frequency: 2
# Entity: 'Small', Label: 'OBS-DP', Frequency: 2
# Entity: 'Unchanged', Label: 'OBS-DP', Frequency: 2
# Entity: 'within', Label: 'OBS-DP', Frequency: 2
# Entity: 'limits', Label: 'OBS-DP', Frequency: 2
# Entity: 'unfolded', Label: 'OBS-DP', Frequency: 2
# Entity: 'small', Label: 'OBS-DP', Frequency: 2
# Entity: 'moderate', Label: 'OBS-DP', Frequency: 2
# Entity: 'size', Label: 'OBS-DP', Frequency: 2
# Entity: 'partially', Label: 'OBS-DP', Frequency: 2
# Entity: 'overlying', Label: 'OBS-DP', Frequency: 2
# Entity: 'wires', Label: 'OBS-DP', Frequency: 2
# Entity: 'increase', Label: 'OBS-DP', Frequency: 2
# Entity: 'component', Label: 'OBS-DP', Frequency: 2
# Entity: 'not well assessed', Label: 'OBS-DP', Frequency: 2
# Entity: 'mild', Label: 'OBS-DP', Frequency: 2
# Entity: 'post - operative', Label: 'OBS-DP', Frequency: 2
# Entity: 'alignment', Label: 'OBS-DP', Frequency: 2
# Entity: 'Mild', Label: 'OBS-DP', Frequency: 2
# Entity: 'Stable', Label: 'OBS-DP', Frequency: 2
# Entity: 'cardiomegaly', Label: 'OBS-DP', Frequency: 2
# Entity: 'enlargement', Label: 'OBS-DP', Frequency: 2
# Entity: 'PICC', Label: 'OBS-DP', Frequency: 2
# Entity: 'line', Label: 'OBS-DP', Frequency: 2
# Entity: 'elevated', Label: 'OBS-DP', Frequency: 2
# Entity: 'pressure', Label: 'OBS-DP', Frequency: 2
# Entity: 'sharply', Label: 'OBS-DP', Frequency: 2
# Entity: 'decrease', Label: 'OBS-DP', Frequency: 2
# Entity: 'opacification', Label: 'OBS-DP', Frequency: 2
# Entity: 'an', Label: 'OBS-DP', Frequency: 2
# Entity: 'prominent', Label: 'OBS-DP', Frequency: 2
# Entity: 'underlying', Label: 'OBS-DP', Frequency: 2
# Entity: 'top - normal', Label: 'OBS-DP', Frequency: 2
# Entity: 'hypertension', Label: 'OBS-DP', Frequency: 2
# Entity: 'Enlarged', Label: 'OBS-DP', Frequency: 2
# Entity: 'prominence', Label: 'OBS-DP', Frequency: 2
# Entity: 'atrium', Label: 'OBS-DP', Frequency: 2
# Entity: 'adjacent', Label: 'OBS-DP', Frequency: 2
# Entity: 'engorgement', Label: 'OBS-DP', Frequency: 2
# Entity: 'failure', Label: 'OBS-DP', Frequency: 2
# Entity: 'layer', Label: 'OBS-DP', Frequency: 2
# Entity: 'dependently', Label: 'OBS-DP', Frequency: 2
# Entity: 'peculiar', Label: 'OBS-DP', Frequency: 2
# Entity: 'shape', Label: 'OBS-DP', Frequency: 2
# Entity: 'relatively', Label: 'OBS-DP', Frequency: 2
# Entity: 'not less distinct', Label: 'OBS-DP', Frequency: 2
# Entity: 'volume', Label: 'OBS-DP', Frequency: 2
# Entity: 'overload', Label: 'OBS-DP', Frequency: 2
# Entity: 'Nasogastric', Label: 'OBS-DP', Frequency: 2
# Entity: 'out of review', Label: 'OBS-DP', Frequency: 2
# Entity: 'Multiple', Label: 'OBS-DP', Frequency: 2
# Entity: 'fracture', Label: 'OBS-DP', Frequency: 2
# Entity: 'lower', Label: 'OBS-DP', Frequency: 2
# Entity: 'multiple', Label: 'OBS-DP', Frequency: 2
# Entity: 'posttraumatic', Label: 'OBS-DP', Frequency: 2
# Entity: 'deformities', Label: 'OBS-DP', Frequency: 2
# Entity: 'Massive', Label: 'OBS-DP', Frequency: 2
# Entity: 'congestion', Label: 'OBS-DP', Frequency: 2
# Entity: 'nearly', Label: 'OBS-DP', Frequency: 2
# Entity: 'resolved', Label: 'OBS-DP', Frequency: 2
# Entity: 'Nonspecific', Label: 'OBS-DP', Frequency: 2
# Entity: 'convex', Label: 'OBS-DP', Frequency: 2
# Entity: 'old', Label: 'OBS-DP', Frequency: 2
# Entity: 'Slight', Label: 'OBS-DP', Frequency: 2
# Entity: 'focal', Label: 'OBS-DP', Frequency: 2
# Entity: 'calcified', Label: 'OBS-DP', Frequency: 2
# Entity: 'Severe', Label: 'OBS-DP', Frequency: 2
# Entity: 'standard', Label: 'OBS-DP', Frequency: 2
# Entity: 'Interval', Label: 'OBS-DP', Frequency: 2
# Entity: 'improved', Label: 'OBS-DP', Frequency: 2
# Entity: 'aeration', Label: 'OBS-DP', Frequency: 2
# Entity: 'resolution', Label: 'OBS-DP', Frequency: 2
# Entity: 'new', Label: 'OBS-DP', Frequency: 2
# Entity: 'confluent', Label: 'OBS-DP', Frequency: 2
# Entity: 'chronic', Label: 'OBS-DP', Frequency: 2
# Entity: 'thickening', Label: 'OBS-DP', Frequency: 2
# Entity: 'S type', Label: 'OBS-DP', Frequency: 2
# Entity: 'similar to prior', Label: 'OBS-DP', Frequency: 2
# Entity: 'tortuosity', Label: 'OBS-DP', Frequency: 2
# Entity: 'Elevation', Label: 'OBS-DP', Frequency: 2
# Entity: 'linear', Label: 'OBS-DP', Frequency: 2
# Entity: 'elevation', Label: 'OBS-DP', Frequency: 2
# Entity: 'scarring', Label: 'OBS-DP', Frequency: 2
# Entity: 'streaky', Label: 'OBS-DP', Frequency: 2
# Entity: 'top', Label: 'OBS-DP', Frequency: 2
# Entity: 'Air', Label: 'OBS-DP', Frequency: 2
# Entity: 'slight', Label: 'OBS-DP', Frequency: 2
# Entity: 'interval', Label: 'OBS-DP', Frequency: 2
# Entity: 'hyperinflated', Label: 'OBS-DP', Frequency: 2
# Entity: 'greater', Label: 'OBS-DP', Frequency: 2
# Entity: 'Sternotomy', Label: 'OBS-DP', Frequency: 2
# Entity: 'extensive', Label: 'OBS-DP', Frequency: 2
# Entity: 'clips', Label: 'OBS-DP', Frequency: 2
# Entity: 'status', Label: 'OBS-DP', Frequency: 2
# Entity: 'post', Label: 'OBS-DP', Frequency: 2
# Entity: 'median', Label: 'OBS-DP', Frequency: 2
# Entity: 'sternotomy', Label: 'OBS-DP', Frequency: 2
# Entity: 'CABG', Label: 'OBS-DP', Frequency: 2
# Entity: 'obstructive', Label: 'OBS-DP', Frequency: 2
# Entity: 'disease', Label: 'OBS-DP', Frequency: 2
# Entity: 'Degenerative', Label: 'OBS-DP', Frequency: 2
# Entity: 'changes', Label: 'OBS-DP', Frequency: 2
# Entity: 'along', Label: 'OBS-DP', Frequency: 2
# Entity: 'COPD', Label: 'OBS-DP', Frequency: 2
# Entity: 'blunting', Label: 'OBS-DP', Frequency: 2
# Entity: 'trace', Label: 'OBS-DP', Frequency: 2
# Entity: 'borderline', Label: 'OBS-DP', Frequency: 2
# Entity: 'calcifications', Label: 'OBS-DP', Frequency: 2
# Entity: 'multilevel', Label: 'OBS-DP', Frequency: 2
# Entity: 'degenerative', Label: 'OBS-DP', Frequency: 2
# Entity: 'post CABG', Label: 'OBS-DP', Frequency: 2
# Entity: 'appropriately', Label: 'OBS-DP', Frequency: 2
# Entity: 'aligned', Label: 'OBS-DP', Frequency: 2
# Entity: 'flattened', Label: 'OBS-DP', Frequency: 2
# Entity: 'markings', Label: 'OBS-DP', Frequency: 2
# Entity: 'subtle', Label: 'OBS-DP', Frequency: 2
# Entity: '9 mm', Label: 'OBS-DP', Frequency: 2
# Entity: 'otherwise', Label: 'OBS-DP', Frequency: 2
# Entity: 'elongation', Label: 'OBS-DP', Frequency: 2
# Entity: 'flattening', Label: 'OBS-DP', Frequency: 2
# Entity: 'diffuse', Label: 'OBS-DP', Frequency: 2
# Entity: 'Improving', Label: 'OBS-DP', Frequency: 2
# Entity: 'moderately', Label: 'OBS-DP', Frequency: 2
# Entity: 'Scattered', Label: 'OBS-DP', Frequency: 2
# Entity: 'nodules', Label: 'OBS-DP', Frequency: 2
# Entity: 'secondary', Label: 'OBS-DP', Frequency: 2
# Entity: 'accentuation', Label: 'OBS-DP', Frequency: 2
# Entity: 'Tortuosity', Label: 'OBS-DP', Frequency: 2
# Entity: 'Cardiomegaly', Label: 'OBS-DP', Frequency: 2
# Entity: 'Ovoid', Label: 'OBS-DP', Frequency: 2
# Entity: 'Diffuse', Label: 'OBS-DP', Frequency: 2
# Entity: 'Supportive', Label: 'OBS-DP', Frequency: 2
# Entity: 'devices', Label: 'OBS-DP', Frequency: 2
# Entity: 'monitoring', Label: 'OBS-DP', Frequency: 2
# Entity: 'support', Label: 'OBS-DP', Frequency: 2
# Entity: 'Continued', Label: 'OBS-DP', Frequency: 2
# Entity: 'loss', Label: 'OBS-DP', Frequency: 2
# Entity: 'fully', Label: 'OBS-DP', Frequency: 2
# Entity: 'expanded', Label: 'OBS-DP', Frequency: 2
# Entity: 'dense', Label: 'OBS-DP', Frequency: 2
# Entity: 'midline', Label: 'OBS-DP', Frequency: 2
# Entity: 'fluid', Label: 'OBS-DP', Frequency: 2
# Entity: 'Opacification', Label: 'OBS-DP', Frequency: 2
# Entity: 'Monitoring', Label: 'OBS-DP', Frequency: 2
# Entity: 'port', Label: 'OBS-DP', Frequency: 2
# Entity: 'catheter', Label: 'OBS-DP', Frequency: 2
# Entity: 'Hyperinflated', Label: 'OBS-DP', Frequency: 2
# Entity: 'upper', Label: 'OBS-DP', Frequency: 2
# Entity: 'in position', Label: 'OBS-DP', Frequency: 2
# Entity: 'Increase', Label: 'OBS-DP', Frequency: 2
# Entity: 'caliber', Label: 'OBS-DP', Frequency: 2
# Entity: 'Port - A - Cath', Label: 'OBS-DP', Frequency: 2
# Entity: 'essentially', Label: 'OBS-DP', Frequency: 2
# Entity: 'inflated', Label: 'OBS-DP', Frequency: 2
# Entity: 'calcification', Label: 'OBS-DP', Frequency: 2
# Entity: 'demineralization', Label: 'OBS-DP', Frequency: 2
# Entity: 'Well', Label: 'OBS-DP', Frequency: 2
# Entity: 'Linear', Label: 'OBS-DP', Frequency: 2
# Entity: 'redistribution', Label: 'OBS-DP', Frequency: 2
# Entity: 'hazy', Label: 'OBS-DP', Frequency: 2
# Entity: 'ill - defined', Label: 'OBS-DP', Frequency: 2
# Entity: 'vascularity', Label: 'OBS-DP', Frequency: 2
# Entity: 'IJ', Label: 'OBS-DP', Frequency: 2
# Entity: 'Increased', Label: 'OBS-DP', Frequency: 2
# Entity: 'faint', Label: 'OBS-DP', Frequency: 2
# Entity: 'Multifocal', Label: 'OBS-DP', Frequency: 2
# Entity: 'infection', Label: 'OBS-DP', Frequency: 2
# Entity: 'decreased', Label: 'OBS-DP', Frequency: 2
# Entity: 'in extent', Label: 'OBS-DP', Frequency: 2
# Entity: 'severity', Label: 'OBS-DP', Frequency: 2
# Entity: 'replacement', Label: 'OBS-DP', Frequency: 2
# Entity: 'right internal jugular vein', Label: 'OBS-DP', Frequency: 2
# Entity: 'Discrete', Label: 'OBS-DP', Frequency: 2
# Entity: 'consolidation', Label: 'OBS-DP', Frequency: 2
# Entity: 'worsened', Label: 'OBS-DP', Frequency: 2
# Entity: 'postoperative', Label: 'OBS-DP', Frequency: 2
# Entity: 'drains', Label: 'OBS-DP', Frequency: 2
# Entity: 'in place', Label: 'OBS-DP', Frequency: 2
# Entity: 'Swan - Ganz', Label: 'OBS-DP', Frequency: 2
# Entity: 'placement', Label: 'OBS-DP', Frequency: 2
# Entity: 'nondistended', Label: 'OBS-DP', Frequency: 2
# Entity: 'migrated', Label: 'OBS-DP', Frequency: 2
# Entity: 'proximally', Label: 'OBS-DP', Frequency: 2
# Entity: 'blurring', Label: 'OBS-DP', Frequency: 2
# Entity: 'horizontal', Label: 'OBS-DP', Frequency: 2
# Entity: 'proximal', Label: 'OBS-DP', Frequency: 2
# Entity: 'side port', Label: 'OBS-DP', Frequency: 2
# Entity: 'other', Label: 'OBS-DP', Frequency: 2
# Entity: 'homogeneous', Label: 'OBS-DP', Frequency: 2
# Entity: 'Trace', Label: 'OBS-DP', Frequency: 2
# Entity: 'constant', Label: 'OBS-DP', Frequency: 2
# Entity: 'Surgical', Label: 'OBS-DP', Frequency: 2
# Entity: 'symmetrical', Label: 'OBS-DP', Frequency: 2
# Entity: 'surgical', Label: 'OBS-DP', Frequency: 2
# Entity: 'deviation', Label: 'OBS-DP', Frequency: 2
# Entity: 'left', Label: 'OBS-DP', Frequency: 2
# Entity: 'vessel on end', Label: 'OBS-DP', Frequency: 2
# Entity: 'Consolidative', Label: 'OBS-DP', Frequency: 2
# Entity: 'NORMAL', Label: 'OBS-DP', Frequency: 2
# Entity: 'accessory', Label: 'OBS-DP', Frequency: 2
# Entity: 'azygos', Label: 'OBS-DP', Frequency: 2
# Entity: 'fissure', Label: 'OBS-DP', Frequency: 2
# Entity: 'tortuous', Label: 'OBS-DP', Frequency: 2
# Entity: 'atherosclerotic', Label: 'OBS-DP', Frequency: 2
# Entity: 'Crowding', Label: 'OBS-DP', Frequency: 2
# Entity: 'decompensated', Label: 'OBS-DP', Frequency: 2
# Entity: 'CHF', Label: 'OBS-DP', Frequency: 2
# Entity: 'Calcific', Label: 'OBS-DP', Frequency: 2
# Entity: 'densities', Label: 'OBS-DP', Frequency: 2
# Entity: 'gallbladder', Label: 'OBS-DP', Frequency: 2
# Entity: 'crowding of', Label: 'OBS-DP', Frequency: 2
# Entity: 'minimally', Label: 'OBS-DP', Frequency: 2
# Entity: 'changed', Label: 'OBS-DP', Frequency: 2
# Entity: 'crowd', Label: 'OBS-DP', Frequency: 2
# Entity: 'vasculature', Label: 'OBS-DP', Frequency: 2
# Entity: 'better', Label: 'OBS-DP', Frequency: 2
# Entity: 'some', Label: 'OBS-DP', Frequency: 2
# Entity: 'Blunting', Label: 'OBS-DP', Frequency: 2
# Entity: 'in standard position', Label: 'OBS-DP', Frequency: 2
# Entity: 'side holes', Label: 'OBS-DP', Frequency: 2
# Entity: 'dual', Label: 'OBS-DP', Frequency: 2
# Entity: 'lead', Label: 'OBS-DP', Frequency: 2
# Entity: 'pacemaker', Label: 'OBS-DP', Frequency: 2
# Entity: 'tips', Label: 'OBS-DP', Frequency: 2
# Entity: '3.5 cm', Label: 'OBS-DP', Frequency: 2
# Entity: 'metallic', Label: 'OBS-DP', Frequency: 2
# Entity: 'foreign', Label: 'OBS-DP', Frequency: 2
# Entity: 'object', Label: 'OBS-DP', Frequency: 2
# Entity: 'two', Label: 'OBS-DP', Frequency: 2
# Entity: 'components', Label: 'OBS-DP', Frequency: 2
# Entity: 'curvilinear', Label: 'OBS-DP', Frequency: 2
# Entity: 'iatrogenic', Label: 'OBS-DP', Frequency: 2
# Entity: 'well - expanded', Label: 'OBS-DP', Frequency: 2
# Entity: 'in acceptable position', Label: 'OBS-DP', Frequency: 2
# Entity: 'advanced', Label: 'OBS-DP', Frequency: 2
# Entity: 'by several centimeters', Label: 'OBS-DP', Frequency: 2
# Entity: 'implement', Label: 'OBS-DP', Frequency: 2
# Entity: 'not seen', Label: 'OBS-DP', Frequency: 2
# Entity: 'less', Label: 'OBS-DP', Frequency: 2
# Entity: 'not well seen', Label: 'OBS-DP', Frequency: 2
# Entity: 'Pacer', Label: 'OBS-DP', Frequency: 2
# Entity: 'leads', Label: 'OBS-DP', Frequency: 2
# Entity: 'improvement', Label: 'OBS-DP', Frequency: 2
# Entity: 'less prominent', Label: 'OBS-DP', Frequency: 2
# Entity: 'upright position', Label: 'OBS-DP', Frequency: 2
# Entity: 'atelectatic', Label: 'OBS-DP', Frequency: 2
# Entity: 'chest', Label: 'OBS-DP', Frequency: 2
# Entity: 'on waterseal', Label: 'OBS-DP', Frequency: 2
# Entity: 'amount', Label: 'OBS-DP', Frequency: 2
# Entity: 'partially assessed', Label: 'OBS-DP', Frequency: 2
# Entity: 'Atelectatic', Label: 'OBS-DP', Frequency: 2
# Entity: 'existing', Label: 'OBS-DP', Frequency: 2
# Entity: 'thickenings', Label: 'OBS-DP', Frequency: 2
# Entity: 'injury', Label: 'OBS-DP', Frequency: 2
# Entity: 'regressed', Label: 'OBS-DP', Frequency: 2
# Entity: 'displaced', Label: 'OBS-DP', Frequency: 2
# Entity: 'injuries', Label: 'OBS-DP', Frequency: 2
# Entity: 'comminuted', Label: 'OBS-DP', Frequency: 2
# Entity: 'displacement', Label: 'OBS-DP', Frequency: 2
# Entity: 'to the right', Label: 'OBS-DP', Frequency: 2
# Entity: 'obliquity of the patient', Label: 'OBS-DP', Frequency: 2
# Entity: 'several', Label: 'OBS-DP', Frequency: 2
# Entity: 'Poor definition', Label: 'OBS-DP', Frequency: 2
# Entity: 'not as well seen on this study', Label: 'OBS-DP', Frequency: 2
# Entity: 'lucency', Label: 'OBS-DP', Frequency: 2
# Entity: 'residual', Label: 'OBS-DP', Frequency: 2
# Entity: 'pneumothorax', Label: 'OBS-DP', Frequency: 2
# Entity: 'air', Label: 'OBS-DP', Frequency: 2
# Entity: 'Extensive', Label: 'OBS-DP', Frequency: 2
# Entity: 'emphysema', Label: 'OBS-DP', Frequency: 2
# Entity: 'Pneumomediastinum', Label: 'OBS-DP', Frequency: 2
# Entity: 'pneumopericardium', Label: 'OBS-DP', Frequency: 2
# Entity: 'severely', Label: 'OBS-DP', Frequency: 2
# Entity: 'fractured', Label: 'OBS-DP', Frequency: 2
# Entity: 'hemorrahge', Label: 'OBS-DP', Frequency: 2
# Entity: 'assessment', Label: 'OBS-DP', Frequency: 2
# Entity: 'limited', Label: 'OBS-DP', Frequency: 2
# Entity: 'Focal', Label: 'OBS-DP', Frequency: 2
# Entity: 'pneumomediastinum', Label: 'OBS-DP', Frequency: 2
# Entity: 'drain', Label: 'OBS-DP', Frequency: 2
# Entity: 'higher', Label: 'OBS-DP', Frequency: 2
# Entity: 'opacified', Label: 'OBS-DP', Frequency: 2
# Entity: 'alongside', Label: 'OBS-DP', Frequency: 2
# Entity: 'elongated', Label: 'OBS-DP', Frequency: 2
# Entity: 'aortosclerosis', Label: 'OBS-DP', Frequency: 2
# Entity: 'increse', Label: 'OBS-DP', Frequency: 2
# Entity: 'collections', Label: 'OBS-DP', Frequency: 2
# Entity: 'very', Label: 'OBS-DP', Frequency: 2
# Entity: 'sharp', Label: 'OBS-DP', Frequency: 2
# Entity: 'severe', Label: 'OBS-DP', Frequency: 2
# Entity: 'deeper', Label: 'OBS-DP', Frequency: 2
# Entity: 'pneumo mediastinum', Label: 'OBS-DP', Frequency: 2
# Entity: 'large', Label: 'OBS-DP', Frequency: 2
# Entity: 'tiny', Label: 'OBS-DP', Frequency: 2
# Entity: '1-2 mm', Label: 'OBS-DP', Frequency: 2
# Entity: 'Unremarkable', Label: 'OBS-DP', Frequency: 2
# Entity: 'examination', Label: 'OBS-DP', Frequency: 2
# Entity: 'clip', Label: 'OBS-DP', Frequency: 2
# Entity: 'Clear', Label: 'OBS-DP', Frequency: 2
# Entity: 'nipple', Label: 'OBS-DP', Frequency: 2
# Entity: 'shadows', Label: 'OBS-DP', Frequency: 2
# Entity: 'A', Label: 'OBS-DP', Frequency: 2
# Entity: 'rod', Label: 'OBS-DP', Frequency: 2
# Entity: 'overlies', Label: 'OBS-DP', Frequency: 2
# Entity: 'area', Label: 'OBS-DP', Frequency: 2
# Entity: 'diameter', Label: 'OBS-DP', Frequency: 2
# Entity: '1.5 cm', Label: 'OBS-DP', Frequency: 2
# Entity: 'deformity', Label: 'OBS-DP', Frequency: 2
# Entity: 'Clips', Label: 'OBS-DP', Frequency: 2
# Entity: 'mediastinal', Label: 'OBS-DP', Frequency: 2
# Entity: 'tubes', Label: 'OBS-DP', Frequency: 2
# Entity: 'sheath', Label: 'OBS-DP', Frequency: 2
# Entity: 'positions', Label: 'OBS-DP', Frequency: 2
# Entity: 'lines', Label: 'OBS-DP', Frequency: 2
# Entity: 'pneumothoraces', Label: 'OBS-DP', Frequency: 2
# Entity: 'distance', Label: 'OBS-DP', Frequency: 2
# Entity: 'bubble', Label: 'OBS-DP', Frequency: 2
# Entity: 'Lines', Label: 'OBS-DP', Frequency: 2
# Entity: 'over', Label: 'OBS-DP', Frequency: 2
# Entity: 'Post - operative', Label: 'OBS-DP', Frequency: 2
# Entity: 'predominance', Label: 'OBS-DP', Frequency: 2
# Entity: 'markedly', Label: 'OBS-DP', Frequency: 2
# Entity: 'Calcified', Label: 'OBS-DP', Frequency: 2
# Entity: 'Streaky', Label: 'OBS-DP', Frequency: 2
# Entity: 'diffusely', Label: 'OBS-DP', Frequency: 2
# Entity: 'demineralized', Label: 'OBS-DP', Frequency: 2
# Entity: 'compression', Label: 'OBS-DP', Frequency: 2
# Entity: 'Deformity', Label: 'OBS-DP', Frequency: 2
# Entity: 'indistinctness', Label: 'OBS-DP', Frequency: 2
# Entity: 'progression', Label: 'OBS-DP', Frequency: 2
# Entity: 'interstitial', Label: 'OBS-DP', Frequency: 2
# Entity: 'worsening', Label: 'OBS-DP', Frequency: 2
# Entity: 'atypical', Label: 'OBS-DP', Frequency: 2
# Entity: 'reticular', Label: 'OBS-DP', Frequency: 2
# Entity: 'previous', Label: 'OBS-DP', Frequency: 2
# Entity: 'moderate - sized', Label: 'OBS-DP', Frequency: 2
# Entity: 'cluster', Label: 'OBS-DP', Frequency: 2
# Entity: 'infiltration', Label: 'OBS-DP', Frequency: 2
# Entity: 'granulomatous', Label: 'OBS-DP', Frequency: 2
# Entity: 'Study', Label: 'OBS-DP', Frequency: 2
# Entity: 'poor', Label: 'OBS-DP', Frequency: 2
# Entity: 'penetration', Label: 'OBS-DP', Frequency: 2
# Entity: 'reexpansion', Label: 'OBS-DP', Frequency: 2
# Entity: 'thoracocentesis', Label: 'OBS-DP', Frequency: 2
# Entity: 'pre - existing', Label: 'OBS-DP', Frequency: 2
# Entity: 'substantially', Label: 'OBS-DP', Frequency: 2
# Entity: 'obscures', Label: 'OBS-DP', Frequency: 2
# Entity: 'right', Label: 'OBS-DP', Frequency: 2
# Entity: 'granuloma', Label: 'OBS-DP', Frequency: 2
# Entity: 'Size', Label: 'OBS-DP', Frequency: 2
# Entity: 'in size', Label: 'OBS-DP', Frequency: 2
# Entity: 'Decreased', Label: 'OBS-DP', Frequency: 2
# Entity: 'engorged', Label: 'OBS-DP', Frequency: 2
# Entity: 'Enlarging', Label: 'OBS-DP', Frequency: 2
# Entity: 'infiltrate', Label: 'OBS-DP', Frequency: 2
# Entity: 'haziness', Label: 'OBS-DP', Frequency: 2
# Entity: 'Large', Label: 'OBS-DP', Frequency: 2
# Entity: 'retracted 4.5 cm', Label: 'OBS-DP', Frequency: 2
# Entity: 'pulled back about 5 cm', Label: 'OBS-DP', Frequency: 2
# Entity: 'Feeding', Label: 'OBS-DP', Frequency: 2
# Entity: 'wire', Label: 'OBS-DP', Frequency: 2
# Entity: 'stylet', Label: 'OBS-DP', Frequency: 2
# Entity: 'Subtle', Label: 'OBS-DP', Frequency: 2
# Entity: 'Improved', Label: 'OBS-DP', Frequency: 2
# Entity: 'internal jugular central venous', Label: 'OBS-DP', Frequency: 2
# Entity: 'reasonably', Label: 'OBS-DP', Frequency: 2
# Entity: 'well defined', Label: 'OBS-DP', Frequency: 2
# Entity: 'Cephalization', Label: 'OBS-DP', Frequency: 2
# Entity: 'Comminuted', Label: 'OBS-DP', Frequency: 2
# Entity: 'hypoventilation', Label: 'OBS-DP', Frequency: 2
# Entity: 'setting of splinting', Label: 'OBS-DP', Frequency: 2
# Entity: 'Partially imaged', Label: 'OBS-DP', Frequency: 2
# Entity: 'fusion', Label: 'OBS-DP', Frequency: 2
# Entity: 'hardware', Label: 'OBS-DP', Frequency: 2
# Entity: 'persistently', Label: 'OBS-DP', Frequency: 2
# Entity: 'acute', Label: 'OBS-DP', Frequency: 2
# Entity: 'Displaced', Label: 'OBS-DP', Frequency: 2
# Entity: 'healed', Label: 'OBS-DP', Frequency: 2
# Entity: 'similar compared to the previous exams', Label: 'OBS-DP', Frequency: 2
# Entity: 'especially', Label: 'OBS-DP', Frequency: 2
# Entity: 'orientation', Label: 'OBS-DP', Frequency: 2
# Entity: 'fixation', Label: 'OBS-DP', Frequency: 2
# Entity: 'transesophageal', Label: 'OBS-DP', Frequency: 2
# Entity: 'SVC', Label: 'OBS-DP', Frequency: 2
# Entity: 'developing', Label: 'OBS-DP', Frequency: 2
# Entity: 'central', Label: 'OBS-DP', Frequency: 2
# Entity: 'venous', Label: 'OBS-DP', Frequency: 2
# Entity: 'Developing', Label: 'OBS-DP', Frequency: 2
# Entity: 'development', Label: 'OBS-DP', Frequency: 2
# Entity: 'widespread', Label: 'OBS-DP', Frequency: 2
# Entity: 'Support', Label: 'OBS-DP', Frequency: 2
# Entity: 'in', Label: 'OBS-DP', Frequency: 2
# Entity: 'osteopenia', Label: 'OBS-DP', Frequency: 2
# Entity: 'sparing', Label: 'OBS-DP', Frequency: 2
# Entity: 'Previous', Label: 'OBS-DP', Frequency: 2
# Entity: 'process', Label: 'OBS-DP', Frequency: 2
# Entity: 'Findings', Label: 'OBS-DP', Frequency: 2
# Entity: 'stably', Label: 'OBS-DP', Frequency: 2
# Entity: 'Status', Label: 'OBS-DP', Frequency: 2
# Entity: 'Loops', Label: 'OBS-DP', Frequency: 2
# Entity: 'Moderately', Label: 'OBS-DP', Frequency: 2
# Entity: 'Improvement', Label: 'OBS-DP', Frequency: 2
# Entity: 'plate - like', Label: 'OBS-DP', Frequency: 2
# Entity: 'platelike', Label: 'OBS-DP', Frequency: 2
# Entity: 'a', Label: 'OBS-DP', Frequency: 2
# Entity: 'distal', Label: 'OBS-DP', Frequency: 2
# Entity: 'persistent', Label: 'OBS-DP', Frequency: 2
# Entity: 'Plate - like', Label: 'OBS-DP', Frequency: 2
# Entity: 'patient', Label: 'OBS-DP', Frequency: 2
# Entity: 'extubated', Label: 'OBS-DP', Frequency: 2
# Entity: 'radiodensity', Label: 'OBS-DP', Frequency: 2
# Entity: 'lying', Label: 'OBS-DP', Frequency: 2
# Entity: 'Two', Label: 'OBS-DP', Frequency: 2
# Entity: '2', Label: 'OBS-DP', Frequency: 2
# Entity: 'air bronchograms', Label: 'OBS-DP', Frequency: 2
# Entity: 'curled', Label: 'OBS-DP', Frequency: 2
# Entity: 'catheters', Label: 'OBS-DP', Frequency: 2
# Entity: 'satisfactory', Label: 'OBS-DP', Frequency: 2
# Entity: 'small - to - moderate', Label: 'OBS-DP', Frequency: 2
# Entity: 'haze', Label: 'OBS-DP', Frequency: 2
# Entity: 'infiltrates', Label: 'OBS-DP', Frequency: 2
# Entity: 'Moderate - to - severe', Label: 'OBS-DP', Frequency: 2
# Entity: 'moderate - to - severe', Label: 'OBS-DP', Frequency: 2
# Entity: 'Widened', Label: 'OBS-DP', Frequency: 2
# Entity: 'lymphadenopathy', Label: 'OBS-DP', Frequency: 2
# Entity: 'denser', Label: 'OBS-DP', Frequency: 2
# Entity: 'feeding', Label: 'OBS-DP', Frequency: 2
# Entity: 'ground - glass', Label: 'OBS-DP', Frequency: 2
# Entity: 'coiled', Label: 'OBS-DP', Frequency: 2
# Entity: 'leftward', Label: 'OBS-DP', Frequency: 2
# Entity: 'shift', Label: 'OBS-DP', Frequency: 2
# Entity: 'adenopathy', Label: 'OBS-DP', Frequency: 2
# Entity: 'Expected', Label: 'OBS-DP', Frequency: 2
# Entity: 'Little', Label: 'OBS-DP', Frequency: 2
# Entity: 'extubation', Label: 'OBS-DP', Frequency: 2
# Entity: 'NGT', Label: 'OBS-DP', Frequency: 2
# Entity: 'removal', Label: 'OBS-DP', Frequency: 2
# Entity: 'bronchograms', Label: 'OBS-DP', Frequency: 2
# Entity: 'obliterating', Label: 'OBS-DP', Frequency: 2
# ...
#          ('aeration', 'OBS-DP'): 2,
#          ('resolution', 'OBS-DP'): 2,
#          ('new', 'OBS-DP'): 2,
#          ('confluent', 'OBS-DP'): 2,
#          ('chronic', 'OBS-DP'): 2,
#          ('thickening', 'OBS-DP'): 2,
#          ('S type', 'OBS-DP'): 2,
#          ('similar to prior', 'OBS-DP'): 2,
#          ('tortuosity', 'OBS-DP'): 2,
#          ('Elevation', 'OBS-DP'): 2,
#          ('linear', 'OBS-DP'): 2,
#          ('elevation', 'OBS-DP'): 2,
#          ('scarring', 'OBS-DP'): 2,
#          ('streaky', 'OBS-DP'): 2,
#          ('top', 'OBS-DP'): 2,
#          ('Air', 'OBS-DP'): 2,
#          ('slight', 'OBS-DP'): 2,
#          ('interval', 'OBS-DP'): 2,
#          ('hyperinflated', 'OBS-DP'): 2,
#          ('greater', 'OBS-DP'): 2,
#          ('Sternotomy', 'OBS-DP'): 2,
#          ('extensive', 'OBS-DP'): 2,
#          ('clips', 'OBS-DP'): 2,
#          ('status', 'OBS-DP'): 2,
#          ('post', 'OBS-DP'): 2,
#          ('median', 'OBS-DP'): 2,
#          ('sternotomy', 'OBS-DP'): 2,
#          ('CABG', 'OBS-DP'): 2,
#          ('obstructive', 'OBS-DP'): 2,
#          ('disease', 'OBS-DP'): 2,
#          ('Degenerative', 'OBS-DP'): 2,
#          ('changes', 'OBS-DP'): 2,
#          ('along', 'OBS-DP'): 2,
#          ('COPD', 'OBS-DP'): 2,
#          ('blunting', 'OBS-DP'): 2,
#          ('trace', 'OBS-DP'): 2,
#          ('borderline', 'OBS-DP'): 2,
#          ('calcifications', 'OBS-DP'): 2,
#          ('multilevel', 'OBS-DP'): 2,
#          ('degenerative', 'OBS-DP'): 2,
#          ('post CABG', 'OBS-DP'): 2,
#          ('appropriately', 'OBS-DP'): 2,
#          ('aligned', 'OBS-DP'): 2,
#          ('flattened', 'OBS-DP'): 2,
#          ('markings', 'OBS-DP'): 2,
#          ('subtle', 'OBS-DP'): 2,
#          ('9 mm', 'OBS-DP'): 2,
#          ('otherwise', 'OBS-DP'): 2,
#          ('elongation', 'OBS-DP'): 2,
#          ('flattening', 'OBS-DP'): 2,
#          ('diffuse', 'OBS-DP'): 2,
#          ('Improving', 'OBS-DP'): 2,
#          ('moderately', 'OBS-DP'): 2,
#          ('Scattered', 'OBS-DP'): 2,
#          ('nodules', 'OBS-DP'): 2,
#          ('secondary', 'OBS-DP'): 2,
#          ('accentuation', 'OBS-DP'): 2,
#          ('Tortuosity', 'OBS-DP'): 2,
#          ('Cardiomegaly', 'OBS-DP'): 2,
#          ('Ovoid', 'OBS-DP'): 2,
#          ('Diffuse', 'OBS-DP'): 2,
#          ('Supportive', 'OBS-DP'): 2,
#          ('devices', 'OBS-DP'): 2,
#          ('monitoring', 'OBS-DP'): 2,
#          ('support', 'OBS-DP'): 2,
#          ('Continued', 'OBS-DP'): 2,
#          ('loss', 'OBS-DP'): 2,
#          ('fully', 'OBS-DP'): 2,
#          ('expanded', 'OBS-DP'): 2,
#          ('dense', 'OBS-DP'): 2,
#          ('midline', 'OBS-DP'): 2,
#          ('fluid', 'OBS-DP'): 2,
#          ('Opacification', 'OBS-DP'): 2,
#          ('Monitoring', 'OBS-DP'): 2,
#          ('port', 'OBS-DP'): 2,
#          ('catheter', 'OBS-DP'): 2,
#          ('Hyperinflated', 'OBS-DP'): 2,
#          ('upper', 'OBS-DP'): 2,
#          ('in position', 'OBS-DP'): 2,
#          ('Increase', 'OBS-DP'): 2,
#          ('caliber', 'OBS-DP'): 2,
#          ('Port - A - Cath', 'OBS-DP'): 2,
#          ('essentially', 'OBS-DP'): 2,
#          ('inflated', 'OBS-DP'): 2,
#          ('calcification', 'OBS-DP'): 2,
#          ('demineralization', 'OBS-DP'): 2,
#          ('Well', 'OBS-DP'): 2,
#          ('Linear', 'OBS-DP'): 2,
#          ('redistribution', 'OBS-DP'): 2,
#          ('hazy', 'OBS-DP'): 2,
#          ('ill - defined', 'OBS-DP'): 2,
#          ('vascularity', 'OBS-DP'): 2,
#          ('IJ', 'OBS-DP'): 2,
#          ('Increased', 'OBS-DP'): 2,
#          ('faint', 'OBS-DP'): 2,
#          ('Multifocal', 'OBS-DP'): 2,
#          ('infection', 'OBS-DP'): 2,
#          ('decreased', 'OBS-DP'): 2,
#          ('in extent', 'OBS-DP'): 2,
#          ('severity', 'OBS-DP'): 2,
#          ('replacement', 'OBS-DP'): 2,
#          ('right internal jugular vein', 'OBS-DP'): 2,
#          ('Discrete', 'OBS-DP'): 2,
#          ('consolidation', 'OBS-DP'): 2,
#          ('worsened', 'OBS-DP'): 2,
#          ('postoperative', 'OBS-DP'): 2,
#          ('drains', 'OBS-DP'): 2,
#          ('in place', 'OBS-DP'): 2,
#          ('Swan - Ganz', 'OBS-DP'): 2,
#          ('placement', 'OBS-DP'): 2,
#          ('nondistended', 'OBS-DP'): 2,
#          ('migrated', 'OBS-DP'): 2,
#          ('proximally', 'OBS-DP'): 2,
#          ('blurring', 'OBS-DP'): 2,
#          ('horizontal', 'OBS-DP'): 2,
#          ('proximal', 'OBS-DP'): 2,
#          ('side port', 'OBS-DP'): 2,
#          ('other', 'OBS-DP'): 2,
#          ('homogeneous', 'OBS-DP'): 2,
#          ('Trace', 'OBS-DP'): 2,
#          ('constant', 'OBS-DP'): 2,
#          ('Surgical', 'OBS-DP'): 2,
#          ('symmetrical', 'OBS-DP'): 2,
#          ('surgical', 'OBS-DP'): 2,
#          ('deviation', 'OBS-DP'): 2,
#          ('left', 'OBS-DP'): 2,
#          ('vessel on end', 'OBS-DP'): 2,
#          ('Consolidative', 'OBS-DP'): 2,
#          ('NORMAL', 'OBS-DP'): 2,
#          ('accessory', 'OBS-DP'): 2,
#          ('azygos', 'OBS-DP'): 2,
#          ('fissure', 'OBS-DP'): 2,
#          ('tortuous', 'OBS-DP'): 2,
#          ('atherosclerotic', 'OBS-DP'): 2,
#          ('Crowding', 'OBS-DP'): 2,
#          ('decompensated', 'OBS-DP'): 2,
#          ('CHF', 'OBS-DP'): 2,
#          ('Calcific', 'OBS-DP'): 2,
#          ('densities', 'OBS-DP'): 2,
#          ('gallbladder', 'OBS-DP'): 2,
#          ('crowding of', 'OBS-DP'): 2,
#          ('minimally', 'OBS-DP'): 2,
#          ('changed', 'OBS-DP'): 2,
#          ('crowd', 'OBS-DP'): 2,
#          ('vasculature', 'OBS-DP'): 2,
#          ('better', 'OBS-DP'): 2,
#          ('some', 'OBS-DP'): 2,
#          ('Blunting', 'OBS-DP'): 2,
#          ('in standard position', 'OBS-DP'): 2,
#          ('side holes', 'OBS-DP'): 2,
#          ('dual', 'OBS-DP'): 2,
#          ('lead', 'OBS-DP'): 2,
#          ('pacemaker', 'OBS-DP'): 2,
#          ('tips', 'OBS-DP'): 2,
#          ('3.5 cm', 'OBS-DP'): 2,
#          ('metallic', 'OBS-DP'): 2,
#          ('foreign', 'OBS-DP'): 2,
#          ('object', 'OBS-DP'): 2,
#          ('two', 'OBS-DP'): 2,
#          ('components', 'OBS-DP'): 2,
#          ('curvilinear', 'OBS-DP'): 2,
#          ('iatrogenic', 'OBS-DP'): 2,
#          ('well - expanded', 'OBS-DP'): 2,
#          ('in acceptable position', 'OBS-DP'): 2,
#          ('advanced', 'OBS-DP'): 2,
#          ('by several centimeters', 'OBS-DP'): 2,
#          ('implement', 'OBS-DP'): 2,
#          ('not seen', 'OBS-DP'): 2,
#          ('less', 'OBS-DP'): 2,
#          ('not well seen', 'OBS-DP'): 2,
#          ('Pacer', 'OBS-DP'): 2,
#          ('leads', 'OBS-DP'): 2,
#          ('improvement', 'OBS-DP'): 2,
#          ('less prominent', 'OBS-DP'): 2,
#          ('upright position', 'OBS-DP'): 2,
#          ('atelectatic', 'OBS-DP'): 2,
#          ('chest', 'OBS-DP'): 2,
#          ('on waterseal', 'OBS-DP'): 2,
#          ('amount', 'OBS-DP'): 2,
#          ('partially assessed', 'OBS-DP'): 2,
#          ('Atelectatic', 'OBS-DP'): 2,
#          ('existing', 'OBS-DP'): 2,
#          ('thickenings', 'OBS-DP'): 2,
#          ('injury', 'OBS-DP'): 2,
#          ('regressed', 'OBS-DP'): 2,
#          ('displaced', 'OBS-DP'): 2,
#          ('injuries', 'OBS-DP'): 2,
#          ('comminuted', 'OBS-DP'): 2,
#          ('displacement', 'OBS-DP'): 2,
#          ('to the right', 'OBS-DP'): 2,
#          ('obliquity of the patient', 'OBS-DP'): 2,
#          ('several', 'OBS-DP'): 2,
#          ('Poor definition', 'OBS-DP'): 2,
#          ('not as well seen on this study', 'OBS-DP'): 2,
#          ('lucency', 'OBS-DP'): 2,
#          ('residual', 'OBS-DP'): 2,
#          ('pneumothorax', 'OBS-DP'): 2,
#          ('air', 'OBS-DP'): 2,
#          ('Extensive', 'OBS-DP'): 2,
#          ('emphysema', 'OBS-DP'): 2,
#          ('Pneumomediastinum', 'OBS-DP'): 2,
#          ('pneumopericardium', 'OBS-DP'): 2,
#          ('severely', 'OBS-DP'): 2,
#          ('fractured', 'OBS-DP'): 2,
#          ('hemorrahge', 'OBS-DP'): 2,
#          ('assessment', 'OBS-DP'): 2,
#          ('limited', 'OBS-DP'): 2,
#          ('Focal', 'OBS-DP'): 2,
#          ('pneumomediastinum', 'OBS-DP'): 2,
#          ('drain', 'OBS-DP'): 2,
#          ('higher', 'OBS-DP'): 2,
#          ('opacified', 'OBS-DP'): 2,
#          ('alongside', 'OBS-DP'): 2,
#          ('elongated', 'OBS-DP'): 2,
#          ('aortosclerosis', 'OBS-DP'): 2,
#          ('increse', 'OBS-DP'): 2,
#          ('collections', 'OBS-DP'): 2,
#          ('very', 'OBS-DP'): 2,
#          ('sharp', 'OBS-DP'): 2,
#          ('severe', 'OBS-DP'): 2,
#          ('deeper', 'OBS-DP'): 2,
#          ('pneumo mediastinum', 'OBS-DP'): 2,
#          ('large', 'OBS-DP'): 2,
#          ('tiny', 'OBS-DP'): 2,
#          ('1-2 mm', 'OBS-DP'): 2,
#          ('Unremarkable', 'OBS-DP'): 2,
#          ('examination', 'OBS-DP'): 2,
#          ('clip', 'OBS-DP'): 2,
#          ('Clear', 'OBS-DP'): 2,
#          ('nipple', 'OBS-DP'): 2,
#          ('shadows', 'OBS-DP'): 2,
#          ('A', 'OBS-DP'): 2,
#          ('rod', 'OBS-DP'): 2,
#          ('overlies', 'OBS-DP'): 2,
#          ('area', 'OBS-DP'): 2,
#          ('diameter', 'OBS-DP'): 2,
#          ('1.5 cm', 'OBS-DP'): 2,
#          ('deformity', 'OBS-DP'): 2,
#          ('Clips', 'OBS-DP'): 2,
#          ('mediastinal', 'OBS-DP'): 2,
#          ('tubes', 'OBS-DP'): 2,
#          ('sheath', 'OBS-DP'): 2,
#          ('positions', 'OBS-DP'): 2,
#          ('lines', 'OBS-DP'): 2,
#          ('pneumothoraces', 'OBS-DP'): 2,
#          ('distance', 'OBS-DP'): 2,
#          ('bubble', 'OBS-DP'): 2,
#          ('Lines', 'OBS-DP'): 2,
#          ('over', 'OBS-DP'): 2,
#          ('Post - operative', 'OBS-DP'): 2,
#          ('predominance', 'OBS-DP'): 2,
#          ('markedly', 'OBS-DP'): 2,
#          ('Calcified', 'OBS-DP'): 2,
#          ('Streaky', 'OBS-DP'): 2,
#          ('diffusely', 'OBS-DP'): 2,
#          ('demineralized', 'OBS-DP'): 2,
#          ('compression', 'OBS-DP'): 2,
#          ('Deformity', 'OBS-DP'): 2,
#          ('indistinctness', 'OBS-DP'): 2,
#          ('progression', 'OBS-DP'): 2,
#          ('interstitial', 'OBS-DP'): 2,
#          ('worsening', 'OBS-DP'): 2,
#          ('atypical', 'OBS-DP'): 2,
#          ('reticular', 'OBS-DP'): 2,
#          ('previous', 'OBS-DP'): 2,
#          ('moderate - sized', 'OBS-DP'): 2,
#          ('cluster', 'OBS-DP'): 2,
#          ('infiltration', 'OBS-DP'): 2,
#          ('granulomatous', 'OBS-DP'): 2,
#          ('Study', 'OBS-DP'): 2,
#          ('poor', 'OBS-DP'): 2,
#          ('penetration', 'OBS-DP'): 2,
#          ('reexpansion', 'OBS-DP'): 2,
#          ('thoracocentesis', 'OBS-DP'): 2,
#          ('pre - existing', 'OBS-DP'): 2,
#          ('substantially', 'OBS-DP'): 2,
#          ('obscures', 'OBS-DP'): 2,
#          ('right', 'OBS-DP'): 2,
#          ('granuloma', 'OBS-DP'): 2,
#          ('Size', 'OBS-DP'): 2,
#          ('in size', 'OBS-DP'): 2,
#          ('Decreased', 'OBS-DP'): 2,
#          ('engorged', 'OBS-DP'): 2,
#          ('Enlarging', 'OBS-DP'): 2,
#          ('infiltrate', 'OBS-DP'): 2,
#          ('haziness', 'OBS-DP'): 2,
#          ('Large', 'OBS-DP'): 2,
#          ('retracted 4.5 cm', 'OBS-DP'): 2,
#          ('pulled back about 5 cm', 'OBS-DP'): 2,
#          ('Feeding', 'OBS-DP'): 2,
#          ('wire', 'OBS-DP'): 2,
#          ('stylet', 'OBS-DP'): 2,
#          ('Subtle', 'OBS-DP'): 2,
#          ('Improved', 'OBS-DP'): 2,
#          ('internal jugular central venous', 'OBS-DP'): 2,
#          ('reasonably', 'OBS-DP'): 2,
#          ('well defined', 'OBS-DP'): 2,
#          ('Cephalization', 'OBS-DP'): 2,
#          ('Comminuted', 'OBS-DP'): 2,
#          ('hypoventilation', 'OBS-DP'): 2,
#          ('setting of splinting', 'OBS-DP'): 2,
#          ('Partially imaged', 'OBS-DP'): 2,
#          ('fusion', 'OBS-DP'): 2,
#          ('hardware', 'OBS-DP'): 2,
#          ('persistently', 'OBS-DP'): 2,
#          ('acute', 'OBS-DP'): 2,
#          ('Displaced', 'OBS-DP'): 2,
#          ('healed', 'OBS-DP'): 2,
#          ('similar compared to the previous exams', 'OBS-DP'): 2,
#          ('especially', 'OBS-DP'): 2,
#          ('orientation', 'OBS-DP'): 2,
#          ('fixation', 'OBS-DP'): 2,
#          ('transesophageal', 'OBS-DP'): 2,
#          ('SVC', 'OBS-DP'): 2,
#          ('developing', 'OBS-DP'): 2,
#          ('central', 'OBS-DP'): 2,
#          ('venous', 'OBS-DP'): 2,
#          ('Developing', 'OBS-DP'): 2,
#          ('development', 'OBS-DP'): 2,
#          ('widespread', 'OBS-DP'): 2,
#          ('Support', 'OBS-DP'): 2,
#          ('in', 'OBS-DP'): 2,
#          ('osteopenia', 'OBS-DP'): 2,
#          ('sparing', 'OBS-DP'): 2,
#          ('Previous', 'OBS-DP'): 2,
#          ('process', 'OBS-DP'): 2,
#          ('Findings', 'OBS-DP'): 2,
#          ('stably', 'OBS-DP'): 2,
#          ('Status', 'OBS-DP'): 2,
#          ('Loops', 'OBS-DP'): 2,
#          ('Moderately', 'OBS-DP'): 2,
#          ('Improvement', 'OBS-DP'): 2,
#          ('plate - like', 'OBS-DP'): 2,
#          ('platelike', 'OBS-DP'): 2,
#          ('a', 'OBS-DP'): 2,
#          ('distal', 'OBS-DP'): 2,
#          ('persistent', 'OBS-DP'): 2,
#          ('Plate - like', 'OBS-DP'): 2,
#          ('patient', 'OBS-DP'): 2,
#          ('extubated', 'OBS-DP'): 2,
#          ('radiodensity', 'OBS-DP'): 2,
#          ('lying', 'OBS-DP'): 2,
#          ('Two', 'OBS-DP'): 2,
#          ('2', 'OBS-DP'): 2,
#          ('air bronchograms', 'OBS-DP'): 2,
#          ('curled', 'OBS-DP'): 2,
#          ('catheters', 'OBS-DP'): 2,
#          ('satisfactory', 'OBS-DP'): 2,
#          ('small - to - moderate', 'OBS-DP'): 2,
#          ('haze', 'OBS-DP'): 2,
#          ('infiltrates', 'OBS-DP'): 2,
#          ('Moderate - to - severe', 'OBS-DP'): 2,
#          ('moderate - to - severe', 'OBS-DP'): 2,
#          ('Widened', 'OBS-DP'): 2,
#          ('lymphadenopathy', 'OBS-DP'): 2,
#          ('denser', 'OBS-DP'): 2,
#          ('feeding', 'OBS-DP'): 2,
#          ('ground - glass', 'OBS-DP'): 2,
#          ('coiled', 'OBS-DP'): 2,
#          ('leftward', 'OBS-DP'): 2,
#          ('shift', 'OBS-DP'): 2,
#          ('adenopathy', 'OBS-DP'): 2,
#          ('Expected', 'OBS-DP'): 2,
#          ('Little', 'OBS-DP'): 2,
#          ('extubation', 'OBS-DP'): 2,
#          ('NGT', 'OBS-DP'): 2,
#          ('removal', 'OBS-DP'): 2,
#          ('bronchograms', 'OBS-DP'): 2,
#          ('obliterating', 'OBS-DP'): 2,
#          ('orogastric', 'OBS-DP'): 2,
#          ('out of the field of view', 'OBS-DP'): 2,
#          ('Enlargement', 'OBS-DP'): 2,
#          ('exaggerated', 'OBS-DP'): 2,
#          ('AP technique', 'OBS-DP'): 2,
#          ('cardiomegally', 'OBS-DP'): 2,
#          ('generalized', 'OBS-DP'): 2,
#          ('out of view', 'OBS-DP'): 2,
#          ('Pacemaker', 'OBS-DP'): 2,
#          ('kyphosis', 'OBS-DP'): 2,
#          ('cardiac', 'OBS-DP'): 2,
#          ('pacer', 'OBS-DP'): 2,
#          ('not well evaluated', 'OBS-DP'): 2,
#          ('Healed', 'OBS-DP'): 2,
#          ('Atelectasis', 'OBS-DP'): 2,
#          ('Subcutaneous', 'OBS-DP'): 2,
#          ('gas', 'OBS-DP'): 2,
#          ('free', 'OBS-DP'): 2,
#          ('approximately', 'OBS-DP'): 2,
#          ('13 mm', 'OBS-DP'): 2,
#          ('hyperlucent', 'OBS-DP'): 2,
#          ('Fully', 'OBS-DP'): 2,
#          ('to', 'OBS-DP'): 2,
#          ('underpenetration', 'OBS-DP'): 2,
#          ('Worsening', 'OBS-DP'): 2,
#          ('supine', 'OBS-DP'): 2,
#          ('6 cm above', 'OBS-DP'): 2,
#          ('coursing', 'OBS-DP'): 2,
#          ('inferiorly', 'OBS-DP'): 2,
#          ('expected', 'OBS-DP'): 2,
#          ('widened', 'OBS-DP'): 2,
#          ('inspiration', 'OBS-DP'): 2,
#          ('opacifications', 'OBS-DP'): 2,
#          ('positioned', 'OBS-DP'): 2,
#          ('high', 'OBS-DP'): 2,
#          ('Widening', 'OBS-DP'): 2,
#          ('High', 'OBS-DP'): 2,
#          ('exchanged', 'OBS-DP'): 2,
#          ('type', 'OBS-DP'): 2,
#          ('Prominent', 'OBS-DP'): 2,
#          ('density', 'OBS-DP'): 2,
#          ('nasoenteric', 'OBS-DP'): 2,
#          ('widening', 'OBS-DP'): 2,
#          ('collapsed', 'OBS-DP'): 2,
#          ('Its', 'OBS-DP'): 2,
#          ('Esophageal', 'OBS-DP'): 2,
#          ('drainage', 'OBS-DP'): 2,
#          ('quite', 'OBS-DP'): 2,
#          ('milder', 'OBS-DP'): 2,
#          ('AICD', 'OBS-DP'): 2,
#          ('single', 'OBS-DP'): 2,
#          ('Indistinctness', 'OBS-DP'): 2,
#          ('wedge', 'OBS-DP'): 2,
#          ('resection', 'OBS-DP'): 2,
#          ('procedure', 'OBS-DP'): 2,
#          ('6 - mm', 'OBS-DP'): 2,
#          ('nodular', 'OBS-DP'): 2,
#          ('suture', 'OBS-DP'): 2,
#          ('6', 'OBS-DP'): 2,
#          ('mm', 'OBS-DP'): 2,
#          ('nodule', 'OBS-DP'): 2,
#          ('chain', 'OBS-DP'): 2,
#          ...})

# %% [markdown]
# ## Discussion about the result from RadGraph
#
# cardiomediastinal
# 要被分成carido，mediastinal
# Heart (C0018787)
# Mediastinal (C1522718)
#
#
# 这里的500标准数据，其实也不可靠，没有考虑到嵌套和后续的可能的标准花处理，比如分割复合单词。
# - 是个很rough的数据。
#
# 我们在这里要多做一步。我称之为 简单实体 to 标准化实体。
# - 这一步用生产式AI，就像上面的例子，很好用。
# - 或者用规则，也可以。
#
# 为后续的normalization做准备。

# %% [markdown]
# 鉴于这个结果，我们可以做一些更实际的应用层面上的工作。

# %%
unique_second_elements = {token[1] for token in all_tokens}

print(unique_second_elements)

num_unique_second_elements = len(unique_second_elements)
print(num_unique_second_elements)

type_counts = {}
for token in all_tokens:
    token_type = token[1]
    if token_type in type_counts:
        type_counts[token_type] += 1
    else:
        type_counts[token_type] = 1

print(type_counts)

# Filter the tokens to include only ANAT-DP tokens
anat_dp_tokens = [token for token in all_tokens if token[1] == 'ANAT-DP']

# Print the content of ANAT-DP tokens
for token in anat_dp_tokens:
    print(token[0])

# %% [markdown]
# entity: 12388
# unique: 1250

# %%
relations = set()

i = 0

# Step 1: Iterate through each document in train_data
for document_key in train_data:
    # Access the 'entities' for the current document
    entities = train_data[document_key]['entities']
    
    # Step 2: Iterate through each entity in 'entities'
    for entity_key in entities:
        # Access the entity and its relations
        entity = entities[entity_key]
        entity_relations = entity['relations']
        
        # Step 3: Iterate through each relation in 'entity_relations'
        for relation in entity_relations:
            # Extract the related entity key and relation type
            related_entity_key = relation[1]
            relation_type = relation[0]
            
            # Get the related entity
            related_entity = entities[related_entity_key]
            
            # Create a tuple with entity1, entity2, and relation
            relation_tuple = (entity['tokens'], related_entity['tokens'], relation_type)
            
            # Add the relation tuple to the set of relations
            relations.add(relation_tuple)

            i += 1

# At this point, 'relations' contains all the relations between entities in the 'train_data'
print(len(relations))
print(i)
# print(relations)
# Out:
# 3363
# 9251

# %% [markdown]
# 3300 relations

# %% [markdown]
# ## neo4j database setup

# %%
from py2neo import Graph, Node, Relationship

# 连接到Neo4j数据库
# graph = Graph("bolt://localhost:7689", auth=("neo4j", "neo4j"))

# 创建节点
# alice = Node("Person", name="Alice", age=25)
# bob = Node("Person", name="Bob", age=30)
# graph.create(alice)
# graph.create(bob)

# # 创建关系
# alice_knows_bob = Relationship(alice, "KNOWS", bob)
# graph.create(alice_knows_bob)

# %% [markdown]
# # RadGraph 75 dev set

# %%
import json
from pprint import pprint

# path = '/DATA1/llm-research/RadGraph/physionet.org/files/radgraph/1.0.0/train.json'
path = '/DATA1/llm-research/RadGraph/physionet.org/files/radgraph/1.0.0/dev.json'


with open(path, 'r') as f:
    train_data = json.load(f)
# Out:
# Length of data: 75
# First 10 keys of data: ['p10/p10003412/s59172281.txt', 'p18/p18001816/s54309228.txt', 'p15/p15003878/s57380048.txt', 'p15/p15003878/s59424963.txt', 'p15/p15003878/s54410100.txt', 'p15/p15003878/s56836141.txt', 'p15/p15003878/s55982972.txt', 'p15/p15003878/s55991257.txt', 'p15/p15003878/s51651577.txt', 'p15/p15003878/s51266756.txt']

# %% [markdown]
# ## to nen file

# %%
import json
import pprint

# Step 1: Initialize an empty dictionary to store all unique entities
# structure: label: {entity: {normalization: null, reports: list}}
all_unique_entities_dict = {}

# list of all entities
i = 0

# Step 2: Iterate through each report in the train_data
for report_key, report_data in train_data.items():
    for entity_id, entity_info in report_data['entities'].items():
        i += 1
        entity = entity_info['tokens']
        label = entity_info['label']
        start_ix = entity_info['start_ix']
        end_ix = entity_info['end_ix']



        if entity not in all_unique_entities_dict:
            all_unique_entities_dict[entity] = {
                'label': label,
                'reports': [
                    {report_key: 
                        {   'start_ix': start_ix, 
                            'end_ix': end_ix
                        }
                    }
                ],
                'normalization': None
            }
        else:
            all_unique_entities_dict[entity]['reports'].append(
                {report_key: 
                    {   'start_ix': start_ix, 
                        'end_ix': end_ix
                    }
                }
            )

# len of all_unique_entities_dict
print('Length of all_unique_entities_dict:', len(all_unique_entities_dict))
print('Number of entities:', i)

# Save Output all_entities to a JSON file
path = '../resource/all_unique_entities_dev.json'
with open(path , 'w', encoding='utf-8') as f:
    json.dump(all_unique_entities_dict, f, ensure_ascii=False, indent=4)

print(f"All entities have been saved to '{path}'")
# Out:
# Length of all_unique_entities_dict: 482
# Number of entities: 2191
# All entities have been saved to '../resource/all_unique_entities_dev.json'

# %% [markdown]
# ## from dev.json to unique_entities_dev.csv

# %%
# all_unique_entities_dict is json
# json has entity, (label, reports: list, normalization)
# csv has name,ui,normalized_name,semanticTypes,definition

import csv
import json
import pprint

all_unique_entities_dict

# creat csv, entity = name
file_path = '../resource/not_normalized_dev.csv'
with open(file_path, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['name', 'ui', 'normalized_name', 'semanticTypes', 'definition'])
    for entity, entity_info in all_unique_entities_dict.items():
        writer.writerow([entity, '', '', '', ''])

print(f"CSV file has been saved to '{file_path}'")
# Out:
# CSV file has been saved to '../resource/not_normalized_dev.csv'

# %% [markdown]
# # whole RadGraph 500

# %%
import json
from pprint import pprint

path = '../resource/radgraph/train_dev.json'

with open(path, 'r') as f:
    data = json.load(f)

# len of data
print('Length of data:', len(data))
# Out:
# Length of data: 500

# %%
import json
import pprint

data

# Step 1: Initialize an empty dictionary to store all unique entities
# structure: label: {entity: {normalization: null, reports: list}}
all_unique_entities_dict = {}

# list of all entities
i = 0

# Step 2: Iterate through each report in the train_data
for report_key, report_data in data.items():
    for entity_id, entity_info in report_data['entities'].items():
        i += 1
        entity = entity_info['tokens']
        label = entity_info['label']
        start_ix = entity_info['start_ix']
        end_ix = entity_info['end_ix']


        if entity not in all_unique_entities_dict:
            all_unique_entities_dict[entity] = {
                'label': label,
                'reports': [
                    {report_key: 
                        {   'start_ix': start_ix, 
                            'end_ix': end_ix
                        }
                    }
                ],
                'normalization': None
            }
        else:
            all_unique_entities_dict[entity]['reports'].append(
                {report_key: 
                    {   'start_ix': start_ix, 
                        'end_ix': end_ix
                    }
                }
            )

# len of all_unique_entities_dict
print('Length of all_unique_entities_dict:', len(all_unique_entities_dict))
print('Number of entities:', i)


###################### creat csv, entity = name
file_path = '../resource/not_normalized.csv'
with open(file_path, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['name', 'ui', 'normalized_name', 'semanticTypes', 'definition'])
    for entity, entity_info in all_unique_entities_dict.items():
        writer.writerow([entity, '', '', '', ''])

print(f"CSV file has been saved to '{file_path}'")
# Out:
# Length of all_unique_entities_dict: 1353
# Number of entities: 14579

# %% [markdown]
# ## read from train.js

# %%
file_path = '../resource/not_normalized.csv'
# Read the data from the CSV file
data = []

with open(file_path, 'r', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        data.append(row)
    
# Print the length of the data
print(f"Length of data: {len(data)}")
# Out:
# Length of data: 1353

# %% [markdown]
# # extract all text

# %%
import json

test_json_path = 'splits/test_chexpert.json'

with open(test_json_path, 'r') as f:
    test_data = json.load(f)

output_file_path = 'test_chexpert_texts.txt'
with open(output_file_path, 'w', encoding='utf-8') as out_file:
    for _, report_data in test_data.items():
        text_content = report_data.get('text', '')
        out_file.write(text_content + '\n')

print(f"All 'text' fields have been saved to '{output_file_path}'")
# Out:
# All 'text' fields have been saved to 'test_chexpert_texts.txt'

# %%
import json

test_json_path = 'splits/test_mimic.json'

with open(test_json_path, 'r') as f:
    test_data = json.load(f)

output_file_path = 'test_mimic_texts.txt'
with open(output_file_path, 'w', encoding='utf-8') as out_file:
    for _, report_data in test_data.items():
        text_content = report_data.get('text', '')
        out_file.write(text_content + '\n')

print(f"All 'text' fields have been saved to '{output_file_path}'")
# Out:
# All 'text' fields have been saved to 'test_mimic_texts.txt'
